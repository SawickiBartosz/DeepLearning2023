# %%
import gc
import os
import pickle
import random
import shutil

import numpy as np
import pandas as pd
import tensorflow as tf
from keras import losses, optimizers, metrics, callbacks

# %%
tf.config.list_logical_devices()
# Out:
# [LogicalDevice(name='/device:CPU:0', device_type='CPU'),
#  LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
SEED = 123
N_CLASS = 12
MAX_EPOCHS = 200

# %%
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Load data

# %%
train_ds = tf.keras.utils.audio_dataset_from_directory(
    directory="data/train",
    batch_size=512,
    output_sequence_length=16000,
    shuffle=True,
    seed=SEED
)

val_ds = tf.keras.utils.audio_dataset_from_directory(
    directory="data/val",
    batch_size=512,
    output_sequence_length=16000
)

test_ds = tf.keras.utils.audio_dataset_from_directory(
    directory="data/test",
    batch_size=512,
    output_sequence_length=16000)

label_names = np.array(train_ds.class_names)
print("label names:", label_names)
# Out:
# Found 45586 files belonging to 12 classes.
# Found 6513 files belonging to 12 classes.
# Found 13024 files belonging to 12 classes.
# label names: ['down' 'go' 'left' 'no' 'off' 'on' 'right' 'silence' 'stop' 'unknown'
#  'up' 'yes']

# %%
def squeeze(audio, labels):
    audio = tf.squeeze(audio, axis=-1)
    return audio, labels

train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
val_ds = val_ds.map(squeeze, tf.data.AUTOTUNE)
test_ds = test_ds.map(squeeze, tf.data.AUTOTUNE)

# %% [markdown]
# ## CNN + LSTM Complex

# %%
from SpeechModels import get_melspec_model
import tensorflow.keras.layers as L
from keras.models import Model

def CNN_LSTM(n_out, input_length, kernel_size):

    mel_spec_model = get_melspec_model(input_length)
    inputs, outputs = mel_spec_model.inputs, mel_spec_model.outputs
    o_shape = outputs[0].shape
    y1 = L.Conv1D(32, kernel_size, activation='relu', padding='same', input_shape=o_shape[1:])(outputs[0])
    y2 = L.Conv1D(32, kernel_size * 2, activation='relu', padding='same', input_shape=o_shape[1:])(outputs[0])
    y3 = L.Conv1D(32, kernel_size * 4, activation='relu', padding='same', input_shape=o_shape[1:])(outputs[0])
    y4 = L.Conv1D(32, kernel_size * 8, activation='relu', padding='same', input_shape=o_shape[1:])(outputs[0])

    x = L.Concatenate(axis=-1)([y1, y2, y3, y4])

    x = L.Bidirectional(L.LSTM(128, return_sequences=False)
                        )(x)  # [b_s, seq_len, vec_dim]

    output = L.Dense(n_out, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs], outputs=[output])

    return model


model = CNN_LSTM(N_CLASS, 16000, 4)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 16000)]      0           []
#
#  tf.signal.stft (TFOpLambda)    (None, 125, 513)     0           ['input[0][0]']
#
#  tf.math.abs (TFOpLambda)       (None, 125, 513)     0           ['tf.signal.stft[0][0]']
#
#  tf.tensordot (TFOpLambda)      (None, 125, 80)      0           ['tf.math.abs[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 125, 80)     0           ['tf.tensordot[0][0]']
#  da)
#
#  tf.math.log (TFOpLambda)       (None, 125, 80)      0           ['tf.__operators__.add[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  ()                  0           ['tf.math.log[0][0]']
#  a)
#
#  tf.math.subtract (TFOpLambda)  (None, 125, 80)      0           ['tf.math.log[0][0]',
#                                                                   'tf.math.reduce_mean[0][0]']
#
#  tf.math.reduce_std (TFOpLambda  ()                  0           ['tf.math.log[0][0]']
#  )
#
#  tf.math.truediv (TFOpLambda)   (None, 125, 80)      0           ['tf.math.subtract[0][0]',
#                                                                   'tf.math.reduce_std[0][0]']
#
#  conv1d (Conv1D)                (None, 125, 32)      10272       ['tf.math.truediv[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 125, 32)      20512       ['tf.math.truediv[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 125, 32)      40992       ['tf.math.truediv[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 125, 32)      81952       ['tf.math.truediv[0][0]']
#
#  concatenate (Concatenate)      (None, 125, 128)     0           ['conv1d[0][0]',
#                                                                   'conv1d_1[0][0]',
#                                                                   'conv1d_2[0][0]',
#                                                                   'conv1d_3[0][0]']
#
#  bidirectional (Bidirectional)  (None, 256)          263168      ['concatenate[0][0]']
#
#  output (Dense)                 (None, 12)           3084        ['bidirectional[0][0]']
#
# ==================================================================================================
# Total params: 419,980
# Trainable params: 419,980
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer=optimizers.Adam(learning_rate=0.001),
    loss=losses.SparseCategoricalCrossentropy(),
    metrics=[metrics.SparseCategoricalAccuracy(), metrics.SparseCategoricalCrossentropy()]
)
checkpoint = callbacks.ModelCheckpoint(
    filepath="simple_cnn.h5",
    monitor="val_sparse_categorical_accuracy",
    verbose=0,
    save_best_only=True,
    save_weights_only=True
)

early_stopping = callbacks.EarlyStopping(
    monitor='val_sparse_categorical_accuracy',
    min_delta=0,
    patience=5,
    verbose=0,
    mode='max',
    baseline=None,
    restore_best_weights=True
)

reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_sparse_categorical_accuracy', factor=0.5, patience=3, min_lr=0.00001, verbose=1)

# %%
history = model.fit(
    train_ds,
    epochs=2,
    validation_data=val_ds,
    shuffle=True,
    callbacks=[checkpoint, early_stopping, reduce_lr]
)
# Out:
# Epoch 1/2
# 90/90 [==============================] - 22s 120ms/step - loss: 1.3249 - sparse_categorical_accuracy: 0.6395 - sparse_categorical_crossentropy: 1.3249 - val_loss: 0.9760 - val_sparse_categorical_accuracy: 0.7029 - val_sparse_categorical_crossentropy: 0.9760 - lr: 0.0010
# Epoch 2/2
# 90/90 [==============================] - 13s 132ms/step - loss: 0.7188 - sparse_categorical_accuracy: 0.7796 - sparse_categorical_crossentropy: 0.7188 - val_loss: 0.5023 - val_sparse_categorical_accuracy: 0.8366 - val_sparse_categorical_crossentropy: 0.5023 - lr: 0.0010

# %% [markdown]
# ## Experiments
#
# Training will be repeated 5 times with different weights initialization.

# %%
EXPERIMENT_NAME = "cnn_lstm_complex"
if os.path.exists(EXPERIMENT_NAME):
    shutil.rmtree(EXPERIMENT_NAME)
    os.mkdir(EXPERIMENT_NAME)
else:
    os.mkdir(EXPERIMENT_NAME)

# %%
TRAINING_SEEDS = list(range(5))
results = []
for seed in TRAINING_SEEDS:
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

    model = CNN_LSTM(N_CLASS, 16000, 4)

    model.compile(
        optimizer=optimizers.Adam(learning_rate=0.01),
        loss=losses.SparseCategoricalCrossentropy(),
        metrics=[metrics.SparseCategoricalAccuracy(), metrics.SparseCategoricalCrossentropy()]
    )

    history = model.fit(
        train_ds,
        epochs=MAX_EPOCHS,
        validation_data=val_ds,
        shuffle=True,
        callbacks=[early_stopping, reduce_lr]
    )

    with open(os.path.join(EXPERIMENT_NAME, f"history_{seed}.pkl"), "wb") as file:
        pickle.dump(history.history, file)

    eval_results = model.evaluate(test_ds)

    predictions = model.predict(test_ds)
    with open(os.path.join(EXPERIMENT_NAME, f"predictions_{seed}.pkl"), "wb") as file:
        pickle.dump(predictions, file)

    results += [{
        'seed': seed,
        'results': dict(zip(model.metrics_names, eval_results))
    }]
    gc.collect()

results = pd.DataFrame(results)
results = pd.concat([results.drop(["results"], axis=1), results["results"].apply(pd.Series)], axis=1)
results.to_csv(os.path.join(EXPERIMENT_NAME, 'results.csv'))
# Out:
# Epoch 1/200
# 90/90 [==============================] - 16s 132ms/step - loss: 1.5407 - sparse_categorical_accuracy: 0.6232 - sparse_categorical_crossentropy: 1.5407 - val_loss: 1.4670 - val_sparse_categorical_accuracy: 0.6301 - val_sparse_categorical_crossentropy: 1.4670 - lr: 0.0100
# Epoch 2/200
# 90/90 [==============================] - 13s 135ms/step - loss: 1.4285 - sparse_categorical_accuracy: 0.6304 - sparse_categorical_crossentropy: 1.4285 - val_loss: 1.4104 - val_sparse_categorical_accuracy: 0.6303 - val_sparse_categorical_crossentropy: 1.4104 - lr: 0.0100
# Epoch 3/200
# 90/90 [==============================] - 13s 137ms/step - loss: 1.3552 - sparse_categorical_accuracy: 0.6316 - sparse_categorical_crossentropy: 1.3552 - val_loss: 1.3186 - val_sparse_categorical_accuracy: 0.6309 - val_sparse_categorical_crossentropy: 1.3186 - lr: 0.0100
# Epoch 4/200
# 90/90 [==============================] - 13s 137ms/step - loss: 1.3199 - sparse_categorical_accuracy: 0.6317 - sparse_categorical_crossentropy: 1.3199 - val_loss: 1.3357 - val_sparse_categorical_accuracy: 0.6317 - val_sparse_categorical_crossentropy: 1.3357 - lr: 0.0100
# Epoch 5/200
# 90/90 [==============================] - 13s 134ms/step - loss: 1.3138 - sparse_categorical_accuracy: 0.6342 - sparse_categorical_crossentropy: 1.3138 - val_loss: 1.3268 - val_sparse_categorical_accuracy: 0.6327 - val_sparse_categorical_crossentropy: 1.3268 - lr: 0.0100
# Epoch 6/200
# 90/90 [==============================] - 13s 134ms/step - loss: 1.2878 - sparse_categorical_accuracy: 0.6375 - sparse_categorical_crossentropy: 1.2878 - val_loss: 1.2772 - val_sparse_categorical_accuracy: 0.6340 - val_sparse_categorical_crossentropy: 1.2772 - lr: 0.0100
# Epoch 7/200
# 90/90 [==============================] - 13s 137ms/step - loss: 1.2413 - sparse_categorical_accuracy: 0.6446 - sparse_categorical_crossentropy: 1.2413 - val_loss: 1.2462 - val_sparse_categorical_accuracy: 0.6446 - val_sparse_categorical_crossentropy: 1.2462 - lr: 0.0100
# Epoch 8/200
# 90/90 [==============================] - 13s 136ms/step - loss: 1.1804 - sparse_categorical_accuracy: 0.6490 - sparse_categorical_crossentropy: 1.1804 - val_loss: 1.1802 - val_sparse_categorical_accuracy: 0.6505 - val_sparse_categorical_crossentropy: 1.1802 - lr: 0.0100
# Epoch 9/200
# 90/90 [==============================] - 13s 137ms/step - loss: 1.1418 - sparse_categorical_accuracy: 0.6574 - sparse_categorical_crossentropy: 1.1418 - val_loss: 1.2927 - val_sparse_categorical_accuracy: 0.6515 - val_sparse_categorical_crossentropy: 1.2927 - lr: 0.0100
# Epoch 10/200
# 90/90 [==============================] - 13s 137ms/step - loss: 1.1409 - sparse_categorical_accuracy: 0.6553 - sparse_categorical_crossentropy: 1.1409 - val_loss: 1.1536 - val_sparse_categorical_accuracy: 0.6582 - val_sparse_categorical_crossentropy: 1.1536 - lr: 0.0100
# Epoch 11/200
# 90/90 [==============================] - 13s 136ms/step - loss: 1.1117 - sparse_categorical_accuracy: 0.6620 - sparse_categorical_crossentropy: 1.1117 - val_loss: 1.0907 - val_sparse_categorical_accuracy: 0.6587 - val_sparse_categorical_crossentropy: 1.0907 - lr: 0.0100
# Epoch 12/200
# 90/90 [==============================] - 13s 136ms/step - loss: 1.1069 - sparse_categorical_accuracy: 0.6611 - sparse_categorical_crossentropy: 1.1069 - val_loss: 1.1539 - val_sparse_categorical_accuracy: 0.6512 - val_sparse_categorical_crossentropy: 1.1539 - lr: 0.0100
# Epoch 13/200
# 90/90 [==============================] - 13s 136ms/step - loss: 1.1005 - sparse_categorical_accuracy: 0.6625 - sparse_categorical_crossentropy: 1.1005 - val_loss: 1.0979 - val_sparse_categorical_accuracy: 0.6547 - val_sparse_categorical_crossentropy: 1.0979 - lr: 0.0100
# Epoch 14/200
# 89/90 [============================>.] - ETA: 0s - loss: 1.0724 - sparse_categorical_accuracy: 0.6696 - sparse_categorical_crossentropy: 1.0724
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 90/90 [==============================] - 13s 136ms/step - loss: 1.0725 - sparse_categorical_accuracy: 0.6696 - sparse_categorical_crossentropy: 1.0725 - val_loss: 1.1275 - val_sparse_categorical_accuracy: 0.6562 - val_sparse_categorical_crossentropy: 1.1275 - lr: 0.0100
# Epoch 15/200
# 90/90 [==============================] - 13s 137ms/step - loss: 1.0373 - sparse_categorical_accuracy: 0.6753 - sparse_categorical_crossentropy: 1.0373 - val_loss: 1.0400 - val_sparse_categorical_accuracy: 0.6637 - val_sparse_categorical_crossentropy: 1.0400 - lr: 0.0050
# Epoch 16/200
# 90/90 [==============================] - 13s 135ms/step - loss: 0.9983 - sparse_categorical_accuracy: 0.6819 - sparse_categorical_crossentropy: 0.9983 - val_loss: 1.0124 - val_sparse_categorical_accuracy: 0.6733 - val_sparse_categorical_crossentropy: 1.0124 - lr: 0.0050
# Epoch 17/200
# 90/90 [==============================] - 13s 135ms/step - loss: 0.9828 - sparse_categorical_accuracy: 0.6812 - sparse_categorical_crossentropy: 0.9828 - val_loss: 0.9782 - val_sparse_categorical_accuracy: 0.6737 - val_sparse_categorical_crossentropy: 0.9782 - lr: 0.0050
# Epoch 18/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.9519 - sparse_categorical_accuracy: 0.6902 - sparse_categorical_crossentropy: 0.9519 - val_loss: 0.9699 - val_sparse_categorical_accuracy: 0.6734 - val_sparse_categorical_crossentropy: 0.9699 - lr: 0.0050
# Epoch 19/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.9428 - sparse_categorical_accuracy: 0.6919 - sparse_categorical_crossentropy: 0.9428 - val_loss: 0.9487 - val_sparse_categorical_accuracy: 0.6771 - val_sparse_categorical_crossentropy: 0.9487 - lr: 0.0050
# Epoch 20/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.9124 - sparse_categorical_accuracy: 0.6967 - sparse_categorical_crossentropy: 0.9124 - val_loss: 0.9254 - val_sparse_categorical_accuracy: 0.6845 - val_sparse_categorical_crossentropy: 0.9254 - lr: 0.0050
# Epoch 21/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.8960 - sparse_categorical_accuracy: 0.6997 - sparse_categorical_crossentropy: 0.8960 - val_loss: 0.9093 - val_sparse_categorical_accuracy: 0.6889 - val_sparse_categorical_crossentropy: 0.9093 - lr: 0.0050
# Epoch 22/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.8849 - sparse_categorical_accuracy: 0.7052 - sparse_categorical_crossentropy: 0.8849 - val_loss: 0.8988 - val_sparse_categorical_accuracy: 0.7031 - val_sparse_categorical_crossentropy: 0.8988 - lr: 0.0050
# Epoch 23/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.8594 - sparse_categorical_accuracy: 0.7098 - sparse_categorical_crossentropy: 0.8594 - val_loss: 0.8921 - val_sparse_categorical_accuracy: 0.7092 - val_sparse_categorical_crossentropy: 0.8921 - lr: 0.0050
# Epoch 24/200
# 90/90 [==============================] - 13s 135ms/step - loss: 0.8666 - sparse_categorical_accuracy: 0.7092 - sparse_categorical_crossentropy: 0.8666 - val_loss: 0.8301 - val_sparse_categorical_accuracy: 0.7090 - val_sparse_categorical_crossentropy: 0.8301 - lr: 0.0050
# Epoch 25/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.8326 - sparse_categorical_accuracy: 0.7171 - sparse_categorical_crossentropy: 0.8326 - val_loss: 0.8400 - val_sparse_categorical_accuracy: 0.7155 - val_sparse_categorical_crossentropy: 0.8400 - lr: 0.0050
# Epoch 26/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.8283 - sparse_categorical_accuracy: 0.7218 - sparse_categorical_crossentropy: 0.8283 - val_loss: 0.8404 - val_sparse_categorical_accuracy: 0.7141 - val_sparse_categorical_crossentropy: 0.8404 - lr: 0.0050
# Epoch 27/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.8124 - sparse_categorical_accuracy: 0.7236 - sparse_categorical_crossentropy: 0.8124 - val_loss: 0.8147 - val_sparse_categorical_accuracy: 0.7236 - val_sparse_categorical_crossentropy: 0.8147 - lr: 0.0050
# Epoch 28/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.8008 - sparse_categorical_accuracy: 0.7259 - sparse_categorical_crossentropy: 0.8008 - val_loss: 0.8362 - val_sparse_categorical_accuracy: 0.7132 - val_sparse_categorical_crossentropy: 0.8362 - lr: 0.0050
# Epoch 29/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.8158 - sparse_categorical_accuracy: 0.7227 - sparse_categorical_crossentropy: 0.8158 - val_loss: 0.8178 - val_sparse_categorical_accuracy: 0.7124 - val_sparse_categorical_crossentropy: 0.8178 - lr: 0.0050
# Epoch 30/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.7931 - sparse_categorical_accuracy: 0.7275 - sparse_categorical_crossentropy: 0.7931
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 90/90 [==============================] - 13s 138ms/step - loss: 0.7932 - sparse_categorical_accuracy: 0.7274 - sparse_categorical_crossentropy: 0.7932 - val_loss: 0.8239 - val_sparse_categorical_accuracy: 0.7173 - val_sparse_categorical_crossentropy: 0.8239 - lr: 0.0050
# Epoch 31/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.7577 - sparse_categorical_accuracy: 0.7426 - sparse_categorical_crossentropy: 0.7577 - val_loss: 0.7637 - val_sparse_categorical_accuracy: 0.7308 - val_sparse_categorical_crossentropy: 0.7637 - lr: 0.0025
# Epoch 32/200
# 90/90 [==============================] - 14s 139ms/step - loss: 0.7265 - sparse_categorical_accuracy: 0.7558 - sparse_categorical_crossentropy: 0.7265 - val_loss: 0.7556 - val_sparse_categorical_accuracy: 0.7405 - val_sparse_categorical_crossentropy: 0.7556 - lr: 0.0025
# Epoch 33/200
# 90/90 [==============================] - 14s 139ms/step - loss: 0.7242 - sparse_categorical_accuracy: 0.7563 - sparse_categorical_crossentropy: 0.7242 - val_loss: 0.7458 - val_sparse_categorical_accuracy: 0.7483 - val_sparse_categorical_crossentropy: 0.7458 - lr: 0.0025
# Epoch 34/200
# 90/90 [==============================] - 13s 139ms/step - loss: 0.7144 - sparse_categorical_accuracy: 0.7604 - sparse_categorical_crossentropy: 0.7144 - val_loss: 0.7252 - val_sparse_categorical_accuracy: 0.7537 - val_sparse_categorical_crossentropy: 0.7252 - lr: 0.0025
# Epoch 35/200
# 90/90 [==============================] - 13s 138ms/step - loss: 0.6984 - sparse_categorical_accuracy: 0.7665 - sparse_categorical_crossentropy: 0.6984 - val_loss: 0.7453 - val_sparse_categorical_accuracy: 0.7563 - val_sparse_categorical_crossentropy: 0.7453 - lr: 0.0025
# Epoch 36/200
# 90/90 [==============================] - 13s 138ms/step - loss: 0.7031 - sparse_categorical_accuracy: 0.7638 - sparse_categorical_crossentropy: 0.7031 - val_loss: 0.7105 - val_sparse_categorical_accuracy: 0.7617 - val_sparse_categorical_crossentropy: 0.7105 - lr: 0.0025
# Epoch 37/200
# 90/90 [==============================] - 13s 139ms/step - loss: 0.6915 - sparse_categorical_accuracy: 0.7714 - sparse_categorical_crossentropy: 0.6915 - val_loss: 0.7005 - val_sparse_categorical_accuracy: 0.7686 - val_sparse_categorical_crossentropy: 0.7005 - lr: 0.0025
# Epoch 38/200
# 90/90 [==============================] - 13s 138ms/step - loss: 0.6748 - sparse_categorical_accuracy: 0.7807 - sparse_categorical_crossentropy: 0.6748 - val_loss: 0.6872 - val_sparse_categorical_accuracy: 0.7749 - val_sparse_categorical_crossentropy: 0.6872 - lr: 0.0025
# Epoch 39/200
# 90/90 [==============================] - 13s 138ms/step - loss: 0.6620 - sparse_categorical_accuracy: 0.7835 - sparse_categorical_crossentropy: 0.6620 - val_loss: 0.7198 - val_sparse_categorical_accuracy: 0.7520 - val_sparse_categorical_crossentropy: 0.7198 - lr: 0.0025
# Epoch 40/200
# 90/90 [==============================] - 13s 139ms/step - loss: 0.6797 - sparse_categorical_accuracy: 0.7741 - sparse_categorical_crossentropy: 0.6797 - val_loss: 0.6727 - val_sparse_categorical_accuracy: 0.7761 - val_sparse_categorical_crossentropy: 0.6727 - lr: 0.0025
# Epoch 41/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.6516 - sparse_categorical_accuracy: 0.7858 - sparse_categorical_crossentropy: 0.6516 - val_loss: 0.6678 - val_sparse_categorical_accuracy: 0.7763 - val_sparse_categorical_crossentropy: 0.6678 - lr: 0.0025
# Epoch 42/200
# 90/90 [==============================] - 13s 138ms/step - loss: 0.6486 - sparse_categorical_accuracy: 0.7858 - sparse_categorical_crossentropy: 0.6486 - val_loss: 0.6669 - val_sparse_categorical_accuracy: 0.7789 - val_sparse_categorical_crossentropy: 0.6669 - lr: 0.0025
# Epoch 43/200
# 90/90 [==============================] - 13s 138ms/step - loss: 0.6420 - sparse_categorical_accuracy: 0.7848 - sparse_categorical_crossentropy: 0.6420 - val_loss: 0.6835 - val_sparse_categorical_accuracy: 0.7668 - val_sparse_categorical_crossentropy: 0.6835 - lr: 0.0025
# Epoch 44/200
# 90/90 [==============================] - 14s 139ms/step - loss: 0.6338 - sparse_categorical_accuracy: 0.7892 - sparse_categorical_crossentropy: 0.6338 - val_loss: 0.6437 - val_sparse_categorical_accuracy: 0.7861 - val_sparse_categorical_crossentropy: 0.6437 - lr: 0.0025
# Epoch 45/200
# 90/90 [==============================] - 14s 140ms/step - loss: 0.6314 - sparse_categorical_accuracy: 0.7920 - sparse_categorical_crossentropy: 0.6314 - val_loss: 0.6598 - val_sparse_categorical_accuracy: 0.7864 - val_sparse_categorical_crossentropy: 0.6598 - lr: 0.0025
# Epoch 46/200
# 90/90 [==============================] - 14s 140ms/step - loss: 0.6246 - sparse_categorical_accuracy: 0.7927 - sparse_categorical_crossentropy: 0.6246 - val_loss: 0.6355 - val_sparse_categorical_accuracy: 0.7854 - val_sparse_categorical_crossentropy: 0.6355 - lr: 0.0025
# Epoch 47/200
# 90/90 [==============================] - 14s 141ms/step - loss: 0.6212 - sparse_categorical_accuracy: 0.7953 - sparse_categorical_crossentropy: 0.6212 - val_loss: 0.6481 - val_sparse_categorical_accuracy: 0.7827 - val_sparse_categorical_crossentropy: 0.6481 - lr: 0.0025
# Epoch 48/200
# 90/90 [==============================] - 14s 139ms/step - loss: 0.6272 - sparse_categorical_accuracy: 0.7924 - sparse_categorical_crossentropy: 0.6272 - val_loss: 0.6382 - val_sparse_categorical_accuracy: 0.7909 - val_sparse_categorical_crossentropy: 0.6382 - lr: 0.0025
# Epoch 49/200
# 90/90 [==============================] - 14s 140ms/step - loss: 0.5989 - sparse_categorical_accuracy: 0.8034 - sparse_categorical_crossentropy: 0.5989 - val_loss: 0.6184 - val_sparse_categorical_accuracy: 0.7920 - val_sparse_categorical_crossentropy: 0.6184 - lr: 0.0025
# Epoch 50/200
# 90/90 [==============================] - 14s 141ms/step - loss: 0.5925 - sparse_categorical_accuracy: 0.8038 - sparse_categorical_crossentropy: 0.5925 - val_loss: 0.6267 - val_sparse_categorical_accuracy: 0.7943 - val_sparse_categorical_crossentropy: 0.6267 - lr: 0.0025
# Epoch 51/200
# 90/90 [==============================] - 14s 141ms/step - loss: 0.5920 - sparse_categorical_accuracy: 0.8052 - sparse_categorical_crossentropy: 0.5920 - val_loss: 0.6070 - val_sparse_categorical_accuracy: 0.8059 - val_sparse_categorical_crossentropy: 0.6070 - lr: 0.0025
# Epoch 52/200
# 90/90 [==============================] - 14s 140ms/step - loss: 0.5837 - sparse_categorical_accuracy: 0.8108 - sparse_categorical_crossentropy: 0.5837 - val_loss: 0.6290 - val_sparse_categorical_accuracy: 0.8015 - val_sparse_categorical_crossentropy: 0.6290 - lr: 0.0025
# Epoch 53/200
# 90/90 [==============================] - 14s 140ms/step - loss: 0.5863 - sparse_categorical_accuracy: 0.8079 - sparse_categorical_crossentropy: 0.5863 - val_loss: 0.6182 - val_sparse_categorical_accuracy: 0.8029 - val_sparse_categorical_crossentropy: 0.6182 - lr: 0.0025
# Epoch 54/200
# 90/90 [==============================] - 14s 139ms/step - loss: 0.5823 - sparse_categorical_accuracy: 0.8097 - sparse_categorical_crossentropy: 0.5823 - val_loss: 0.5914 - val_sparse_categorical_accuracy: 0.8092 - val_sparse_categorical_crossentropy: 0.5914 - lr: 0.0025
# Epoch 55/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.5822 - sparse_categorical_accuracy: 0.8091 - sparse_categorical_crossentropy: 0.5822 - val_loss: 0.6073 - val_sparse_categorical_accuracy: 0.7961 - val_sparse_categorical_crossentropy: 0.6073 - lr: 0.0025
# Epoch 56/200
# 90/90 [==============================] - 13s 134ms/step - loss: 0.5940 - sparse_categorical_accuracy: 0.8052 - sparse_categorical_crossentropy: 0.5940 - val_loss: 0.5915 - val_sparse_categorical_accuracy: 0.8045 - val_sparse_categorical_crossentropy: 0.5915 - lr: 0.0025
# Epoch 57/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.5691 - sparse_categorical_accuracy: 0.8141 - sparse_categorical_crossentropy: 0.5691
# Epoch 57: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 90/90 [==============================] - 13s 133ms/step - loss: 0.5691 - sparse_categorical_accuracy: 0.8141 - sparse_categorical_crossentropy: 0.5691 - val_loss: 0.5951 - val_sparse_categorical_accuracy: 0.7941 - val_sparse_categorical_crossentropy: 0.5951 - lr: 0.0025
# Epoch 58/200
# 90/90 [==============================] - 13s 133ms/step - loss: 0.5480 - sparse_categorical_accuracy: 0.8223 - sparse_categorical_crossentropy: 0.5480 - val_loss: 0.5699 - val_sparse_categorical_accuracy: 0.8141 - val_sparse_categorical_crossentropy: 0.5699 - lr: 0.0012
# Epoch 59/200
# 90/90 [==============================] - 13s 133ms/step - loss: 0.5359 - sparse_categorical_accuracy: 0.8264 - sparse_categorical_crossentropy: 0.5359 - val_loss: 0.5767 - val_sparse_categorical_accuracy: 0.8128 - val_sparse_categorical_crossentropy: 0.5767 - lr: 0.0012
# Epoch 60/200
# 90/90 [==============================] - 13s 135ms/step - loss: 0.5433 - sparse_categorical_accuracy: 0.8243 - sparse_categorical_crossentropy: 0.5433 - val_loss: 0.5650 - val_sparse_categorical_accuracy: 0.8167 - val_sparse_categorical_crossentropy: 0.5650 - lr: 0.0012
# Epoch 61/200
# 90/90 [==============================] - 13s 134ms/step - loss: 0.5298 - sparse_categorical_accuracy: 0.8257 - sparse_categorical_crossentropy: 0.5298 - val_loss: 0.5687 - val_sparse_categorical_accuracy: 0.8127 - val_sparse_categorical_crossentropy: 0.5687 - lr: 0.0012
# Epoch 62/200
# 90/90 [==============================] - 13s 135ms/step - loss: 0.5261 - sparse_categorical_accuracy: 0.8283 - sparse_categorical_crossentropy: 0.5261 - val_loss: 0.5601 - val_sparse_categorical_accuracy: 0.8184 - val_sparse_categorical_crossentropy: 0.5601 - lr: 0.0012
# Epoch 63/200
# 90/90 [==============================] - 13s 138ms/step - loss: 0.5174 - sparse_categorical_accuracy: 0.8312 - sparse_categorical_crossentropy: 0.5174 - val_loss: 0.5605 - val_sparse_categorical_accuracy: 0.8158 - val_sparse_categorical_crossentropy: 0.5605 - lr: 0.0012
# Epoch 64/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.5205 - sparse_categorical_accuracy: 0.8294 - sparse_categorical_crossentropy: 0.5205 - val_loss: 0.5559 - val_sparse_categorical_accuracy: 0.8185 - val_sparse_categorical_crossentropy: 0.5559 - lr: 0.0012
# Epoch 65/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.5200 - sparse_categorical_accuracy: 0.8333 - sparse_categorical_crossentropy: 0.5200 - val_loss: 0.5579 - val_sparse_categorical_accuracy: 0.8224 - val_sparse_categorical_crossentropy: 0.5579 - lr: 0.0012
# Epoch 66/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.5121 - sparse_categorical_accuracy: 0.8383 - sparse_categorical_crossentropy: 0.5121 - val_loss: 0.5546 - val_sparse_categorical_accuracy: 0.8205 - val_sparse_categorical_crossentropy: 0.5546 - lr: 0.0012
# Epoch 67/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.5818 - sparse_categorical_accuracy: 0.8084 - sparse_categorical_crossentropy: 0.5818 - val_loss: 0.5632 - val_sparse_categorical_accuracy: 0.8184 - val_sparse_categorical_crossentropy: 0.5632 - lr: 0.0012
# Epoch 68/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.5167 - sparse_categorical_accuracy: 0.8371 - sparse_categorical_crossentropy: 0.5167
# Epoch 68: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 90/90 [==============================] - 14s 139ms/step - loss: 0.5166 - sparse_categorical_accuracy: 0.8372 - sparse_categorical_crossentropy: 0.5166 - val_loss: 0.5581 - val_sparse_categorical_accuracy: 0.8222 - val_sparse_categorical_crossentropy: 0.5581 - lr: 0.0012
# Epoch 69/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.5001 - sparse_categorical_accuracy: 0.8435 - sparse_categorical_crossentropy: 0.5001 - val_loss: 0.5468 - val_sparse_categorical_accuracy: 0.8290 - val_sparse_categorical_crossentropy: 0.5468 - lr: 6.2500e-04
# Epoch 70/200
# 90/90 [==============================] - 13s 135ms/step - loss: 0.4971 - sparse_categorical_accuracy: 0.8442 - sparse_categorical_crossentropy: 0.4971 - val_loss: 0.5390 - val_sparse_categorical_accuracy: 0.8308 - val_sparse_categorical_crossentropy: 0.5390 - lr: 6.2500e-04
# Epoch 71/200
# 90/90 [==============================] - 13s 135ms/step - loss: 0.4851 - sparse_categorical_accuracy: 0.8492 - sparse_categorical_crossentropy: 0.4851 - val_loss: 0.5332 - val_sparse_categorical_accuracy: 0.8311 - val_sparse_categorical_crossentropy: 0.5332 - lr: 6.2500e-04
# Epoch 72/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.4800 - sparse_categorical_accuracy: 0.8513 - sparse_categorical_crossentropy: 0.4800 - val_loss: 0.5374 - val_sparse_categorical_accuracy: 0.8325 - val_sparse_categorical_crossentropy: 0.5374 - lr: 6.2500e-04
# Epoch 73/200
# 90/90 [==============================] - 14s 139ms/step - loss: 0.4763 - sparse_categorical_accuracy: 0.8532 - sparse_categorical_crossentropy: 0.4763 - val_loss: 0.5239 - val_sparse_categorical_accuracy: 0.8376 - val_sparse_categorical_crossentropy: 0.5239 - lr: 6.2500e-04
# Epoch 74/200
# 90/90 [==============================] - 13s 134ms/step - loss: 0.4718 - sparse_categorical_accuracy: 0.8549 - sparse_categorical_crossentropy: 0.4718 - val_loss: 0.5189 - val_sparse_categorical_accuracy: 0.8377 - val_sparse_categorical_crossentropy: 0.5189 - lr: 6.2500e-04
# Epoch 75/200
# 90/90 [==============================] - 13s 135ms/step - loss: 0.4684 - sparse_categorical_accuracy: 0.8556 - sparse_categorical_crossentropy: 0.4684 - val_loss: 0.5191 - val_sparse_categorical_accuracy: 0.8377 - val_sparse_categorical_crossentropy: 0.5191 - lr: 6.2500e-04
# Epoch 76/200
# 90/90 [==============================] - 13s 135ms/step - loss: 0.4639 - sparse_categorical_accuracy: 0.8579 - sparse_categorical_crossentropy: 0.4639 - val_loss: 0.5214 - val_sparse_categorical_accuracy: 0.8419 - val_sparse_categorical_crossentropy: 0.5214 - lr: 6.2500e-04
# Epoch 77/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.4614 - sparse_categorical_accuracy: 0.8592 - sparse_categorical_crossentropy: 0.4614 - val_loss: 0.5140 - val_sparse_categorical_accuracy: 0.8399 - val_sparse_categorical_crossentropy: 0.5140 - lr: 6.2500e-04
# Epoch 78/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.4606 - sparse_categorical_accuracy: 0.8588 - sparse_categorical_crossentropy: 0.4606 - val_loss: 0.5096 - val_sparse_categorical_accuracy: 0.8449 - val_sparse_categorical_crossentropy: 0.5096 - lr: 6.2500e-04
# Epoch 79/200
# 90/90 [==============================] - 13s 135ms/step - loss: 0.4567 - sparse_categorical_accuracy: 0.8604 - sparse_categorical_crossentropy: 0.4567 - val_loss: 0.5106 - val_sparse_categorical_accuracy: 0.8428 - val_sparse_categorical_crossentropy: 0.5106 - lr: 6.2500e-04
# Epoch 80/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.4553 - sparse_categorical_accuracy: 0.8596 - sparse_categorical_crossentropy: 0.4553 - val_loss: 0.5039 - val_sparse_categorical_accuracy: 0.8449 - val_sparse_categorical_crossentropy: 0.5039 - lr: 6.2500e-04
# Epoch 81/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.4488 - sparse_categorical_accuracy: 0.8628 - sparse_categorical_crossentropy: 0.4488 - val_loss: 0.5082 - val_sparse_categorical_accuracy: 0.8451 - val_sparse_categorical_crossentropy: 0.5082 - lr: 6.2500e-04
# Epoch 82/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.4485 - sparse_categorical_accuracy: 0.8630 - sparse_categorical_crossentropy: 0.4485 - val_loss: 0.5052 - val_sparse_categorical_accuracy: 0.8429 - val_sparse_categorical_crossentropy: 0.5052 - lr: 6.2500e-04
# Epoch 83/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.4446 - sparse_categorical_accuracy: 0.8638 - sparse_categorical_crossentropy: 0.4446 - val_loss: 0.5017 - val_sparse_categorical_accuracy: 0.8431 - val_sparse_categorical_crossentropy: 0.5017 - lr: 6.2500e-04
# Epoch 84/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.4448 - sparse_categorical_accuracy: 0.8639 - sparse_categorical_crossentropy: 0.4448
# Epoch 84: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 90/90 [==============================] - 13s 135ms/step - loss: 0.4448 - sparse_categorical_accuracy: 0.8639 - sparse_categorical_crossentropy: 0.4448 - val_loss: 0.5007 - val_sparse_categorical_accuracy: 0.8445 - val_sparse_categorical_crossentropy: 0.5007 - lr: 6.2500e-04
# Epoch 85/200
# 90/90 [==============================] - 13s 134ms/step - loss: 0.4378 - sparse_categorical_accuracy: 0.8669 - sparse_categorical_crossentropy: 0.4378 - val_loss: 0.5019 - val_sparse_categorical_accuracy: 0.8425 - val_sparse_categorical_crossentropy: 0.5019 - lr: 3.1250e-04
# Epoch 86/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.4348 - sparse_categorical_accuracy: 0.8680 - sparse_categorical_crossentropy: 0.4348 - val_loss: 0.4994 - val_sparse_categorical_accuracy: 0.8462 - val_sparse_categorical_crossentropy: 0.4994 - lr: 3.1250e-04
# Epoch 87/200
# 90/90 [==============================] - 13s 137ms/step - loss: 0.4319 - sparse_categorical_accuracy: 0.8688 - sparse_categorical_crossentropy: 0.4319 - val_loss: 0.5026 - val_sparse_categorical_accuracy: 0.8460 - val_sparse_categorical_crossentropy: 0.5026 - lr: 3.1250e-04
# Epoch 88/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.4299 - sparse_categorical_accuracy: 0.8707 - sparse_categorical_crossentropy: 0.4299 - val_loss: 0.4965 - val_sparse_categorical_accuracy: 0.8474 - val_sparse_categorical_crossentropy: 0.4965 - lr: 3.1250e-04
# Epoch 89/200
# 90/90 [==============================] - 13s 135ms/step - loss: 0.4269 - sparse_categorical_accuracy: 0.8707 - sparse_categorical_crossentropy: 0.4269 - val_loss: 0.4986 - val_sparse_categorical_accuracy: 0.8471 - val_sparse_categorical_crossentropy: 0.4986 - lr: 3.1250e-04
# Epoch 90/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.4270 - sparse_categorical_accuracy: 0.8711 - sparse_categorical_crossentropy: 0.4270 - val_loss: 0.4933 - val_sparse_categorical_accuracy: 0.8469 - val_sparse_categorical_crossentropy: 0.4933 - lr: 3.1250e-04
# Epoch 91/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.4243 - sparse_categorical_accuracy: 0.8717 - sparse_categorical_crossentropy: 0.4243
# Epoch 91: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 90/90 [==============================] - 13s 137ms/step - loss: 0.4244 - sparse_categorical_accuracy: 0.8716 - sparse_categorical_crossentropy: 0.4244 - val_loss: 0.4965 - val_sparse_categorical_accuracy: 0.8458 - val_sparse_categorical_crossentropy: 0.4965 - lr: 3.1250e-04
# Epoch 92/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.4229 - sparse_categorical_accuracy: 0.8716 - sparse_categorical_crossentropy: 0.4229 - val_loss: 0.4915 - val_sparse_categorical_accuracy: 0.8488 - val_sparse_categorical_crossentropy: 0.4915 - lr: 1.5625e-04
# Epoch 93/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.4203 - sparse_categorical_accuracy: 0.8730 - sparse_categorical_crossentropy: 0.4203 - val_loss: 0.4937 - val_sparse_categorical_accuracy: 0.8481 - val_sparse_categorical_crossentropy: 0.4937 - lr: 1.5625e-04
# Epoch 94/200
# 90/90 [==============================] - 13s 134ms/step - loss: 0.4185 - sparse_categorical_accuracy: 0.8737 - sparse_categorical_crossentropy: 0.4185 - val_loss: 0.4934 - val_sparse_categorical_accuracy: 0.8485 - val_sparse_categorical_crossentropy: 0.4934 - lr: 1.5625e-04
# Epoch 95/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.4188 - sparse_categorical_accuracy: 0.8737 - sparse_categorical_crossentropy: 0.4188
# Epoch 95: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 90/90 [==============================] - 13s 134ms/step - loss: 0.4188 - sparse_categorical_accuracy: 0.8737 - sparse_categorical_crossentropy: 0.4188 - val_loss: 0.4915 - val_sparse_categorical_accuracy: 0.8486 - val_sparse_categorical_crossentropy: 0.4915 - lr: 1.5625e-04
# Epoch 96/200
# 90/90 [==============================] - 13s 134ms/step - loss: 0.4165 - sparse_categorical_accuracy: 0.8747 - sparse_categorical_crossentropy: 0.4165 - val_loss: 0.4899 - val_sparse_categorical_accuracy: 0.8497 - val_sparse_categorical_crossentropy: 0.4899 - lr: 7.8125e-05
# Epoch 97/200
# 90/90 [==============================] - 13s 135ms/step - loss: 0.4162 - sparse_categorical_accuracy: 0.8746 - sparse_categorical_crossentropy: 0.4162 - val_loss: 0.4922 - val_sparse_categorical_accuracy: 0.8506 - val_sparse_categorical_crossentropy: 0.4922 - lr: 7.8125e-05
# Epoch 98/200
# 90/90 [==============================] - 13s 135ms/step - loss: 0.4156 - sparse_categorical_accuracy: 0.8749 - sparse_categorical_crossentropy: 0.4156 - val_loss: 0.4902 - val_sparse_categorical_accuracy: 0.8508 - val_sparse_categorical_crossentropy: 0.4902 - lr: 7.8125e-05
# Epoch 99/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.4142 - sparse_categorical_accuracy: 0.8754 - sparse_categorical_crossentropy: 0.4142 - val_loss: 0.4897 - val_sparse_categorical_accuracy: 0.8500 - val_sparse_categorical_crossentropy: 0.4897 - lr: 7.8125e-05
# Epoch 100/200
# 90/90 [==============================] - 14s 140ms/step - loss: 0.4144 - sparse_categorical_accuracy: 0.8748 - sparse_categorical_crossentropy: 0.4144 - val_loss: 0.4886 - val_sparse_categorical_accuracy: 0.8508 - val_sparse_categorical_crossentropy: 0.4886 - lr: 7.8125e-05
# Epoch 101/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.4139 - sparse_categorical_accuracy: 0.8754 - sparse_categorical_crossentropy: 0.4139
# Epoch 101: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 90/90 [==============================] - 13s 136ms/step - loss: 0.4140 - sparse_categorical_accuracy: 0.8754 - sparse_categorical_crossentropy: 0.4140 - val_loss: 0.4907 - val_sparse_categorical_accuracy: 0.8506 - val_sparse_categorical_crossentropy: 0.4907 - lr: 7.8125e-05
# Epoch 102/200
# 90/90 [==============================] - 13s 135ms/step - loss: 0.4133 - sparse_categorical_accuracy: 0.8750 - sparse_categorical_crossentropy: 0.4133 - val_loss: 0.4894 - val_sparse_categorical_accuracy: 0.8497 - val_sparse_categorical_crossentropy: 0.4894 - lr: 3.9062e-05
# Epoch 103/200
# 90/90 [==============================] - 13s 136ms/step - loss: 0.4126 - sparse_categorical_accuracy: 0.8759 - sparse_categorical_crossentropy: 0.4126 - val_loss: 0.4908 - val_sparse_categorical_accuracy: 0.8494 - val_sparse_categorical_crossentropy: 0.4908 - lr: 3.9062e-05
# 26/26 [==============================] - 3s 94ms/step - loss: 0.5153 - sparse_categorical_accuracy: 0.8431 - sparse_categorical_crossentropy: 0.5153
# 26/26 [==============================] - 4s 90ms/step
# Epoch 1/200
# 90/90 [==============================] - 17s 145ms/step - loss: 1.5441 - sparse_categorical_accuracy: 0.6235 - sparse_categorical_crossentropy: 1.5441 - val_loss: 1.5028 - val_sparse_categorical_accuracy: 0.6301 - val_sparse_categorical_crossentropy: 1.5028 - lr: 0.0100
# Epoch 2/200
# 90/90 [==============================] - 14s 144ms/step - loss: 1.4844 - sparse_categorical_accuracy: 0.6305 - sparse_categorical_crossentropy: 1.4844 - val_loss: 1.4637 - val_sparse_categorical_accuracy: 0.6321 - val_sparse_categorical_crossentropy: 1.4637 - lr: 0.0100
# Epoch 3/200
# 90/90 [==============================] - 14s 146ms/step - loss: 1.4339 - sparse_categorical_accuracy: 0.6326 - sparse_categorical_crossentropy: 1.4339 - val_loss: 1.4263 - val_sparse_categorical_accuracy: 0.6326 - val_sparse_categorical_crossentropy: 1.4263 - lr: 0.0100
# Epoch 4/200
# 90/90 [==============================] - 14s 147ms/step - loss: 1.3893 - sparse_categorical_accuracy: 0.6334 - sparse_categorical_crossentropy: 1.3893 - val_loss: 1.3606 - val_sparse_categorical_accuracy: 0.6344 - val_sparse_categorical_crossentropy: 1.3606 - lr: 0.0100
# Epoch 5/200
# 90/90 [==============================] - 14s 147ms/step - loss: 1.3549 - sparse_categorical_accuracy: 0.6329 - sparse_categorical_crossentropy: 1.3549 - val_loss: 1.3532 - val_sparse_categorical_accuracy: 0.6349 - val_sparse_categorical_crossentropy: 1.3532 - lr: 0.0100
# Epoch 6/200
# 90/90 [==============================] - 14s 148ms/step - loss: 1.3131 - sparse_categorical_accuracy: 0.6378 - sparse_categorical_crossentropy: 1.3131 - val_loss: 1.3081 - val_sparse_categorical_accuracy: 0.6337 - val_sparse_categorical_crossentropy: 1.3081 - lr: 0.0100
# Epoch 7/200
# 90/90 [==============================] - 14s 149ms/step - loss: 1.2903 - sparse_categorical_accuracy: 0.6400 - sparse_categorical_crossentropy: 1.2903 - val_loss: 1.2981 - val_sparse_categorical_accuracy: 0.6340 - val_sparse_categorical_crossentropy: 1.2981 - lr: 0.0100
# Epoch 8/200
# 90/90 [==============================] - 14s 148ms/step - loss: 1.2724 - sparse_categorical_accuracy: 0.6415 - sparse_categorical_crossentropy: 1.2724 - val_loss: 1.2688 - val_sparse_categorical_accuracy: 0.6409 - val_sparse_categorical_crossentropy: 1.2688 - lr: 0.0100
# Epoch 9/200
# 90/90 [==============================] - 14s 148ms/step - loss: 1.2424 - sparse_categorical_accuracy: 0.6461 - sparse_categorical_crossentropy: 1.2424 - val_loss: 1.2568 - val_sparse_categorical_accuracy: 0.6442 - val_sparse_categorical_crossentropy: 1.2568 - lr: 0.0100
# Epoch 10/200
# 90/90 [==============================] - 14s 147ms/step - loss: 1.2292 - sparse_categorical_accuracy: 0.6450 - sparse_categorical_crossentropy: 1.2292 - val_loss: 1.2412 - val_sparse_categorical_accuracy: 0.6436 - val_sparse_categorical_crossentropy: 1.2412 - lr: 0.0100
# Epoch 11/200
# 90/90 [==============================] - 14s 149ms/step - loss: 1.2156 - sparse_categorical_accuracy: 0.6455 - sparse_categorical_crossentropy: 1.2156 - val_loss: 1.2063 - val_sparse_categorical_accuracy: 0.6459 - val_sparse_categorical_crossentropy: 1.2063 - lr: 0.0100
# Epoch 12/200
# 90/90 [==============================] - 14s 149ms/step - loss: 1.1838 - sparse_categorical_accuracy: 0.6504 - sparse_categorical_crossentropy: 1.1838 - val_loss: 1.1922 - val_sparse_categorical_accuracy: 0.6550 - val_sparse_categorical_crossentropy: 1.1922 - lr: 0.0100
# Epoch 13/200
# 90/90 [==============================] - 14s 148ms/step - loss: 1.1756 - sparse_categorical_accuracy: 0.6534 - sparse_categorical_crossentropy: 1.1756 - val_loss: 1.1463 - val_sparse_categorical_accuracy: 0.6585 - val_sparse_categorical_crossentropy: 1.1463 - lr: 0.0100
# Epoch 14/200
# 90/90 [==============================] - 14s 147ms/step - loss: 1.1539 - sparse_categorical_accuracy: 0.6555 - sparse_categorical_crossentropy: 1.1539 - val_loss: 1.1143 - val_sparse_categorical_accuracy: 0.6591 - val_sparse_categorical_crossentropy: 1.1143 - lr: 0.0100
# Epoch 15/200
# 90/90 [==============================] - 14s 148ms/step - loss: 1.1042 - sparse_categorical_accuracy: 0.6587 - sparse_categorical_crossentropy: 1.1042 - val_loss: 1.1136 - val_sparse_categorical_accuracy: 0.6568 - val_sparse_categorical_crossentropy: 1.1136 - lr: 0.0100
# Epoch 16/200
# 90/90 [==============================] - 14s 147ms/step - loss: 1.1022 - sparse_categorical_accuracy: 0.6626 - sparse_categorical_crossentropy: 1.1022 - val_loss: 1.0977 - val_sparse_categorical_accuracy: 0.6601 - val_sparse_categorical_crossentropy: 1.0977 - lr: 0.0100
# Epoch 17/200
# 90/90 [==============================] - 14s 148ms/step - loss: 1.0414 - sparse_categorical_accuracy: 0.6735 - sparse_categorical_crossentropy: 1.0414 - val_loss: 1.0064 - val_sparse_categorical_accuracy: 0.6714 - val_sparse_categorical_crossentropy: 1.0064 - lr: 0.0100
# Epoch 18/200
# 90/90 [==============================] - 14s 148ms/step - loss: 1.0113 - sparse_categorical_accuracy: 0.6811 - sparse_categorical_crossentropy: 1.0113 - val_loss: 1.0388 - val_sparse_categorical_accuracy: 0.6699 - val_sparse_categorical_crossentropy: 1.0388 - lr: 0.0100
# Epoch 19/200
# 90/90 [==============================] - 14s 147ms/step - loss: 0.9789 - sparse_categorical_accuracy: 0.6871 - sparse_categorical_crossentropy: 0.9789 - val_loss: 0.9595 - val_sparse_categorical_accuracy: 0.6934 - val_sparse_categorical_crossentropy: 0.9595 - lr: 0.0100
# Epoch 20/200
# 90/90 [==============================] - 15s 149ms/step - loss: 0.9756 - sparse_categorical_accuracy: 0.6927 - sparse_categorical_crossentropy: 0.9756 - val_loss: 0.9609 - val_sparse_categorical_accuracy: 0.6877 - val_sparse_categorical_crossentropy: 0.9609 - lr: 0.0100
# Epoch 21/200
# 90/90 [==============================] - 14s 147ms/step - loss: 0.9395 - sparse_categorical_accuracy: 0.6970 - sparse_categorical_crossentropy: 0.9395 - val_loss: 0.9200 - val_sparse_categorical_accuracy: 0.6952 - val_sparse_categorical_crossentropy: 0.9200 - lr: 0.0100
# Epoch 22/200
# 90/90 [==============================] - 14s 148ms/step - loss: 0.9140 - sparse_categorical_accuracy: 0.7058 - sparse_categorical_crossentropy: 0.9140 - val_loss: 0.8866 - val_sparse_categorical_accuracy: 0.7110 - val_sparse_categorical_crossentropy: 0.8866 - lr: 0.0100
# Epoch 23/200
# 90/90 [==============================] - 14s 148ms/step - loss: 0.9324 - sparse_categorical_accuracy: 0.7049 - sparse_categorical_crossentropy: 0.9324 - val_loss: 0.8954 - val_sparse_categorical_accuracy: 0.7083 - val_sparse_categorical_crossentropy: 0.8954 - lr: 0.0100
# Epoch 24/200
# 90/90 [==============================] - 14s 147ms/step - loss: 0.8920 - sparse_categorical_accuracy: 0.7161 - sparse_categorical_crossentropy: 0.8920 - val_loss: 0.8514 - val_sparse_categorical_accuracy: 0.7281 - val_sparse_categorical_crossentropy: 0.8514 - lr: 0.0100
# Epoch 25/200
# 90/90 [==============================] - 14s 148ms/step - loss: 0.8837 - sparse_categorical_accuracy: 0.7180 - sparse_categorical_crossentropy: 0.8837 - val_loss: 0.8960 - val_sparse_categorical_accuracy: 0.7090 - val_sparse_categorical_crossentropy: 0.8960 - lr: 0.0100
# Epoch 26/200
# 90/90 [==============================] - 14s 147ms/step - loss: 0.8764 - sparse_categorical_accuracy: 0.7210 - sparse_categorical_crossentropy: 0.8764 - val_loss: 0.8387 - val_sparse_categorical_accuracy: 0.7307 - val_sparse_categorical_crossentropy: 0.8387 - lr: 0.0100
# Epoch 27/200
# 90/90 [==============================] - 14s 147ms/step - loss: 0.8791 - sparse_categorical_accuracy: 0.7223 - sparse_categorical_crossentropy: 0.8791 - val_loss: 0.8755 - val_sparse_categorical_accuracy: 0.7179 - val_sparse_categorical_crossentropy: 0.8755 - lr: 0.0100
# Epoch 28/200
# 90/90 [==============================] - 14s 147ms/step - loss: 0.8749 - sparse_categorical_accuracy: 0.7248 - sparse_categorical_crossentropy: 0.8749 - val_loss: 0.8393 - val_sparse_categorical_accuracy: 0.7293 - val_sparse_categorical_crossentropy: 0.8393 - lr: 0.0100
# Epoch 29/200
# 90/90 [==============================] - 14s 148ms/step - loss: 0.8161 - sparse_categorical_accuracy: 0.7418 - sparse_categorical_crossentropy: 0.8161 - val_loss: 0.8210 - val_sparse_categorical_accuracy: 0.7345 - val_sparse_categorical_crossentropy: 0.8210 - lr: 0.0100
# Epoch 30/200
# 90/90 [==============================] - 14s 148ms/step - loss: 0.8636 - sparse_categorical_accuracy: 0.7211 - sparse_categorical_crossentropy: 0.8636 - val_loss: 0.8267 - val_sparse_categorical_accuracy: 0.7345 - val_sparse_categorical_crossentropy: 0.8267 - lr: 0.0100
# Epoch 31/200
# 90/90 [==============================] - 14s 148ms/step - loss: 0.8520 - sparse_categorical_accuracy: 0.7257 - sparse_categorical_crossentropy: 0.8520 - val_loss: 0.8045 - val_sparse_categorical_accuracy: 0.7431 - val_sparse_categorical_crossentropy: 0.8045 - lr: 0.0100
# Epoch 32/200
# 90/90 [==============================] - 14s 148ms/step - loss: 0.8370 - sparse_categorical_accuracy: 0.7354 - sparse_categorical_crossentropy: 0.8370 - val_loss: 0.8354 - val_sparse_categorical_accuracy: 0.7276 - val_sparse_categorical_crossentropy: 0.8354 - lr: 0.0100
# Epoch 33/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.8066 - sparse_categorical_accuracy: 0.7440 - sparse_categorical_crossentropy: 0.8066 - val_loss: 0.7758 - val_sparse_categorical_accuracy: 0.7537 - val_sparse_categorical_crossentropy: 0.7758 - lr: 0.0100
# Epoch 34/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.8062 - sparse_categorical_accuracy: 0.7430 - sparse_categorical_crossentropy: 0.8062 - val_loss: 0.8172 - val_sparse_categorical_accuracy: 0.7287 - val_sparse_categorical_crossentropy: 0.8172 - lr: 0.0100
# Epoch 35/200
# 90/90 [==============================] - 14s 150ms/step - loss: 0.8102 - sparse_categorical_accuracy: 0.7422 - sparse_categorical_crossentropy: 0.8102 - val_loss: 0.8592 - val_sparse_categorical_accuracy: 0.7236 - val_sparse_categorical_crossentropy: 0.8592 - lr: 0.0100
# Epoch 36/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.8030 - sparse_categorical_accuracy: 0.7435 - sparse_categorical_crossentropy: 0.8030
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 90/90 [==============================] - 14s 149ms/step - loss: 0.8030 - sparse_categorical_accuracy: 0.7435 - sparse_categorical_crossentropy: 0.8030 - val_loss: 0.7939 - val_sparse_categorical_accuracy: 0.7477 - val_sparse_categorical_crossentropy: 0.7939 - lr: 0.0100
# Epoch 37/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.7448 - sparse_categorical_accuracy: 0.7613 - sparse_categorical_crossentropy: 0.7448 - val_loss: 0.7335 - val_sparse_categorical_accuracy: 0.7637 - val_sparse_categorical_crossentropy: 0.7335 - lr: 0.0050
# Epoch 38/200
# 90/90 [==============================] - 15s 149ms/step - loss: 0.7247 - sparse_categorical_accuracy: 0.7655 - sparse_categorical_crossentropy: 0.7247 - val_loss: 0.7237 - val_sparse_categorical_accuracy: 0.7657 - val_sparse_categorical_crossentropy: 0.7237 - lr: 0.0050
# Epoch 39/200
# 90/90 [==============================] - 14s 149ms/step - loss: 0.7096 - sparse_categorical_accuracy: 0.7708 - sparse_categorical_crossentropy: 0.7096 - val_loss: 0.7133 - val_sparse_categorical_accuracy: 0.7726 - val_sparse_categorical_crossentropy: 0.7133 - lr: 0.0050
# Epoch 40/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.7109 - sparse_categorical_accuracy: 0.7735 - sparse_categorical_crossentropy: 0.7109 - val_loss: 0.7155 - val_sparse_categorical_accuracy: 0.7649 - val_sparse_categorical_crossentropy: 0.7155 - lr: 0.0050
# Epoch 41/200
# 90/90 [==============================] - 14s 149ms/step - loss: 0.7083 - sparse_categorical_accuracy: 0.7722 - sparse_categorical_crossentropy: 0.7083 - val_loss: 0.7123 - val_sparse_categorical_accuracy: 0.7737 - val_sparse_categorical_crossentropy: 0.7123 - lr: 0.0050
# Epoch 42/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.6959 - sparse_categorical_accuracy: 0.7780 - sparse_categorical_crossentropy: 0.6959 - val_loss: 0.7087 - val_sparse_categorical_accuracy: 0.7751 - val_sparse_categorical_crossentropy: 0.7087 - lr: 0.0050
# Epoch 43/200
# 90/90 [==============================] - 14s 149ms/step - loss: 0.6904 - sparse_categorical_accuracy: 0.7824 - sparse_categorical_crossentropy: 0.6904 - val_loss: 0.6822 - val_sparse_categorical_accuracy: 0.7880 - val_sparse_categorical_crossentropy: 0.6822 - lr: 0.0050
# Epoch 44/200
# 90/90 [==============================] - 14s 148ms/step - loss: 0.6792 - sparse_categorical_accuracy: 0.7848 - sparse_categorical_crossentropy: 0.6792 - val_loss: 0.6882 - val_sparse_categorical_accuracy: 0.7769 - val_sparse_categorical_crossentropy: 0.6882 - lr: 0.0050
# Epoch 45/200
# 90/90 [==============================] - 14s 149ms/step - loss: 0.7015 - sparse_categorical_accuracy: 0.7752 - sparse_categorical_crossentropy: 0.7015 - val_loss: 0.6771 - val_sparse_categorical_accuracy: 0.7844 - val_sparse_categorical_crossentropy: 0.6771 - lr: 0.0050
# Epoch 46/200
# 90/90 [==============================] - 14s 149ms/step - loss: 0.6804 - sparse_categorical_accuracy: 0.7845 - sparse_categorical_crossentropy: 0.6804 - val_loss: 0.6642 - val_sparse_categorical_accuracy: 0.7890 - val_sparse_categorical_crossentropy: 0.6642 - lr: 0.0050
# Epoch 47/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.6697 - sparse_categorical_accuracy: 0.7881 - sparse_categorical_crossentropy: 0.6697 - val_loss: 0.6810 - val_sparse_categorical_accuracy: 0.7764 - val_sparse_categorical_crossentropy: 0.6810 - lr: 0.0050
# Epoch 48/200
# 90/90 [==============================] - 14s 148ms/step - loss: 0.6633 - sparse_categorical_accuracy: 0.7882 - sparse_categorical_crossentropy: 0.6633 - val_loss: 0.6602 - val_sparse_categorical_accuracy: 0.7890 - val_sparse_categorical_crossentropy: 0.6602 - lr: 0.0050
# Epoch 49/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.6756 - sparse_categorical_accuracy: 0.7851 - sparse_categorical_crossentropy: 0.6756
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 90/90 [==============================] - 15s 150ms/step - loss: 0.6756 - sparse_categorical_accuracy: 0.7851 - sparse_categorical_crossentropy: 0.6756 - val_loss: 0.7298 - val_sparse_categorical_accuracy: 0.7688 - val_sparse_categorical_crossentropy: 0.7298 - lr: 0.0050
# Epoch 50/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.6827 - sparse_categorical_accuracy: 0.7795 - sparse_categorical_crossentropy: 0.6827 - val_loss: 0.6512 - val_sparse_categorical_accuracy: 0.7873 - val_sparse_categorical_crossentropy: 0.6512 - lr: 0.0025
# Epoch 51/200
# 90/90 [==============================] - 14s 149ms/step - loss: 0.6482 - sparse_categorical_accuracy: 0.7938 - sparse_categorical_crossentropy: 0.6482 - val_loss: 0.6572 - val_sparse_categorical_accuracy: 0.7895 - val_sparse_categorical_crossentropy: 0.6572 - lr: 0.0025
# Epoch 52/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.6324 - sparse_categorical_accuracy: 0.7988 - sparse_categorical_crossentropy: 0.6324 - val_loss: 0.6356 - val_sparse_categorical_accuracy: 0.7970 - val_sparse_categorical_crossentropy: 0.6356 - lr: 0.0025
# Epoch 53/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.6324 - sparse_categorical_accuracy: 0.7988 - sparse_categorical_crossentropy: 0.6324 - val_loss: 0.6367 - val_sparse_categorical_accuracy: 0.7970 - val_sparse_categorical_crossentropy: 0.6367 - lr: 0.0025
# Epoch 54/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.6243 - sparse_categorical_accuracy: 0.8030 - sparse_categorical_crossentropy: 0.6243 - val_loss: 0.6268 - val_sparse_categorical_accuracy: 0.7967 - val_sparse_categorical_crossentropy: 0.6268 - lr: 0.0025
# Epoch 55/200
# 90/90 [==============================] - 15s 151ms/step - loss: 0.6177 - sparse_categorical_accuracy: 0.8035 - sparse_categorical_crossentropy: 0.6177 - val_loss: 0.6313 - val_sparse_categorical_accuracy: 0.7981 - val_sparse_categorical_crossentropy: 0.6313 - lr: 0.0025
# Epoch 56/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.6177 - sparse_categorical_accuracy: 0.8031 - sparse_categorical_crossentropy: 0.6177 - val_loss: 0.6246 - val_sparse_categorical_accuracy: 0.8038 - val_sparse_categorical_crossentropy: 0.6246 - lr: 0.0025
# Epoch 57/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.6440 - sparse_categorical_accuracy: 0.7971 - sparse_categorical_crossentropy: 0.6440 - val_loss: 0.6567 - val_sparse_categorical_accuracy: 0.7897 - val_sparse_categorical_crossentropy: 0.6567 - lr: 0.0025
# Epoch 58/200
# ...
# Epoch 4/200
# 90/90 [==============================] - 14s 148ms/step - loss: 1.3022 - sparse_categorical_accuracy: 0.6338 - sparse_categorical_crossentropy: 1.3022 - val_loss: 1.2938 - val_sparse_categorical_accuracy: 0.6332 - val_sparse_categorical_crossentropy: 1.2938 - lr: 0.0100
# Epoch 5/200
# 90/90 [==============================] - 14s 149ms/step - loss: 1.2450 - sparse_categorical_accuracy: 0.6387 - sparse_categorical_crossentropy: 1.2450 - val_loss: 1.2645 - val_sparse_categorical_accuracy: 0.6381 - val_sparse_categorical_crossentropy: 1.2645 - lr: 0.0100
# Epoch 6/200
# 90/90 [==============================] - 15s 151ms/step - loss: 1.1835 - sparse_categorical_accuracy: 0.6419 - sparse_categorical_crossentropy: 1.1835 - val_loss: 1.1301 - val_sparse_categorical_accuracy: 0.6433 - val_sparse_categorical_crossentropy: 1.1301 - lr: 0.0100
# Epoch 7/200
# 90/90 [==============================] - 14s 148ms/step - loss: 1.1258 - sparse_categorical_accuracy: 0.6501 - sparse_categorical_crossentropy: 1.1258 - val_loss: 1.1313 - val_sparse_categorical_accuracy: 0.6512 - val_sparse_categorical_crossentropy: 1.1313 - lr: 0.0100
# Epoch 8/200
# 90/90 [==============================] - 14s 147ms/step - loss: 1.1185 - sparse_categorical_accuracy: 0.6511 - sparse_categorical_crossentropy: 1.1185 - val_loss: 1.1111 - val_sparse_categorical_accuracy: 0.6370 - val_sparse_categorical_crossentropy: 1.1111 - lr: 0.0100
# Epoch 9/200
# 90/90 [==============================] - 14s 148ms/step - loss: 1.1049 - sparse_categorical_accuracy: 0.6526 - sparse_categorical_crossentropy: 1.1049 - val_loss: 1.0194 - val_sparse_categorical_accuracy: 0.6636 - val_sparse_categorical_crossentropy: 1.0194 - lr: 0.0100
# Epoch 10/200
# 90/90 [==============================] - 14s 149ms/step - loss: 1.0425 - sparse_categorical_accuracy: 0.6638 - sparse_categorical_crossentropy: 1.0425 - val_loss: 0.9970 - val_sparse_categorical_accuracy: 0.6737 - val_sparse_categorical_crossentropy: 0.9970 - lr: 0.0100
# Epoch 11/200
# 90/90 [==============================] - 15s 149ms/step - loss: 1.0017 - sparse_categorical_accuracy: 0.6805 - sparse_categorical_crossentropy: 1.0017 - val_loss: 0.9880 - val_sparse_categorical_accuracy: 0.6739 - val_sparse_categorical_crossentropy: 0.9880 - lr: 0.0100
# Epoch 12/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.9738 - sparse_categorical_accuracy: 0.6826 - sparse_categorical_crossentropy: 0.9738 - val_loss: 0.9548 - val_sparse_categorical_accuracy: 0.6727 - val_sparse_categorical_crossentropy: 0.9548 - lr: 0.0100
# Epoch 13/200
# 90/90 [==============================] - 14s 149ms/step - loss: 0.9516 - sparse_categorical_accuracy: 0.6940 - sparse_categorical_crossentropy: 0.9516 - val_loss: 0.9663 - val_sparse_categorical_accuracy: 0.6942 - val_sparse_categorical_crossentropy: 0.9663 - lr: 0.0100
# Epoch 14/200
# 90/90 [==============================] - 15s 152ms/step - loss: 0.9378 - sparse_categorical_accuracy: 0.6940 - sparse_categorical_crossentropy: 0.9378 - val_loss: 0.8848 - val_sparse_categorical_accuracy: 0.7161 - val_sparse_categorical_crossentropy: 0.8848 - lr: 0.0100
# Epoch 15/200
# 90/90 [==============================] - 14s 148ms/step - loss: 0.9188 - sparse_categorical_accuracy: 0.7067 - sparse_categorical_crossentropy: 0.9188 - val_loss: 0.8681 - val_sparse_categorical_accuracy: 0.7178 - val_sparse_categorical_crossentropy: 0.8681 - lr: 0.0100
# Epoch 16/200
# 90/90 [==============================] - 14s 147ms/step - loss: 0.9094 - sparse_categorical_accuracy: 0.7107 - sparse_categorical_crossentropy: 0.9094 - val_loss: 0.9653 - val_sparse_categorical_accuracy: 0.6872 - val_sparse_categorical_crossentropy: 0.9653 - lr: 0.0100
# Epoch 17/200
# 90/90 [==============================] - 15s 149ms/step - loss: 0.8906 - sparse_categorical_accuracy: 0.7141 - sparse_categorical_crossentropy: 0.8906 - val_loss: 0.8769 - val_sparse_categorical_accuracy: 0.7219 - val_sparse_categorical_crossentropy: 0.8769 - lr: 0.0100
# Epoch 18/200
# 90/90 [==============================] - 14s 148ms/step - loss: 0.8790 - sparse_categorical_accuracy: 0.7177 - sparse_categorical_crossentropy: 0.8790 - val_loss: 0.8626 - val_sparse_categorical_accuracy: 0.7216 - val_sparse_categorical_crossentropy: 0.8626 - lr: 0.0100
# Epoch 19/200
# 90/90 [==============================] - 14s 149ms/step - loss: 0.8662 - sparse_categorical_accuracy: 0.7236 - sparse_categorical_crossentropy: 0.8662 - val_loss: 0.8357 - val_sparse_categorical_accuracy: 0.7250 - val_sparse_categorical_crossentropy: 0.8357 - lr: 0.0100
# Epoch 20/200
# 90/90 [==============================] - 14s 149ms/step - loss: 0.8273 - sparse_categorical_accuracy: 0.7377 - sparse_categorical_crossentropy: 0.8273 - val_loss: 0.8293 - val_sparse_categorical_accuracy: 0.7276 - val_sparse_categorical_crossentropy: 0.8293 - lr: 0.0100
# Epoch 21/200
# 90/90 [==============================] - 14s 149ms/step - loss: 0.8140 - sparse_categorical_accuracy: 0.7450 - sparse_categorical_crossentropy: 0.8140 - val_loss: 0.8321 - val_sparse_categorical_accuracy: 0.7330 - val_sparse_categorical_crossentropy: 0.8321 - lr: 0.0100
# Epoch 22/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.8525 - sparse_categorical_accuracy: 0.7326 - sparse_categorical_crossentropy: 0.8525 - val_loss: 0.8393 - val_sparse_categorical_accuracy: 0.7401 - val_sparse_categorical_crossentropy: 0.8393 - lr: 0.0100
# Epoch 23/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.8459 - sparse_categorical_accuracy: 0.7338 - sparse_categorical_crossentropy: 0.8459 - val_loss: 0.8162 - val_sparse_categorical_accuracy: 0.7398 - val_sparse_categorical_crossentropy: 0.8162 - lr: 0.0100
# Epoch 24/200
# 90/90 [==============================] - 14s 147ms/step - loss: 0.8085 - sparse_categorical_accuracy: 0.7440 - sparse_categorical_crossentropy: 0.8085 - val_loss: 0.7786 - val_sparse_categorical_accuracy: 0.7350 - val_sparse_categorical_crossentropy: 0.7786 - lr: 0.0100
# Epoch 25/200
# 90/90 [==============================] - 14s 148ms/step - loss: 0.7722 - sparse_categorical_accuracy: 0.7523 - sparse_categorical_crossentropy: 0.7722 - val_loss: 0.7595 - val_sparse_categorical_accuracy: 0.7444 - val_sparse_categorical_crossentropy: 0.7595 - lr: 0.0100
# Epoch 26/200
# 90/90 [==============================] - 15s 149ms/step - loss: 0.8124 - sparse_categorical_accuracy: 0.7406 - sparse_categorical_crossentropy: 0.8124 - val_loss: 0.7676 - val_sparse_categorical_accuracy: 0.7520 - val_sparse_categorical_crossentropy: 0.7676 - lr: 0.0100
# Epoch 27/200
# 90/90 [==============================] - 14s 149ms/step - loss: 0.8129 - sparse_categorical_accuracy: 0.7373 - sparse_categorical_crossentropy: 0.8129 - val_loss: 0.9301 - val_sparse_categorical_accuracy: 0.6711 - val_sparse_categorical_crossentropy: 0.9301 - lr: 0.0100
# Epoch 28/200
# 90/90 [==============================] - 14s 148ms/step - loss: 0.9686 - sparse_categorical_accuracy: 0.6913 - sparse_categorical_crossentropy: 0.9686 - val_loss: 0.9927 - val_sparse_categorical_accuracy: 0.6983 - val_sparse_categorical_crossentropy: 0.9927 - lr: 0.0100
# Epoch 29/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.9072 - sparse_categorical_accuracy: 0.7084 - sparse_categorical_crossentropy: 0.9072
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 90/90 [==============================] - 15s 150ms/step - loss: 0.9072 - sparse_categorical_accuracy: 0.7084 - sparse_categorical_crossentropy: 0.9072 - val_loss: 0.8491 - val_sparse_categorical_accuracy: 0.7207 - val_sparse_categorical_crossentropy: 0.8491 - lr: 0.0100
# Epoch 30/200
# 90/90 [==============================] - 14s 148ms/step - loss: 0.8160 - sparse_categorical_accuracy: 0.7387 - sparse_categorical_crossentropy: 0.8160 - val_loss: 0.7861 - val_sparse_categorical_accuracy: 0.7427 - val_sparse_categorical_crossentropy: 0.7861 - lr: 0.0050
# Epoch 31/200
# 90/90 [==============================] - 15s 150ms/step - loss: 0.7724 - sparse_categorical_accuracy: 0.7512 - sparse_categorical_crossentropy: 0.7724 - val_loss: 0.7435 - val_sparse_categorical_accuracy: 0.7519 - val_sparse_categorical_crossentropy: 0.7435 - lr: 0.0050
# 26/26 [==============================] - 4s 103ms/step - loss: 0.7887 - sparse_categorical_accuracy: 0.7515 - sparse_categorical_crossentropy: 0.7887
# 26/26 [==============================] - 4s 99ms/step
# Epoch 1/200
# 90/90 [==============================] - 18s 158ms/step - loss: 1.5485 - sparse_categorical_accuracy: 0.6236 - sparse_categorical_crossentropy: 1.5485 - val_loss: 1.5150 - val_sparse_categorical_accuracy: 0.6301 - val_sparse_categorical_crossentropy: 1.5150 - lr: 0.0100
# Epoch 2/200
# 90/90 [==============================] - 16s 165ms/step - loss: 1.4821 - sparse_categorical_accuracy: 0.6306 - sparse_categorical_crossentropy: 1.4821 - val_loss: 1.4608 - val_sparse_categorical_accuracy: 0.6301 - val_sparse_categorical_crossentropy: 1.4608 - lr: 0.0100
# Epoch 3/200
# 90/90 [==============================] - 16s 164ms/step - loss: 1.4388 - sparse_categorical_accuracy: 0.6310 - sparse_categorical_crossentropy: 1.4388 - val_loss: 1.4064 - val_sparse_categorical_accuracy: 0.6321 - val_sparse_categorical_crossentropy: 1.4064 - lr: 0.0100
# Epoch 4/200
# 90/90 [==============================] - 16s 161ms/step - loss: 1.4057 - sparse_categorical_accuracy: 0.6317 - sparse_categorical_crossentropy: 1.4057 - val_loss: 1.3627 - val_sparse_categorical_accuracy: 0.6314 - val_sparse_categorical_crossentropy: 1.3627 - lr: 0.0100
# Epoch 5/200
# 90/90 [==============================] - 16s 163ms/step - loss: 1.3431 - sparse_categorical_accuracy: 0.6351 - sparse_categorical_crossentropy: 1.3431 - val_loss: 1.3220 - val_sparse_categorical_accuracy: 0.6375 - val_sparse_categorical_crossentropy: 1.3220 - lr: 0.0100
# Epoch 6/200
# 90/90 [==============================] - 16s 165ms/step - loss: 1.3033 - sparse_categorical_accuracy: 0.6379 - sparse_categorical_crossentropy: 1.3033 - val_loss: 1.2662 - val_sparse_categorical_accuracy: 0.6446 - val_sparse_categorical_crossentropy: 1.2662 - lr: 0.0100
# Epoch 7/200
# 90/90 [==============================] - 16s 165ms/step - loss: 1.2311 - sparse_categorical_accuracy: 0.6463 - sparse_categorical_crossentropy: 1.2311 - val_loss: 1.1949 - val_sparse_categorical_accuracy: 0.6507 - val_sparse_categorical_crossentropy: 1.1949 - lr: 0.0100
# Epoch 8/200
# 90/90 [==============================] - 16s 163ms/step - loss: 1.1895 - sparse_categorical_accuracy: 0.6549 - sparse_categorical_crossentropy: 1.1895 - val_loss: 1.1494 - val_sparse_categorical_accuracy: 0.6650 - val_sparse_categorical_crossentropy: 1.1494 - lr: 0.0100
# Epoch 9/200
# 90/90 [==============================] - 16s 164ms/step - loss: 1.1364 - sparse_categorical_accuracy: 0.6609 - sparse_categorical_crossentropy: 1.1364 - val_loss: 1.1145 - val_sparse_categorical_accuracy: 0.6697 - val_sparse_categorical_crossentropy: 1.1145 - lr: 0.0100
# Epoch 10/200
# 90/90 [==============================] - 16s 164ms/step - loss: 1.0832 - sparse_categorical_accuracy: 0.6741 - sparse_categorical_crossentropy: 1.0832 - val_loss: 1.0780 - val_sparse_categorical_accuracy: 0.6862 - val_sparse_categorical_crossentropy: 1.0780 - lr: 0.0100
# Epoch 11/200
# 90/90 [==============================] - 16s 164ms/step - loss: 1.0361 - sparse_categorical_accuracy: 0.6874 - sparse_categorical_crossentropy: 1.0361 - val_loss: 1.0629 - val_sparse_categorical_accuracy: 0.6877 - val_sparse_categorical_crossentropy: 1.0629 - lr: 0.0100
# Epoch 12/200
# 90/90 [==============================] - 16s 165ms/step - loss: 0.9951 - sparse_categorical_accuracy: 0.6867 - sparse_categorical_crossentropy: 0.9951 - val_loss: 0.9700 - val_sparse_categorical_accuracy: 0.7008 - val_sparse_categorical_crossentropy: 0.9700 - lr: 0.0100
# Epoch 13/200
# 90/90 [==============================] - 16s 163ms/step - loss: 0.9534 - sparse_categorical_accuracy: 0.7015 - sparse_categorical_crossentropy: 0.9534 - val_loss: 0.9205 - val_sparse_categorical_accuracy: 0.6963 - val_sparse_categorical_crossentropy: 0.9205 - lr: 0.0100
# Epoch 14/200
# 90/90 [==============================] - 16s 165ms/step - loss: 0.9360 - sparse_categorical_accuracy: 0.7059 - sparse_categorical_crossentropy: 0.9360 - val_loss: 0.9022 - val_sparse_categorical_accuracy: 0.7094 - val_sparse_categorical_crossentropy: 0.9022 - lr: 0.0100
# Epoch 15/200
# 90/90 [==============================] - 16s 165ms/step - loss: 0.9623 - sparse_categorical_accuracy: 0.6899 - sparse_categorical_crossentropy: 0.9623 - val_loss: 0.9565 - val_sparse_categorical_accuracy: 0.6879 - val_sparse_categorical_crossentropy: 0.9565 - lr: 0.0100
# Epoch 16/200
# 90/90 [==============================] - 15s 158ms/step - loss: 0.9229 - sparse_categorical_accuracy: 0.7096 - sparse_categorical_crossentropy: 0.9229 - val_loss: 0.9125 - val_sparse_categorical_accuracy: 0.7054 - val_sparse_categorical_crossentropy: 0.9125 - lr: 0.0100
# Epoch 17/200
# 90/90 [==============================] - 16s 164ms/step - loss: 0.9160 - sparse_categorical_accuracy: 0.7057 - sparse_categorical_crossentropy: 0.9160 - val_loss: 0.8863 - val_sparse_categorical_accuracy: 0.7141 - val_sparse_categorical_crossentropy: 0.8863 - lr: 0.0100
# Epoch 18/200
# 90/90 [==============================] - 16s 162ms/step - loss: 0.9033 - sparse_categorical_accuracy: 0.7108 - sparse_categorical_crossentropy: 0.9033 - val_loss: 0.9003 - val_sparse_categorical_accuracy: 0.7110 - val_sparse_categorical_crossentropy: 0.9003 - lr: 0.0100
# Epoch 19/200
# 90/90 [==============================] - 16s 164ms/step - loss: 0.8856 - sparse_categorical_accuracy: 0.7120 - sparse_categorical_crossentropy: 0.8856 - val_loss: 0.8493 - val_sparse_categorical_accuracy: 0.7141 - val_sparse_categorical_crossentropy: 0.8493 - lr: 0.0100
# Epoch 20/200
# 90/90 [==============================] - 16s 161ms/step - loss: 0.9000 - sparse_categorical_accuracy: 0.7148 - sparse_categorical_crossentropy: 0.9000 - val_loss: 0.8866 - val_sparse_categorical_accuracy: 0.7183 - val_sparse_categorical_crossentropy: 0.8866 - lr: 0.0100
# Epoch 21/200
# 90/90 [==============================] - 16s 166ms/step - loss: 0.9137 - sparse_categorical_accuracy: 0.7135 - sparse_categorical_crossentropy: 0.9137 - val_loss: 0.9003 - val_sparse_categorical_accuracy: 0.7152 - val_sparse_categorical_crossentropy: 0.9003 - lr: 0.0100
# Epoch 22/200
# 90/90 [==============================] - 16s 165ms/step - loss: 0.8643 - sparse_categorical_accuracy: 0.7150 - sparse_categorical_crossentropy: 0.8643 - val_loss: 0.9196 - val_sparse_categorical_accuracy: 0.6922 - val_sparse_categorical_crossentropy: 0.9196 - lr: 0.0100
# Epoch 23/200
# 89/90 [============================>.] - ETA: 0s - loss: 1.1177 - sparse_categorical_accuracy: 0.6584 - sparse_categorical_crossentropy: 1.1177
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 90/90 [==============================] - 16s 163ms/step - loss: 1.1178 - sparse_categorical_accuracy: 0.6583 - sparse_categorical_crossentropy: 1.1178 - val_loss: 1.0063 - val_sparse_categorical_accuracy: 0.6788 - val_sparse_categorical_crossentropy: 1.0063 - lr: 0.0100
# Epoch 24/200
# 90/90 [==============================] - 16s 164ms/step - loss: 0.9678 - sparse_categorical_accuracy: 0.6962 - sparse_categorical_crossentropy: 0.9678 - val_loss: 0.9463 - val_sparse_categorical_accuracy: 0.6977 - val_sparse_categorical_crossentropy: 0.9463 - lr: 0.0050
# Epoch 25/200
# 90/90 [==============================] - 16s 164ms/step - loss: 0.9519 - sparse_categorical_accuracy: 0.6973 - sparse_categorical_crossentropy: 0.9519 - val_loss: 0.9328 - val_sparse_categorical_accuracy: 0.6954 - val_sparse_categorical_crossentropy: 0.9328 - lr: 0.0050
# 26/26 [==============================] - 4s 113ms/step - loss: 0.8935 - sparse_categorical_accuracy: 0.7262 - sparse_categorical_crossentropy: 0.8935
# 26/26 [==============================] - 5s 105ms/step

# %%
results
# Out:
#    seed      loss  sparse_categorical_accuracy  \
# 0     0  0.515337                     0.843136
# 1     1  0.623787                     0.811348
# 2     2  0.372375                     0.889281
# 3     3  0.788748                     0.751459
# 4     4  0.893548                     0.726198
#
#    sparse_categorical_crossentropy
# 0                         0.515337
# 1                         0.623787
# 2                         0.372375
# 3                         0.788748
# 4                         0.893548
