# %%
import gc
import os
import pickle
import random
import shutil

import numpy as np
import pandas as pd
import tensorflow as tf
from keras import losses, optimizers, metrics, callbacks

# %%
tf.config.list_logical_devices()
# Out:
# [LogicalDevice(name='/device:CPU:0', device_type='CPU'),
#  LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
SEED = 123
N_CLASS = 12
MAX_EPOCHS = 200

# %%
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Load data

# %%
train_ds = tf.keras.utils.audio_dataset_from_directory(
    directory="data/train",
    batch_size=512,
    output_sequence_length=16000,
    shuffle=True,
    seed=SEED
)

val_ds = tf.keras.utils.audio_dataset_from_directory(
    directory="data/val",
    batch_size=512,
    output_sequence_length=16000,
    shuffle=False
)

test_ds = tf.keras.utils.audio_dataset_from_directory(
    directory="data/test",
    batch_size=512,
    output_sequence_length=16000,
    shuffle=False
)

label_names = np.array(train_ds.class_names)
print("label names:", label_names)
# Out:
# Found 45586 files belonging to 12 classes.
# Found 6513 files belonging to 12 classes.
# Found 13024 files belonging to 12 classes.
# label names: ['down' 'go' 'left' 'no' 'off' 'on' 'right' 'silence' 'stop' 'unknown'
#  'up' 'yes']

# %%
def squeeze(audio, labels):
    audio = tf.squeeze(audio, axis=-1)
    return audio, labels

train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
val_ds = val_ds.map(squeeze, tf.data.AUTOTUNE)
test_ds = test_ds.map(squeeze, tf.data.AUTOTUNE)

# %% [markdown]
# ## CNN + LSTM Complex

# %%
from SpeechModels import get_melspec_model
import tensorflow.keras.layers as L
from keras.models import Model

def CNN_LSTM(n_out, input_length, kernel_size):

    mel_spec_model = get_melspec_model(input_length)
    inputs, outputs = mel_spec_model.inputs, mel_spec_model.outputs
    o_shape = outputs[0].shape
    y1 = L.Conv1D(32, kernel_size, activation='relu', padding='same', input_shape=o_shape[1:])(outputs[0])
    y2 = L.Conv1D(32, kernel_size * 2, activation='relu', padding='same', input_shape=o_shape[1:])(outputs[0])
    y3 = L.Conv1D(32, kernel_size * 4, activation='relu', padding='same', input_shape=o_shape[1:])(outputs[0])
    y4 = L.Conv1D(32, kernel_size * 8, activation='relu', padding='same', input_shape=o_shape[1:])(outputs[0])

    x = L.Concatenate(axis=-1)([y1, y2, y3, y4])

    x = L.Bidirectional(L.LSTM(128, return_sequences=False)
                        )(x)  # [b_s, seq_len, vec_dim]

    output = L.Dense(n_out, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs], outputs=[output])

    return model


model = CNN_LSTM(N_CLASS, 16000, 4)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 16000)]      0           []
#
#  tf.signal.stft (TFOpLambda)    (None, 125, 513)     0           ['input[0][0]']
#
#  tf.math.abs (TFOpLambda)       (None, 125, 513)     0           ['tf.signal.stft[0][0]']
#
#  tf.tensordot (TFOpLambda)      (None, 125, 80)      0           ['tf.math.abs[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 125, 80)     0           ['tf.tensordot[0][0]']
#  da)
#
#  tf.math.log (TFOpLambda)       (None, 125, 80)      0           ['tf.__operators__.add[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  ()                  0           ['tf.math.log[0][0]']
#  a)
#
#  tf.math.subtract (TFOpLambda)  (None, 125, 80)      0           ['tf.math.log[0][0]',
#                                                                   'tf.math.reduce_mean[0][0]']
#
#  tf.math.reduce_std (TFOpLambda  ()                  0           ['tf.math.log[0][0]']
#  )
#
#  tf.math.truediv (TFOpLambda)   (None, 125, 80)      0           ['tf.math.subtract[0][0]',
#                                                                   'tf.math.reduce_std[0][0]']
#
#  conv1d (Conv1D)                (None, 125, 32)      10272       ['tf.math.truediv[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 125, 32)      20512       ['tf.math.truediv[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 125, 32)      40992       ['tf.math.truediv[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 125, 32)      81952       ['tf.math.truediv[0][0]']
#
#  concatenate (Concatenate)      (None, 125, 128)     0           ['conv1d[0][0]',
#                                                                   'conv1d_1[0][0]',
#                                                                   'conv1d_2[0][0]',
#                                                                   'conv1d_3[0][0]']
#
#  bidirectional (Bidirectional)  (None, 256)          263168      ['concatenate[0][0]']
#
#  output (Dense)                 (None, 12)           3084        ['bidirectional[0][0]']
#
# ==================================================================================================
# Total params: 419,980
# Trainable params: 419,980
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer=optimizers.Adam(learning_rate=0.001),
    loss=losses.SparseCategoricalCrossentropy(),
    metrics=[metrics.SparseCategoricalAccuracy(), metrics.SparseCategoricalCrossentropy()]
)
checkpoint = callbacks.ModelCheckpoint(
    filepath="simple_cnn.h5",
    monitor="val_sparse_categorical_accuracy",
    verbose=0,
    save_best_only=True,
    save_weights_only=True
)

early_stopping = callbacks.EarlyStopping(
    monitor='val_sparse_categorical_accuracy',
    min_delta=0,
    patience=5,
    verbose=0,
    mode='max',
    baseline=None,
    restore_best_weights=True
)

reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_sparse_categorical_accuracy', factor=0.5, patience=3, min_lr=0.00001, verbose=1)

# %%
history = model.fit(
    train_ds,
    epochs=2,
    validation_data=val_ds,
    shuffle=True,
    callbacks=[checkpoint, early_stopping, reduce_lr]
)
# Out:
# Epoch 1/2
# 90/90 [==============================] - 21s 108ms/step - loss: 1.3262 - sparse_categorical_accuracy: 0.6401 - sparse_categorical_crossentropy: 1.3262 - val_loss: 0.9690 - val_sparse_categorical_accuracy: 0.6992 - val_sparse_categorical_crossentropy: 0.9690 - lr: 0.0010
# Epoch 2/2
# 90/90 [==============================] - 11s 107ms/step - loss: 0.7321 - sparse_categorical_accuracy: 0.7722 - sparse_categorical_crossentropy: 0.7321 - val_loss: 0.5440 - val_sparse_categorical_accuracy: 0.8276 - val_sparse_categorical_crossentropy: 0.5440 - lr: 0.0010

# %% [markdown]
# ## Experiments
#
# Training will be repeated 5 times with different weights initialization.

# %%
EXPERIMENT_NAME = "cnn_lstm_complex"
if os.path.exists(EXPERIMENT_NAME):
    shutil.rmtree(EXPERIMENT_NAME)
    os.mkdir(EXPERIMENT_NAME)
else:
    os.mkdir(EXPERIMENT_NAME)

# %%
TRAINING_SEEDS = list(range(5))
results = []
for seed in TRAINING_SEEDS:
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

    model = CNN_LSTM(N_CLASS, 16000, 4)

    model.compile(
        optimizer=optimizers.Adam(learning_rate=0.01),
        loss=losses.SparseCategoricalCrossentropy(),
        metrics=[metrics.SparseCategoricalAccuracy(), metrics.SparseCategoricalCrossentropy()]
    )

    history = model.fit(
        train_ds,
        epochs=MAX_EPOCHS,
        validation_data=val_ds,
        shuffle=True,
        callbacks=[early_stopping, reduce_lr]
    )

    with open(os.path.join(EXPERIMENT_NAME, f"history_{seed}.pkl"), "wb") as file:
        pickle.dump(history.history, file)

    eval_results = model.evaluate(test_ds)

    predictions = model.predict(test_ds)
    with open(os.path.join(EXPERIMENT_NAME, f"predictions_{seed}.pkl"), "wb") as file:
        pickle.dump(predictions, file)

    results += [{
        'seed': seed,
        'results': dict(zip(model.metrics_names, eval_results))
    }]
    gc.collect()

results = pd.DataFrame(results)
results = pd.concat([results.drop(["results"], axis=1), results["results"].apply(pd.Series)], axis=1)
results.to_csv(os.path.join(EXPERIMENT_NAME, 'results.csv'))
# Out:
# Epoch 1/200
# 90/90 [==============================] - 14s 114ms/step - loss: 1.5458 - sparse_categorical_accuracy: 0.6232 - sparse_categorical_crossentropy: 1.5458 - val_loss: 1.4983 - val_sparse_categorical_accuracy: 0.6301 - val_sparse_categorical_crossentropy: 1.4983 - lr: 0.0100
# Epoch 2/200
# 90/90 [==============================] - 11s 111ms/step - loss: 1.4779 - sparse_categorical_accuracy: 0.6310 - sparse_categorical_crossentropy: 1.4779 - val_loss: 1.4534 - val_sparse_categorical_accuracy: 0.6301 - val_sparse_categorical_crossentropy: 1.4534 - lr: 0.0100
# Epoch 3/200
# 90/90 [==============================] - 11s 109ms/step - loss: 1.4096 - sparse_categorical_accuracy: 0.6318 - sparse_categorical_crossentropy: 1.4096 - val_loss: 1.3882 - val_sparse_categorical_accuracy: 0.6314 - val_sparse_categorical_crossentropy: 1.3882 - lr: 0.0100
# Epoch 4/200
# 90/90 [==============================] - 11s 113ms/step - loss: 1.3466 - sparse_categorical_accuracy: 0.6337 - sparse_categorical_crossentropy: 1.3466 - val_loss: 1.3190 - val_sparse_categorical_accuracy: 0.6387 - val_sparse_categorical_crossentropy: 1.3190 - lr: 0.0100
# Epoch 5/200
# 90/90 [==============================] - 11s 108ms/step - loss: 1.2941 - sparse_categorical_accuracy: 0.6348 - sparse_categorical_crossentropy: 1.2941 - val_loss: 1.2803 - val_sparse_categorical_accuracy: 0.6297 - val_sparse_categorical_crossentropy: 1.2803 - lr: 0.0100
# Epoch 6/200
# 90/90 [==============================] - 11s 113ms/step - loss: 1.2318 - sparse_categorical_accuracy: 0.6419 - sparse_categorical_crossentropy: 1.2318 - val_loss: 1.2884 - val_sparse_categorical_accuracy: 0.6416 - val_sparse_categorical_crossentropy: 1.2884 - lr: 0.0100
# Epoch 7/200
# 90/90 [==============================] - 11s 111ms/step - loss: 1.2353 - sparse_categorical_accuracy: 0.6405 - sparse_categorical_crossentropy: 1.2353 - val_loss: 1.1948 - val_sparse_categorical_accuracy: 0.6430 - val_sparse_categorical_crossentropy: 1.1948 - lr: 0.0100
# Epoch 8/200
# 90/90 [==============================] - 11s 110ms/step - loss: 1.2026 - sparse_categorical_accuracy: 0.6443 - sparse_categorical_crossentropy: 1.2026 - val_loss: 1.2019 - val_sparse_categorical_accuracy: 0.6489 - val_sparse_categorical_crossentropy: 1.2019 - lr: 0.0100
# Epoch 9/200
# 90/90 [==============================] - 11s 109ms/step - loss: 1.2182 - sparse_categorical_accuracy: 0.6438 - sparse_categorical_crossentropy: 1.2182 - val_loss: 1.2478 - val_sparse_categorical_accuracy: 0.6435 - val_sparse_categorical_crossentropy: 1.2478 - lr: 0.0100
# Epoch 10/200
# 90/90 [==============================] - 11s 110ms/step - loss: 1.2029 - sparse_categorical_accuracy: 0.6471 - sparse_categorical_crossentropy: 1.2029 - val_loss: 1.2281 - val_sparse_categorical_accuracy: 0.6464 - val_sparse_categorical_crossentropy: 1.2281 - lr: 0.0100
# Epoch 11/200
# 90/90 [==============================] - 11s 112ms/step - loss: 1.1729 - sparse_categorical_accuracy: 0.6504 - sparse_categorical_crossentropy: 1.1729 - val_loss: 1.1520 - val_sparse_categorical_accuracy: 0.6544 - val_sparse_categorical_crossentropy: 1.1520 - lr: 0.0100
# Epoch 12/200
# 90/90 [==============================] - 11s 114ms/step - loss: 1.1616 - sparse_categorical_accuracy: 0.6545 - sparse_categorical_crossentropy: 1.1616 - val_loss: 1.1501 - val_sparse_categorical_accuracy: 0.6462 - val_sparse_categorical_crossentropy: 1.1501 - lr: 0.0100
# Epoch 13/200
# 90/90 [==============================] - 11s 112ms/step - loss: 1.1287 - sparse_categorical_accuracy: 0.6545 - sparse_categorical_crossentropy: 1.1287 - val_loss: 1.1480 - val_sparse_categorical_accuracy: 0.6555 - val_sparse_categorical_crossentropy: 1.1480 - lr: 0.0100
# Epoch 14/200
# 90/90 [==============================] - 11s 111ms/step - loss: 1.1320 - sparse_categorical_accuracy: 0.6575 - sparse_categorical_crossentropy: 1.1320 - val_loss: 1.1387 - val_sparse_categorical_accuracy: 0.6433 - val_sparse_categorical_crossentropy: 1.1387 - lr: 0.0100
# Epoch 15/200
# 90/90 [==============================] - 11s 114ms/step - loss: 1.1222 - sparse_categorical_accuracy: 0.6578 - sparse_categorical_crossentropy: 1.1222 - val_loss: 1.1294 - val_sparse_categorical_accuracy: 0.6509 - val_sparse_categorical_crossentropy: 1.1294 - lr: 0.0100
# Epoch 16/200
# 90/90 [==============================] - 11s 111ms/step - loss: 1.1043 - sparse_categorical_accuracy: 0.6607 - sparse_categorical_crossentropy: 1.1043 - val_loss: 1.1179 - val_sparse_categorical_accuracy: 0.6584 - val_sparse_categorical_crossentropy: 1.1179 - lr: 0.0100
# Epoch 17/200
# 90/90 [==============================] - 11s 111ms/step - loss: 1.1022 - sparse_categorical_accuracy: 0.6621 - sparse_categorical_crossentropy: 1.1022 - val_loss: 1.1180 - val_sparse_categorical_accuracy: 0.6548 - val_sparse_categorical_crossentropy: 1.1180 - lr: 0.0100
# Epoch 18/200
# 90/90 [==============================] - 11s 112ms/step - loss: 1.0848 - sparse_categorical_accuracy: 0.6667 - sparse_categorical_crossentropy: 1.0848 - val_loss: 1.0892 - val_sparse_categorical_accuracy: 0.6654 - val_sparse_categorical_crossentropy: 1.0892 - lr: 0.0100
# Epoch 19/200
# 90/90 [==============================] - 11s 111ms/step - loss: 1.0755 - sparse_categorical_accuracy: 0.6680 - sparse_categorical_crossentropy: 1.0755 - val_loss: 1.0878 - val_sparse_categorical_accuracy: 0.6728 - val_sparse_categorical_crossentropy: 1.0878 - lr: 0.0100
# Epoch 20/200
# 90/90 [==============================] - 11s 111ms/step - loss: 1.0616 - sparse_categorical_accuracy: 0.6692 - sparse_categorical_crossentropy: 1.0616 - val_loss: 1.0502 - val_sparse_categorical_accuracy: 0.6673 - val_sparse_categorical_crossentropy: 1.0502 - lr: 0.0100
# Epoch 21/200
# 90/90 [==============================] - 11s 111ms/step - loss: 1.0532 - sparse_categorical_accuracy: 0.6674 - sparse_categorical_crossentropy: 1.0532 - val_loss: 1.0548 - val_sparse_categorical_accuracy: 0.6747 - val_sparse_categorical_crossentropy: 1.0548 - lr: 0.0100
# Epoch 22/200
# 90/90 [==============================] - 11s 111ms/step - loss: 1.0229 - sparse_categorical_accuracy: 0.6754 - sparse_categorical_crossentropy: 1.0229 - val_loss: 0.9931 - val_sparse_categorical_accuracy: 0.6894 - val_sparse_categorical_crossentropy: 0.9931 - lr: 0.0100
# Epoch 23/200
# 90/90 [==============================] - 11s 112ms/step - loss: 1.0096 - sparse_categorical_accuracy: 0.6838 - sparse_categorical_crossentropy: 1.0096 - val_loss: 1.0037 - val_sparse_categorical_accuracy: 0.6717 - val_sparse_categorical_crossentropy: 1.0037 - lr: 0.0100
# Epoch 24/200
# 90/90 [==============================] - 11s 111ms/step - loss: 0.9627 - sparse_categorical_accuracy: 0.6871 - sparse_categorical_crossentropy: 0.9627 - val_loss: 0.9396 - val_sparse_categorical_accuracy: 0.6989 - val_sparse_categorical_crossentropy: 0.9396 - lr: 0.0100
# Epoch 25/200
# 90/90 [==============================] - 11s 112ms/step - loss: 0.9143 - sparse_categorical_accuracy: 0.7013 - sparse_categorical_crossentropy: 0.9143 - val_loss: 0.9203 - val_sparse_categorical_accuracy: 0.7109 - val_sparse_categorical_crossentropy: 0.9203 - lr: 0.0100
# Epoch 26/200
# 90/90 [==============================] - 11s 111ms/step - loss: 0.8848 - sparse_categorical_accuracy: 0.7106 - sparse_categorical_crossentropy: 0.8848 - val_loss: 0.9998 - val_sparse_categorical_accuracy: 0.6751 - val_sparse_categorical_crossentropy: 0.9998 - lr: 0.0100
# Epoch 27/200
# 90/90 [==============================] - 11s 111ms/step - loss: 0.9571 - sparse_categorical_accuracy: 0.6930 - sparse_categorical_crossentropy: 0.9571 - val_loss: 0.8815 - val_sparse_categorical_accuracy: 0.7147 - val_sparse_categorical_crossentropy: 0.8815 - lr: 0.0100
# Epoch 28/200
# 90/90 [==============================] - 11s 110ms/step - loss: 0.8628 - sparse_categorical_accuracy: 0.7232 - sparse_categorical_crossentropy: 0.8628 - val_loss: 0.8702 - val_sparse_categorical_accuracy: 0.7113 - val_sparse_categorical_crossentropy: 0.8702 - lr: 0.0100
# Epoch 29/200
# 90/90 [==============================] - 11s 111ms/step - loss: 0.8704 - sparse_categorical_accuracy: 0.7190 - sparse_categorical_crossentropy: 0.8704 - val_loss: 0.8394 - val_sparse_categorical_accuracy: 0.7281 - val_sparse_categorical_crossentropy: 0.8394 - lr: 0.0100
# Epoch 30/200
# 90/90 [==============================] - 11s 112ms/step - loss: 0.8216 - sparse_categorical_accuracy: 0.7299 - sparse_categorical_crossentropy: 0.8216 - val_loss: 0.7993 - val_sparse_categorical_accuracy: 0.7325 - val_sparse_categorical_crossentropy: 0.7993 - lr: 0.0100
# Epoch 31/200
# 90/90 [==============================] - 11s 115ms/step - loss: 0.8032 - sparse_categorical_accuracy: 0.7406 - sparse_categorical_crossentropy: 0.8032 - val_loss: 0.7941 - val_sparse_categorical_accuracy: 0.7387 - val_sparse_categorical_crossentropy: 0.7941 - lr: 0.0100
# Epoch 32/200
# 90/90 [==============================] - 11s 112ms/step - loss: 0.7869 - sparse_categorical_accuracy: 0.7424 - sparse_categorical_crossentropy: 0.7869 - val_loss: 0.7584 - val_sparse_categorical_accuracy: 0.7531 - val_sparse_categorical_crossentropy: 0.7584 - lr: 0.0100
# Epoch 33/200
# 90/90 [==============================] - 11s 112ms/step - loss: 0.7796 - sparse_categorical_accuracy: 0.7464 - sparse_categorical_crossentropy: 0.7796 - val_loss: 0.8118 - val_sparse_categorical_accuracy: 0.7315 - val_sparse_categorical_crossentropy: 0.8118 - lr: 0.0100
# Epoch 34/200
# 90/90 [==============================] - 11s 113ms/step - loss: 0.8113 - sparse_categorical_accuracy: 0.7417 - sparse_categorical_crossentropy: 0.8113 - val_loss: 0.8080 - val_sparse_categorical_accuracy: 0.7368 - val_sparse_categorical_crossentropy: 0.8080 - lr: 0.0100
# Epoch 35/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.8240 - sparse_categorical_accuracy: 0.7342 - sparse_categorical_crossentropy: 0.8240
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 90/90 [==============================] - 11s 113ms/step - loss: 0.8241 - sparse_categorical_accuracy: 0.7342 - sparse_categorical_crossentropy: 0.8241 - val_loss: 0.8159 - val_sparse_categorical_accuracy: 0.7341 - val_sparse_categorical_crossentropy: 0.8159 - lr: 0.0100
# Epoch 36/200
# 90/90 [==============================] - 11s 114ms/step - loss: 0.7507 - sparse_categorical_accuracy: 0.7511 - sparse_categorical_crossentropy: 0.7507 - val_loss: 0.7206 - val_sparse_categorical_accuracy: 0.7609 - val_sparse_categorical_crossentropy: 0.7206 - lr: 0.0050
# Epoch 37/200
# 90/90 [==============================] - 11s 114ms/step - loss: 0.7076 - sparse_categorical_accuracy: 0.7702 - sparse_categorical_crossentropy: 0.7076 - val_loss: 0.6908 - val_sparse_categorical_accuracy: 0.7769 - val_sparse_categorical_crossentropy: 0.6908 - lr: 0.0050
# Epoch 38/200
# 90/90 [==============================] - 11s 114ms/step - loss: 0.6928 - sparse_categorical_accuracy: 0.7773 - sparse_categorical_crossentropy: 0.6928 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.7715 - val_sparse_categorical_crossentropy: 0.6922 - lr: 0.0050
# Epoch 39/200
# 90/90 [==============================] - 11s 115ms/step - loss: 0.6744 - sparse_categorical_accuracy: 0.7813 - sparse_categorical_crossentropy: 0.6744 - val_loss: 0.6894 - val_sparse_categorical_accuracy: 0.7794 - val_sparse_categorical_crossentropy: 0.6894 - lr: 0.0050
# Epoch 40/200
# 90/90 [==============================] - 11s 114ms/step - loss: 0.6865 - sparse_categorical_accuracy: 0.7769 - sparse_categorical_crossentropy: 0.6865 - val_loss: 0.6744 - val_sparse_categorical_accuracy: 0.7801 - val_sparse_categorical_crossentropy: 0.6744 - lr: 0.0050
# Epoch 41/200
# 90/90 [==============================] - 11s 115ms/step - loss: 0.6630 - sparse_categorical_accuracy: 0.7861 - sparse_categorical_crossentropy: 0.6630 - val_loss: 0.6638 - val_sparse_categorical_accuracy: 0.7918 - val_sparse_categorical_crossentropy: 0.6638 - lr: 0.0050
# Epoch 42/200
# 90/90 [==============================] - 11s 115ms/step - loss: 0.6508 - sparse_categorical_accuracy: 0.7923 - sparse_categorical_crossentropy: 0.6508 - val_loss: 0.6651 - val_sparse_categorical_accuracy: 0.7901 - val_sparse_categorical_crossentropy: 0.6651 - lr: 0.0050
# Epoch 43/200
# 90/90 [==============================] - 11s 115ms/step - loss: 0.6565 - sparse_categorical_accuracy: 0.7906 - sparse_categorical_crossentropy: 0.6565 - val_loss: 0.6497 - val_sparse_categorical_accuracy: 0.7943 - val_sparse_categorical_crossentropy: 0.6497 - lr: 0.0050
# Epoch 44/200
# 90/90 [==============================] - 11s 116ms/step - loss: 0.6357 - sparse_categorical_accuracy: 0.7963 - sparse_categorical_crossentropy: 0.6357 - val_loss: 0.6643 - val_sparse_categorical_accuracy: 0.7883 - val_sparse_categorical_crossentropy: 0.6643 - lr: 0.0050
# Epoch 45/200
# 90/90 [==============================] - 11s 116ms/step - loss: 0.6504 - sparse_categorical_accuracy: 0.7918 - sparse_categorical_crossentropy: 0.6504 - val_loss: 0.6446 - val_sparse_categorical_accuracy: 0.7867 - val_sparse_categorical_crossentropy: 0.6446 - lr: 0.0050
# Epoch 46/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.6430 - sparse_categorical_accuracy: 0.7930 - sparse_categorical_crossentropy: 0.6430
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 90/90 [==============================] - 11s 115ms/step - loss: 0.6431 - sparse_categorical_accuracy: 0.7930 - sparse_categorical_crossentropy: 0.6431 - val_loss: 0.6384 - val_sparse_categorical_accuracy: 0.7941 - val_sparse_categorical_crossentropy: 0.6384 - lr: 0.0050
# Epoch 47/200
# 90/90 [==============================] - 11s 115ms/step - loss: 0.6149 - sparse_categorical_accuracy: 0.8014 - sparse_categorical_crossentropy: 0.6149 - val_loss: 0.6357 - val_sparse_categorical_accuracy: 0.7941 - val_sparse_categorical_crossentropy: 0.6357 - lr: 0.0025
# Epoch 48/200
# 90/90 [==============================] - 11s 116ms/step - loss: 0.5948 - sparse_categorical_accuracy: 0.8076 - sparse_categorical_crossentropy: 0.5948 - val_loss: 0.6111 - val_sparse_categorical_accuracy: 0.7982 - val_sparse_categorical_crossentropy: 0.6111 - lr: 0.0025
# Epoch 49/200
# 90/90 [==============================] - 11s 116ms/step - loss: 0.5871 - sparse_categorical_accuracy: 0.8087 - sparse_categorical_crossentropy: 0.5871 - val_loss: 0.6089 - val_sparse_categorical_accuracy: 0.8030 - val_sparse_categorical_crossentropy: 0.6089 - lr: 0.0025
# Epoch 50/200
# 90/90 [==============================] - 11s 115ms/step - loss: 0.5880 - sparse_categorical_accuracy: 0.8094 - sparse_categorical_crossentropy: 0.5880 - val_loss: 0.6056 - val_sparse_categorical_accuracy: 0.8081 - val_sparse_categorical_crossentropy: 0.6056 - lr: 0.0025
# Epoch 51/200
# 90/90 [==============================] - 11s 114ms/step - loss: 0.5785 - sparse_categorical_accuracy: 0.8134 - sparse_categorical_crossentropy: 0.5785 - val_loss: 0.5905 - val_sparse_categorical_accuracy: 0.8081 - val_sparse_categorical_crossentropy: 0.5905 - lr: 0.0025
# Epoch 52/200
# 90/90 [==============================] - 11s 116ms/step - loss: 0.5721 - sparse_categorical_accuracy: 0.8156 - sparse_categorical_crossentropy: 0.5721 - val_loss: 0.5982 - val_sparse_categorical_accuracy: 0.8093 - val_sparse_categorical_crossentropy: 0.5982 - lr: 0.0025
# Epoch 53/200
# 90/90 [==============================] - 11s 115ms/step - loss: 0.5713 - sparse_categorical_accuracy: 0.8170 - sparse_categorical_crossentropy: 0.5713 - val_loss: 0.5953 - val_sparse_categorical_accuracy: 0.8059 - val_sparse_categorical_crossentropy: 0.5953 - lr: 0.0025
# Epoch 54/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.5650 - sparse_categorical_accuracy: 0.8193 - sparse_categorical_crossentropy: 0.5650 - val_loss: 0.5701 - val_sparse_categorical_accuracy: 0.8108 - val_sparse_categorical_crossentropy: 0.5701 - lr: 0.0025
# Epoch 55/200
# 90/90 [==============================] - 11s 116ms/step - loss: 0.5566 - sparse_categorical_accuracy: 0.8197 - sparse_categorical_crossentropy: 0.5566 - val_loss: 0.5702 - val_sparse_categorical_accuracy: 0.8147 - val_sparse_categorical_crossentropy: 0.5702 - lr: 0.0025
# Epoch 56/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.5516 - sparse_categorical_accuracy: 0.8235 - sparse_categorical_crossentropy: 0.5516 - val_loss: 0.5658 - val_sparse_categorical_accuracy: 0.8121 - val_sparse_categorical_crossentropy: 0.5658 - lr: 0.0025
# Epoch 57/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.5447 - sparse_categorical_accuracy: 0.8250 - sparse_categorical_crossentropy: 0.5447 - val_loss: 0.5608 - val_sparse_categorical_accuracy: 0.8182 - val_sparse_categorical_crossentropy: 0.5608 - lr: 0.0025
# Epoch 58/200
# 90/90 [==============================] - 11s 116ms/step - loss: 0.5419 - sparse_categorical_accuracy: 0.8295 - sparse_categorical_crossentropy: 0.5419 - val_loss: 0.5729 - val_sparse_categorical_accuracy: 0.8162 - val_sparse_categorical_crossentropy: 0.5729 - lr: 0.0025
# Epoch 59/200
# 90/90 [==============================] - 11s 115ms/step - loss: 0.5371 - sparse_categorical_accuracy: 0.8293 - sparse_categorical_crossentropy: 0.5371 - val_loss: 0.5670 - val_sparse_categorical_accuracy: 0.8177 - val_sparse_categorical_crossentropy: 0.5670 - lr: 0.0025
# Epoch 60/200
# 90/90 [==============================] - 11s 116ms/step - loss: 0.5475 - sparse_categorical_accuracy: 0.8261 - sparse_categorical_crossentropy: 0.5475 - val_loss: 0.5593 - val_sparse_categorical_accuracy: 0.8207 - val_sparse_categorical_crossentropy: 0.5593 - lr: 0.0025
# Epoch 61/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.5296 - sparse_categorical_accuracy: 0.8301 - sparse_categorical_crossentropy: 0.5296 - val_loss: 0.5538 - val_sparse_categorical_accuracy: 0.8177 - val_sparse_categorical_crossentropy: 0.5538 - lr: 0.0025
# Epoch 62/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.5265 - sparse_categorical_accuracy: 0.8344 - sparse_categorical_crossentropy: 0.5265 - val_loss: 0.5438 - val_sparse_categorical_accuracy: 0.8253 - val_sparse_categorical_crossentropy: 0.5438 - lr: 0.0025
# Epoch 63/200
# 90/90 [==============================] - 12s 119ms/step - loss: 0.5233 - sparse_categorical_accuracy: 0.8337 - sparse_categorical_crossentropy: 0.5233 - val_loss: 0.5509 - val_sparse_categorical_accuracy: 0.8256 - val_sparse_categorical_crossentropy: 0.5509 - lr: 0.0025
# Epoch 64/200
# 90/90 [==============================] - 11s 116ms/step - loss: 0.5315 - sparse_categorical_accuracy: 0.8292 - sparse_categorical_crossentropy: 0.5315 - val_loss: 0.5588 - val_sparse_categorical_accuracy: 0.8201 - val_sparse_categorical_crossentropy: 0.5588 - lr: 0.0025
# Epoch 65/200
# 90/90 [==============================] - 11s 116ms/step - loss: 0.5204 - sparse_categorical_accuracy: 0.8358 - sparse_categorical_crossentropy: 0.5204 - val_loss: 0.5409 - val_sparse_categorical_accuracy: 0.8305 - val_sparse_categorical_crossentropy: 0.5409 - lr: 0.0025
# Epoch 66/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.5612 - sparse_categorical_accuracy: 0.8199 - sparse_categorical_crossentropy: 0.5612 - val_loss: 0.5842 - val_sparse_categorical_accuracy: 0.8164 - val_sparse_categorical_crossentropy: 0.5842 - lr: 0.0025
# Epoch 67/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.5330 - sparse_categorical_accuracy: 0.8305 - sparse_categorical_crossentropy: 0.5330 - val_loss: 0.5450 - val_sparse_categorical_accuracy: 0.8282 - val_sparse_categorical_crossentropy: 0.5450 - lr: 0.0025
# Epoch 68/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.5257 - sparse_categorical_accuracy: 0.8341 - sparse_categorical_crossentropy: 0.5257
# Epoch 68: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 90/90 [==============================] - 11s 117ms/step - loss: 0.5256 - sparse_categorical_accuracy: 0.8342 - sparse_categorical_crossentropy: 0.5256 - val_loss: 0.5538 - val_sparse_categorical_accuracy: 0.8224 - val_sparse_categorical_crossentropy: 0.5538 - lr: 0.0025
# Epoch 69/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.5125 - sparse_categorical_accuracy: 0.8377 - sparse_categorical_crossentropy: 0.5125 - val_loss: 0.5408 - val_sparse_categorical_accuracy: 0.8308 - val_sparse_categorical_crossentropy: 0.5408 - lr: 0.0012
# Epoch 70/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.5062 - sparse_categorical_accuracy: 0.8403 - sparse_categorical_crossentropy: 0.5062 - val_loss: 0.5356 - val_sparse_categorical_accuracy: 0.8334 - val_sparse_categorical_crossentropy: 0.5356 - lr: 0.0012
# Epoch 71/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.5000 - sparse_categorical_accuracy: 0.8419 - sparse_categorical_crossentropy: 0.5000 - val_loss: 0.5337 - val_sparse_categorical_accuracy: 0.8322 - val_sparse_categorical_crossentropy: 0.5337 - lr: 0.0012
# Epoch 72/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.5007 - sparse_categorical_accuracy: 0.8401 - sparse_categorical_crossentropy: 0.5007 - val_loss: 0.5253 - val_sparse_categorical_accuracy: 0.8328 - val_sparse_categorical_crossentropy: 0.5253 - lr: 0.0012
# Epoch 73/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.4947 - sparse_categorical_accuracy: 0.8447 - sparse_categorical_crossentropy: 0.4947
# Epoch 73: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 90/90 [==============================] - 12s 118ms/step - loss: 0.4946 - sparse_categorical_accuracy: 0.8447 - sparse_categorical_crossentropy: 0.4946 - val_loss: 0.5298 - val_sparse_categorical_accuracy: 0.8331 - val_sparse_categorical_crossentropy: 0.5298 - lr: 0.0012
# Epoch 74/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.4867 - sparse_categorical_accuracy: 0.8455 - sparse_categorical_crossentropy: 0.4867 - val_loss: 0.5197 - val_sparse_categorical_accuracy: 0.8385 - val_sparse_categorical_crossentropy: 0.5197 - lr: 6.2500e-04
# Epoch 75/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.4815 - sparse_categorical_accuracy: 0.8481 - sparse_categorical_crossentropy: 0.4815 - val_loss: 0.5168 - val_sparse_categorical_accuracy: 0.8406 - val_sparse_categorical_crossentropy: 0.5168 - lr: 6.2500e-04
# Epoch 76/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.4802 - sparse_categorical_accuracy: 0.8479 - sparse_categorical_crossentropy: 0.4802 - val_loss: 0.5162 - val_sparse_categorical_accuracy: 0.8379 - val_sparse_categorical_crossentropy: 0.5162 - lr: 6.2500e-04
# Epoch 77/200
# 90/90 [==============================] - 12s 118ms/step - loss: 0.4779 - sparse_categorical_accuracy: 0.8485 - sparse_categorical_crossentropy: 0.4779 - val_loss: 0.5131 - val_sparse_categorical_accuracy: 0.8392 - val_sparse_categorical_crossentropy: 0.5131 - lr: 6.2500e-04
# Epoch 78/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.4774 - sparse_categorical_accuracy: 0.8493 - sparse_categorical_crossentropy: 0.4774
# Epoch 78: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 90/90 [==============================] - 11s 117ms/step - loss: 0.4773 - sparse_categorical_accuracy: 0.8493 - sparse_categorical_crossentropy: 0.4773 - val_loss: 0.5126 - val_sparse_categorical_accuracy: 0.8360 - val_sparse_categorical_crossentropy: 0.5126 - lr: 6.2500e-04
# Epoch 79/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.4737 - sparse_categorical_accuracy: 0.8511 - sparse_categorical_crossentropy: 0.4737 - val_loss: 0.5125 - val_sparse_categorical_accuracy: 0.8383 - val_sparse_categorical_crossentropy: 0.5125 - lr: 3.1250e-04
# Epoch 80/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.4695 - sparse_categorical_accuracy: 0.8520 - sparse_categorical_crossentropy: 0.4695 - val_loss: 0.5129 - val_sparse_categorical_accuracy: 0.8376 - val_sparse_categorical_crossentropy: 0.5129 - lr: 3.1250e-04
# 26/26 [==============================] - 3s 102ms/step - loss: 0.5445 - sparse_categorical_accuracy: 0.8285 - sparse_categorical_crossentropy: 0.5445
# 26/26 [==============================] - 3s 100ms/step
# Epoch 1/200
# 90/90 [==============================] - 14s 117ms/step - loss: 1.5506 - sparse_categorical_accuracy: 0.6232 - sparse_categorical_crossentropy: 1.5506 - val_loss: 1.5219 - val_sparse_categorical_accuracy: 0.6301 - val_sparse_categorical_crossentropy: 1.5219 - lr: 0.0100
# Epoch 2/200
# 90/90 [==============================] - 11s 114ms/step - loss: 1.4908 - sparse_categorical_accuracy: 0.6302 - sparse_categorical_crossentropy: 1.4908 - val_loss: 1.4851 - val_sparse_categorical_accuracy: 0.6301 - val_sparse_categorical_crossentropy: 1.4851 - lr: 0.0100
# Epoch 3/200
# 90/90 [==============================] - 11s 115ms/step - loss: 1.4559 - sparse_categorical_accuracy: 0.6308 - sparse_categorical_crossentropy: 1.4559 - val_loss: 1.4489 - val_sparse_categorical_accuracy: 0.6338 - val_sparse_categorical_crossentropy: 1.4489 - lr: 0.0100
# Epoch 4/200
# 90/90 [==============================] - 11s 116ms/step - loss: 1.4071 - sparse_categorical_accuracy: 0.6321 - sparse_categorical_crossentropy: 1.4071 - val_loss: 1.4038 - val_sparse_categorical_accuracy: 0.6315 - val_sparse_categorical_crossentropy: 1.4038 - lr: 0.0100
# Epoch 5/200
# 90/90 [==============================] - 11s 117ms/step - loss: 1.3613 - sparse_categorical_accuracy: 0.6340 - sparse_categorical_crossentropy: 1.3613 - val_loss: 1.3841 - val_sparse_categorical_accuracy: 0.6312 - val_sparse_categorical_crossentropy: 1.3841 - lr: 0.0100
# Epoch 6/200
# 89/90 [============================>.] - ETA: 0s - loss: 1.3351 - sparse_categorical_accuracy: 0.6316 - sparse_categorical_crossentropy: 1.3351
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 90/90 [==============================] - 11s 117ms/step - loss: 1.3352 - sparse_categorical_accuracy: 0.6316 - sparse_categorical_crossentropy: 1.3352 - val_loss: 1.3191 - val_sparse_categorical_accuracy: 0.6307 - val_sparse_categorical_crossentropy: 1.3191 - lr: 0.0100
# Epoch 7/200
# 90/90 [==============================] - 11s 115ms/step - loss: 1.2878 - sparse_categorical_accuracy: 0.6355 - sparse_categorical_crossentropy: 1.2878 - val_loss: 1.3006 - val_sparse_categorical_accuracy: 0.6350 - val_sparse_categorical_crossentropy: 1.3006 - lr: 0.0050
# Epoch 8/200
# 90/90 [==============================] - 11s 116ms/step - loss: 1.2598 - sparse_categorical_accuracy: 0.6384 - sparse_categorical_crossentropy: 1.2598 - val_loss: 1.2562 - val_sparse_categorical_accuracy: 0.6355 - val_sparse_categorical_crossentropy: 1.2562 - lr: 0.0050
# Epoch 9/200
# 90/90 [==============================] - 11s 116ms/step - loss: 1.2395 - sparse_categorical_accuracy: 0.6389 - sparse_categorical_crossentropy: 1.2395 - val_loss: 1.2390 - val_sparse_categorical_accuracy: 0.6424 - val_sparse_categorical_crossentropy: 1.2390 - lr: 0.0050
# Epoch 10/200
# 90/90 [==============================] - 11s 117ms/step - loss: 1.2157 - sparse_categorical_accuracy: 0.6416 - sparse_categorical_crossentropy: 1.2157 - val_loss: 1.2129 - val_sparse_categorical_accuracy: 0.6447 - val_sparse_categorical_crossentropy: 1.2129 - lr: 0.0050
# Epoch 11/200
# 90/90 [==============================] - 11s 117ms/step - loss: 1.1675 - sparse_categorical_accuracy: 0.6483 - sparse_categorical_crossentropy: 1.1675 - val_loss: 1.1699 - val_sparse_categorical_accuracy: 0.6547 - val_sparse_categorical_crossentropy: 1.1699 - lr: 0.0050
# Epoch 12/200
# 90/90 [==============================] - 11s 114ms/step - loss: 1.1727 - sparse_categorical_accuracy: 0.6507 - sparse_categorical_crossentropy: 1.1727 - val_loss: 1.1601 - val_sparse_categorical_accuracy: 0.6539 - val_sparse_categorical_crossentropy: 1.1601 - lr: 0.0050
# Epoch 13/200
# 90/90 [==============================] - 11s 115ms/step - loss: 1.1288 - sparse_categorical_accuracy: 0.6520 - sparse_categorical_crossentropy: 1.1288 - val_loss: 1.1205 - val_sparse_categorical_accuracy: 0.6595 - val_sparse_categorical_crossentropy: 1.1205 - lr: 0.0050
# Epoch 14/200
# 90/90 [==============================] - 11s 117ms/step - loss: 1.0881 - sparse_categorical_accuracy: 0.6602 - sparse_categorical_crossentropy: 1.0881 - val_loss: 1.0491 - val_sparse_categorical_accuracy: 0.6641 - val_sparse_categorical_crossentropy: 1.0491 - lr: 0.0050
# Epoch 15/200
# 90/90 [==============================] - 11s 115ms/step - loss: 1.0202 - sparse_categorical_accuracy: 0.6715 - sparse_categorical_crossentropy: 1.0202 - val_loss: 1.0105 - val_sparse_categorical_accuracy: 0.6731 - val_sparse_categorical_crossentropy: 1.0105 - lr: 0.0050
# Epoch 16/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.9854 - sparse_categorical_accuracy: 0.6840 - sparse_categorical_crossentropy: 0.9854 - val_loss: 0.9776 - val_sparse_categorical_accuracy: 0.6832 - val_sparse_categorical_crossentropy: 0.9776 - lr: 0.0050
# Epoch 17/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.9735 - sparse_categorical_accuracy: 0.6861 - sparse_categorical_crossentropy: 0.9735 - val_loss: 0.9366 - val_sparse_categorical_accuracy: 0.6885 - val_sparse_categorical_crossentropy: 0.9366 - lr: 0.0050
# Epoch 18/200
# 90/90 [==============================] - 12s 119ms/step - loss: 0.9186 - sparse_categorical_accuracy: 0.6945 - sparse_categorical_crossentropy: 0.9186 - val_loss: 0.8963 - val_sparse_categorical_accuracy: 0.7078 - val_sparse_categorical_crossentropy: 0.8963 - lr: 0.0050
# Epoch 19/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.8969 - sparse_categorical_accuracy: 0.7061 - sparse_categorical_crossentropy: 0.8969 - val_loss: 0.9142 - val_sparse_categorical_accuracy: 0.6935 - val_sparse_categorical_crossentropy: 0.9142 - lr: 0.0050
# Epoch 20/200
# 90/90 [==============================] - 11s 115ms/step - loss: 0.8808 - sparse_categorical_accuracy: 0.7134 - sparse_categorical_crossentropy: 0.8808 - val_loss: 0.8654 - val_sparse_categorical_accuracy: 0.7229 - val_sparse_categorical_crossentropy: 0.8654 - lr: 0.0050
# Epoch 21/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.8485 - sparse_categorical_accuracy: 0.7239 - sparse_categorical_crossentropy: 0.8485 - val_loss: 0.8803 - val_sparse_categorical_accuracy: 0.7046 - val_sparse_categorical_crossentropy: 0.8803 - lr: 0.0050
# Epoch 22/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.8277 - sparse_categorical_accuracy: 0.7315 - sparse_categorical_crossentropy: 0.8277 - val_loss: 0.8621 - val_sparse_categorical_accuracy: 0.7204 - val_sparse_categorical_crossentropy: 0.8621 - lr: 0.0050
# Epoch 23/200
# 90/90 [==============================] - ETA: 0s - loss: 0.8819 - sparse_categorical_accuracy: 0.7217 - sparse_categorical_crossentropy: 0.8819
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 90/90 [==============================] - 12s 119ms/step - loss: 0.8819 - sparse_categorical_accuracy: 0.7217 - sparse_categorical_crossentropy: 0.8819 - val_loss: 0.8533 - val_sparse_categorical_accuracy: 0.7169 - val_sparse_categorical_crossentropy: 0.8533 - lr: 0.0050
# Epoch 24/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.7986 - sparse_categorical_accuracy: 0.7383 - sparse_categorical_crossentropy: 0.7986 - val_loss: 0.7969 - val_sparse_categorical_accuracy: 0.7467 - val_sparse_categorical_crossentropy: 0.7969 - lr: 0.0025
# Epoch 25/200
# 90/90 [==============================] - 12s 119ms/step - loss: 0.7754 - sparse_categorical_accuracy: 0.7461 - sparse_categorical_crossentropy: 0.7754 - val_loss: 0.7908 - val_sparse_categorical_accuracy: 0.7374 - val_sparse_categorical_crossentropy: 0.7908 - lr: 0.0025
# Epoch 26/200
# 90/90 [==============================] - 11s 116ms/step - loss: 0.7706 - sparse_categorical_accuracy: 0.7474 - sparse_categorical_crossentropy: 0.7706 - val_loss: 0.7823 - val_sparse_categorical_accuracy: 0.7464 - val_sparse_categorical_crossentropy: 0.7823 - lr: 0.0025
# Epoch 27/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.7447 - sparse_categorical_accuracy: 0.7569 - sparse_categorical_crossentropy: 0.7447
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 90/90 [==============================] - 11s 117ms/step - loss: 0.7448 - sparse_categorical_accuracy: 0.7568 - sparse_categorical_crossentropy: 0.7448 - val_loss: 0.7841 - val_sparse_categorical_accuracy: 0.7448 - val_sparse_categorical_crossentropy: 0.7841 - lr: 0.0025
# Epoch 28/200
# 90/90 [==============================] - 12s 118ms/step - loss: 0.7306 - sparse_categorical_accuracy: 0.7635 - sparse_categorical_crossentropy: 0.7306 - val_loss: 0.7453 - val_sparse_categorical_accuracy: 0.7596 - val_sparse_categorical_crossentropy: 0.7453 - lr: 0.0012
# Epoch 29/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.7172 - sparse_categorical_accuracy: 0.7698 - sparse_categorical_crossentropy: 0.7172 - val_loss: 0.7363 - val_sparse_categorical_accuracy: 0.7550 - val_sparse_categorical_crossentropy: 0.7363 - lr: 0.0012
# Epoch 30/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.7059 - sparse_categorical_accuracy: 0.7740 - sparse_categorical_crossentropy: 0.7059 - val_loss: 0.7329 - val_sparse_categorical_accuracy: 0.7623 - val_sparse_categorical_crossentropy: 0.7329 - lr: 0.0012
# Epoch 31/200
# 90/90 [==============================] - 12s 118ms/step - loss: 0.7070 - sparse_categorical_accuracy: 0.7746 - sparse_categorical_crossentropy: 0.7070 - val_loss: 0.7240 - val_sparse_categorical_accuracy: 0.7668 - val_sparse_categorical_crossentropy: 0.7240 - lr: 0.0012
# Epoch 32/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.6969 - sparse_categorical_accuracy: 0.7757 - sparse_categorical_crossentropy: 0.6969 - val_loss: 0.7248 - val_sparse_categorical_accuracy: 0.7751 - val_sparse_categorical_crossentropy: 0.7248 - lr: 0.0012
# Epoch 33/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.6907 - sparse_categorical_accuracy: 0.7823 - sparse_categorical_crossentropy: 0.6907 - val_loss: 0.7048 - val_sparse_categorical_accuracy: 0.7711 - val_sparse_categorical_crossentropy: 0.7048 - lr: 0.0012
# Epoch 34/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.7808 - sparse_categorical_crossentropy: 0.6930 - val_loss: 0.7159 - val_sparse_categorical_accuracy: 0.7686 - val_sparse_categorical_crossentropy: 0.7159 - lr: 0.0012
# Epoch 35/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.6837 - sparse_categorical_accuracy: 0.7844 - sparse_categorical_crossentropy: 0.6837
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 90/90 [==============================] - 11s 117ms/step - loss: 0.6837 - sparse_categorical_accuracy: 0.7845 - sparse_categorical_crossentropy: 0.6837 - val_loss: 0.7023 - val_sparse_categorical_accuracy: 0.7732 - val_sparse_categorical_crossentropy: 0.7023 - lr: 0.0012
# Epoch 36/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.6765 - sparse_categorical_accuracy: 0.7876 - sparse_categorical_crossentropy: 0.6765 - val_loss: 0.6946 - val_sparse_categorical_accuracy: 0.7826 - val_sparse_categorical_crossentropy: 0.6946 - lr: 6.2500e-04
# Epoch 37/200
# 90/90 [==============================] - 11s 116ms/step - loss: 0.6622 - sparse_categorical_accuracy: 0.7921 - sparse_categorical_crossentropy: 0.6622 - val_loss: 0.6858 - val_sparse_categorical_accuracy: 0.7843 - val_sparse_categorical_crossentropy: 0.6858 - lr: 6.2500e-04
# Epoch 38/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.6555 - sparse_categorical_accuracy: 0.7949 - sparse_categorical_crossentropy: 0.6555 - val_loss: 0.6870 - val_sparse_categorical_accuracy: 0.7846 - val_sparse_categorical_crossentropy: 0.6870 - lr: 6.2500e-04
# Epoch 39/200
# 90/90 [==============================] - 12s 118ms/step - loss: 0.6552 - sparse_categorical_accuracy: 0.7959 - sparse_categorical_crossentropy: 0.6552 - val_loss: 0.6898 - val_sparse_categorical_accuracy: 0.7815 - val_sparse_categorical_crossentropy: 0.6898 - lr: 6.2500e-04
# Epoch 40/200
# 90/90 [==============================] - 12s 119ms/step - loss: 0.6497 - sparse_categorical_accuracy: 0.7970 - sparse_categorical_crossentropy: 0.6497 - val_loss: 0.6781 - val_sparse_categorical_accuracy: 0.7847 - val_sparse_categorical_crossentropy: 0.6781 - lr: 6.2500e-04
# Epoch 41/200
# 90/90 [==============================] - 12s 118ms/step - loss: 0.6436 - sparse_categorical_accuracy: 0.7989 - sparse_categorical_crossentropy: 0.6436 - val_loss: 0.6786 - val_sparse_categorical_accuracy: 0.7824 - val_sparse_categorical_crossentropy: 0.6786 - lr: 6.2500e-04
# Epoch 42/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.6403 - sparse_categorical_accuracy: 0.7991 - sparse_categorical_crossentropy: 0.6403 - val_loss: 0.6747 - val_sparse_categorical_accuracy: 0.7869 - val_sparse_categorical_crossentropy: 0.6747 - lr: 6.2500e-04
# Epoch 43/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.6356 - sparse_categorical_accuracy: 0.8012 - sparse_categorical_crossentropy: 0.6356 - val_loss: 0.6788 - val_sparse_categorical_accuracy: 0.7818 - val_sparse_categorical_crossentropy: 0.6788 - lr: 6.2500e-04
# Epoch 44/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.6334 - sparse_categorical_accuracy: 0.8027 - sparse_categorical_crossentropy: 0.6334 - val_loss: 0.6680 - val_sparse_categorical_accuracy: 0.7881 - val_sparse_categorical_crossentropy: 0.6680 - lr: 6.2500e-04
# Epoch 45/200
# 90/90 [==============================] - 12s 119ms/step - loss: 0.6288 - sparse_categorical_accuracy: 0.8048 - sparse_categorical_crossentropy: 0.6288 - val_loss: 0.6692 - val_sparse_categorical_accuracy: 0.7863 - val_sparse_categorical_crossentropy: 0.6692 - lr: 6.2500e-04
# Epoch 46/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.6265 - sparse_categorical_accuracy: 0.8040 - sparse_categorical_crossentropy: 0.6265 - val_loss: 0.6700 - val_sparse_categorical_accuracy: 0.7878 - val_sparse_categorical_crossentropy: 0.6700 - lr: 6.2500e-04
# Epoch 47/200
# 90/90 [==============================] - ETA: 0s - loss: 0.6224 - sparse_categorical_accuracy: 0.8067 - sparse_categorical_crossentropy: 0.6224
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 90/90 [==============================] - 12s 119ms/step - loss: 0.6224 - sparse_categorical_accuracy: 0.8067 - sparse_categorical_crossentropy: 0.6224 - val_loss: 0.6720 - val_sparse_categorical_accuracy: 0.7844 - val_sparse_categorical_crossentropy: 0.6720 - lr: 6.2500e-04
# Epoch 48/200
# 90/90 [==============================] - 12s 119ms/step - loss: 0.6185 - sparse_categorical_accuracy: 0.8075 - sparse_categorical_crossentropy: 0.6185 - val_loss: 0.6673 - val_sparse_categorical_accuracy: 0.7901 - val_sparse_categorical_crossentropy: 0.6673 - lr: 3.1250e-04
# Epoch 49/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.6162 - sparse_categorical_accuracy: 0.8086 - sparse_categorical_crossentropy: 0.6162 - val_loss: 0.6649 - val_sparse_categorical_accuracy: 0.7901 - val_sparse_categorical_crossentropy: 0.6649 - lr: 3.1250e-04
# Epoch 50/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.6104 - sparse_categorical_accuracy: 0.8118 - sparse_categorical_crossentropy: 0.6104 - val_loss: 0.6625 - val_sparse_categorical_accuracy: 0.7910 - val_sparse_categorical_crossentropy: 0.6625 - lr: 3.1250e-04
# Epoch 51/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.6092 - sparse_categorical_accuracy: 0.8121 - sparse_categorical_crossentropy: 0.6092 - val_loss: 0.6642 - val_sparse_categorical_accuracy: 0.7915 - val_sparse_categorical_crossentropy: 0.6642 - lr: 3.1250e-04
# Epoch 52/200
# 90/90 [==============================] - 12s 118ms/step - loss: 0.6099 - sparse_categorical_accuracy: 0.8113 - sparse_categorical_crossentropy: 0.6099 - val_loss: 0.6583 - val_sparse_categorical_accuracy: 0.7932 - val_sparse_categorical_crossentropy: 0.6583 - lr: 3.1250e-04
# Epoch 53/200
# 90/90 [==============================] - 12s 119ms/step - loss: 0.6040 - sparse_categorical_accuracy: 0.8136 - sparse_categorical_crossentropy: 0.6040 - val_loss: 0.6606 - val_sparse_categorical_accuracy: 0.7915 - val_sparse_categorical_crossentropy: 0.6606 - lr: 3.1250e-04
# Epoch 54/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.6032 - sparse_categorical_accuracy: 0.8142 - sparse_categorical_crossentropy: 0.6032 - val_loss: 0.6584 - val_sparse_categorical_accuracy: 0.7933 - val_sparse_categorical_crossentropy: 0.6584 - lr: 3.1250e-04
# Epoch 55/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.6020 - sparse_categorical_accuracy: 0.8131 - sparse_categorical_crossentropy: 0.6020 - val_loss: 0.6607 - val_sparse_categorical_accuracy: 0.7898 - val_sparse_categorical_crossentropy: 0.6607 - lr: 3.1250e-04
# Epoch 56/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.6016 - sparse_categorical_accuracy: 0.8136 - sparse_categorical_crossentropy: 0.6016 - val_loss: 0.6616 - val_sparse_categorical_accuracy: 0.7910 - val_sparse_categorical_crossentropy: 0.6616 - lr: 3.1250e-04
# Epoch 57/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.5976 - sparse_categorical_accuracy: 0.8157 - sparse_categorical_crossentropy: 0.5976
# Epoch 57: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 90/90 [==============================] - 11s 116ms/step - loss: 0.5977 - sparse_categorical_accuracy: 0.8157 - sparse_categorical_crossentropy: 0.5977 - val_loss: 0.6584 - val_sparse_categorical_accuracy: 0.7926 - val_sparse_categorical_crossentropy: 0.6584 - lr: 3.1250e-04
# Epoch 58/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.5945 - sparse_categorical_accuracy: 0.8161 - sparse_categorical_crossentropy: 0.5945 - val_loss: 0.6562 - val_sparse_categorical_accuracy: 0.7930 - val_sparse_categorical_crossentropy: 0.6562 - lr: 1.5625e-04
# Epoch 59/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.5930 - sparse_categorical_accuracy: 0.8174 - sparse_categorical_crossentropy: 0.5930 - val_loss: 0.6595 - val_sparse_categorical_accuracy: 0.7912 - val_sparse_categorical_crossentropy: 0.6595 - lr: 1.5625e-04
# 26/26 [==============================] - 3s 99ms/step - loss: 0.6745 - sparse_categorical_accuracy: 0.7985 - sparse_categorical_crossentropy: 0.6745
# 26/26 [==============================] - 3s 96ms/step
# Epoch 1/200
# 90/90 [==============================] - 14s 120ms/step - loss: 1.5084 - sparse_categorical_accuracy: 0.6235 - sparse_categorical_crossentropy: 1.5084 - val_loss: 1.4391 - val_sparse_categorical_accuracy: 0.6300 - val_sparse_categorical_crossentropy: 1.4391 - lr: 0.0100
# Epoch 2/200
# 90/90 [==============================] - 11s 114ms/step - loss: 1.3945 - sparse_categorical_accuracy: 0.6309 - sparse_categorical_crossentropy: 1.3945 - val_loss: 1.3861 - val_sparse_categorical_accuracy: 0.6306 - val_sparse_categorical_crossentropy: 1.3861 - lr: 0.0100
# Epoch 3/200
# 90/90 [==============================] - 11s 115ms/step - loss: 1.3389 - sparse_categorical_accuracy: 0.6344 - sparse_categorical_crossentropy: 1.3389 - val_loss: 1.3241 - val_sparse_categorical_accuracy: 0.6332 - val_sparse_categorical_crossentropy: 1.3241 - lr: 0.0100
# Epoch 4/200
# 90/90 [==============================] - 11s 115ms/step - loss: 1.2951 - sparse_categorical_accuracy: 0.6412 - sparse_categorical_crossentropy: 1.2951 - val_loss: 1.2670 - val_sparse_categorical_accuracy: 0.6469 - val_sparse_categorical_crossentropy: 1.2670 - lr: 0.0100
# Epoch 5/200
# 90/90 [==============================] - 11s 114ms/step - loss: 1.2462 - sparse_categorical_accuracy: 0.6479 - sparse_categorical_crossentropy: 1.2462 - val_loss: 1.2007 - val_sparse_categorical_accuracy: 0.6545 - val_sparse_categorical_crossentropy: 1.2007 - lr: 0.0100
# Epoch 6/200
# 90/90 [==============================] - 11s 118ms/step - loss: 1.1562 - sparse_categorical_accuracy: 0.6585 - sparse_categorical_crossentropy: 1.1562 - val_loss: 1.2046 - val_sparse_categorical_accuracy: 0.6547 - val_sparse_categorical_crossentropy: 1.2046 - lr: 0.0100
# Epoch 7/200
# 90/90 [==============================] - 11s 117ms/step - loss: 1.1622 - sparse_categorical_accuracy: 0.6519 - sparse_categorical_crossentropy: 1.1622 - val_loss: 1.1625 - val_sparse_categorical_accuracy: 0.6476 - val_sparse_categorical_crossentropy: 1.1625 - lr: 0.0100
# Epoch 8/200
# 90/90 [==============================] - 12s 122ms/step - loss: 1.1271 - sparse_categorical_accuracy: 0.6623 - sparse_categorical_crossentropy: 1.1271 - val_loss: 1.0324 - val_sparse_categorical_accuracy: 0.6714 - val_sparse_categorical_crossentropy: 1.0324 - lr: 0.0100
# Epoch 9/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.9998 - sparse_categorical_accuracy: 0.6848 - sparse_categorical_crossentropy: 0.9998 - val_loss: 0.9510 - val_sparse_categorical_accuracy: 0.7052 - val_sparse_categorical_crossentropy: 0.9510 - lr: 0.0100
# Epoch 10/200
# 90/90 [==============================] - 12s 120ms/step - loss: 0.9458 - sparse_categorical_accuracy: 0.7035 - sparse_categorical_crossentropy: 0.9458 - val_loss: 0.9923 - val_sparse_categorical_accuracy: 0.6723 - val_sparse_categorical_crossentropy: 0.9923 - lr: 0.0100
# Epoch 11/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.9444 - sparse_categorical_accuracy: 0.7044 - sparse_categorical_crossentropy: 0.9444 - val_loss: 0.9108 - val_sparse_categorical_accuracy: 0.7152 - val_sparse_categorical_crossentropy: 0.9108 - lr: 0.0100
# Epoch 12/200
# 90/90 [==============================] - 11s 116ms/step - loss: 0.9429 - sparse_categorical_accuracy: 0.7062 - sparse_categorical_crossentropy: 0.9429 - val_loss: 0.9507 - val_sparse_categorical_accuracy: 0.6816 - val_sparse_categorical_crossentropy: 0.9507 - lr: 0.0100
# Epoch 13/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.9699 - sparse_categorical_accuracy: 0.6939 - sparse_categorical_crossentropy: 0.9699 - val_loss: 0.8839 - val_sparse_categorical_accuracy: 0.7239 - val_sparse_categorical_crossentropy: 0.8839 - lr: 0.0100
# Epoch 14/200
# 90/90 [==============================] - 11s 116ms/step - loss: 0.8516 - sparse_categorical_accuracy: 0.7272 - sparse_categorical_crossentropy: 0.8516 - val_loss: 0.8343 - val_sparse_categorical_accuracy: 0.7356 - val_sparse_categorical_crossentropy: 0.8343 - lr: 0.0100
# Epoch 15/200
# 90/90 [==============================] - 12s 119ms/step - loss: 0.8320 - sparse_categorical_accuracy: 0.7353 - sparse_categorical_crossentropy: 0.8320 - val_loss: 0.8785 - val_sparse_categorical_accuracy: 0.7141 - val_sparse_categorical_crossentropy: 0.8785 - lr: 0.0100
# Epoch 16/200
# 90/90 [==============================] - 11s 117ms/step - loss: 0.8638 - sparse_categorical_accuracy: 0.7232 - sparse_categorical_crossentropy: 0.8638 - val_loss: 0.8506 - val_sparse_categorical_accuracy: 0.7129 - val_sparse_categorical_crossentropy: 0.8506 - lr: 0.0100
# Epoch 17/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.8680 - sparse_categorical_accuracy: 0.7215 - sparse_categorical_crossentropy: 0.8680
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 90/90 [==============================] - 11s 117ms/step - loss: 0.8680 - sparse_categorical_accuracy: 0.7215 - sparse_categorical_crossentropy: 0.8680 - val_loss: 0.8144 - val_sparse_categorical_accuracy: 0.7328 - val_sparse_categorical_crossentropy: 0.8144 - lr: 0.0100
# Epoch 18/200
# 90/90 [==============================] - 11s 118ms/step - loss: 0.7691 - sparse_categorical_accuracy: 0.7566 - sparse_categorical_crossentropy: 0.7691 - val_loss: 0.7465 - val_sparse_categorical_accuracy: 0.7655 - val_sparse_categorical_crossentropy: 0.7465 - lr: 0.0050
# Epoch 19/200
# ...
# Epoch 7/200
# 90/90 [==============================] - 12s 127ms/step - loss: 1.2022 - sparse_categorical_accuracy: 0.6520 - sparse_categorical_crossentropy: 1.2022 - val_loss: 1.1761 - val_sparse_categorical_accuracy: 0.6562 - val_sparse_categorical_crossentropy: 1.1761 - lr: 0.0100
# Epoch 8/200
# 90/90 [==============================] - 12s 127ms/step - loss: 1.1508 - sparse_categorical_accuracy: 0.6613 - sparse_categorical_crossentropy: 1.1508 - val_loss: 1.0804 - val_sparse_categorical_accuracy: 0.6677 - val_sparse_categorical_crossentropy: 1.0804 - lr: 0.0100
# Epoch 9/200
# 90/90 [==============================] - 12s 129ms/step - loss: 1.0680 - sparse_categorical_accuracy: 0.6752 - sparse_categorical_crossentropy: 1.0680 - val_loss: 0.9959 - val_sparse_categorical_accuracy: 0.6762 - val_sparse_categorical_crossentropy: 0.9959 - lr: 0.0100
# Epoch 10/200
# 90/90 [==============================] - 12s 127ms/step - loss: 0.9934 - sparse_categorical_accuracy: 0.6869 - sparse_categorical_crossentropy: 0.9934 - val_loss: 0.9539 - val_sparse_categorical_accuracy: 0.6980 - val_sparse_categorical_crossentropy: 0.9539 - lr: 0.0100
# Epoch 11/200
# 90/90 [==============================] - 13s 129ms/step - loss: 0.9447 - sparse_categorical_accuracy: 0.7001 - sparse_categorical_crossentropy: 0.9447 - val_loss: 0.9182 - val_sparse_categorical_accuracy: 0.7031 - val_sparse_categorical_crossentropy: 0.9182 - lr: 0.0100
# Epoch 12/200
# 90/90 [==============================] - 12s 128ms/step - loss: 0.9225 - sparse_categorical_accuracy: 0.7164 - sparse_categorical_crossentropy: 0.9225 - val_loss: 0.8887 - val_sparse_categorical_accuracy: 0.7080 - val_sparse_categorical_crossentropy: 0.8887 - lr: 0.0100
# Epoch 13/200
# 90/90 [==============================] - 13s 130ms/step - loss: 0.8742 - sparse_categorical_accuracy: 0.7237 - sparse_categorical_crossentropy: 0.8742 - val_loss: 0.8952 - val_sparse_categorical_accuracy: 0.7100 - val_sparse_categorical_crossentropy: 0.8952 - lr: 0.0100
# Epoch 14/200
# 90/90 [==============================] - 12s 126ms/step - loss: 0.8632 - sparse_categorical_accuracy: 0.7281 - sparse_categorical_crossentropy: 0.8632 - val_loss: 0.8904 - val_sparse_categorical_accuracy: 0.7172 - val_sparse_categorical_crossentropy: 0.8904 - lr: 0.0100
# Epoch 15/200
# 90/90 [==============================] - 13s 129ms/step - loss: 0.8647 - sparse_categorical_accuracy: 0.7288 - sparse_categorical_crossentropy: 0.8647 - val_loss: 0.8288 - val_sparse_categorical_accuracy: 0.7319 - val_sparse_categorical_crossentropy: 0.8288 - lr: 0.0100
# Epoch 16/200
# 90/90 [==============================] - 13s 129ms/step - loss: 0.8231 - sparse_categorical_accuracy: 0.7398 - sparse_categorical_crossentropy: 0.8231 - val_loss: 0.7981 - val_sparse_categorical_accuracy: 0.7510 - val_sparse_categorical_crossentropy: 0.7981 - lr: 0.0100
# Epoch 17/200
# 90/90 [==============================] - 12s 128ms/step - loss: 0.7935 - sparse_categorical_accuracy: 0.7516 - sparse_categorical_crossentropy: 0.7935 - val_loss: 0.7655 - val_sparse_categorical_accuracy: 0.7634 - val_sparse_categorical_crossentropy: 0.7655 - lr: 0.0100
# Epoch 18/200
# 90/90 [==============================] - 13s 129ms/step - loss: 0.8293 - sparse_categorical_accuracy: 0.7436 - sparse_categorical_crossentropy: 0.8293 - val_loss: 0.7710 - val_sparse_categorical_accuracy: 0.7546 - val_sparse_categorical_crossentropy: 0.7710 - lr: 0.0100
# Epoch 19/200
# 90/90 [==============================] - 13s 129ms/step - loss: 0.7666 - sparse_categorical_accuracy: 0.7596 - sparse_categorical_crossentropy: 0.7666 - val_loss: 0.7587 - val_sparse_categorical_accuracy: 0.7571 - val_sparse_categorical_crossentropy: 0.7587 - lr: 0.0100
# Epoch 20/200
# 90/90 [==============================] - 12s 128ms/step - loss: 0.7670 - sparse_categorical_accuracy: 0.7590 - sparse_categorical_crossentropy: 0.7670 - val_loss: 0.7426 - val_sparse_categorical_accuracy: 0.7671 - val_sparse_categorical_crossentropy: 0.7426 - lr: 0.0100
# Epoch 21/200
# 90/90 [==============================] - 13s 131ms/step - loss: 0.7613 - sparse_categorical_accuracy: 0.7591 - sparse_categorical_crossentropy: 0.7613 - val_loss: 0.7116 - val_sparse_categorical_accuracy: 0.7723 - val_sparse_categorical_crossentropy: 0.7116 - lr: 0.0100
# Epoch 22/200
# 90/90 [==============================] - 12s 127ms/step - loss: 0.7589 - sparse_categorical_accuracy: 0.7579 - sparse_categorical_crossentropy: 0.7589 - val_loss: 0.6920 - val_sparse_categorical_accuracy: 0.7729 - val_sparse_categorical_crossentropy: 0.6920 - lr: 0.0100
# Epoch 23/200
# 90/90 [==============================] - 13s 131ms/step - loss: 0.7625 - sparse_categorical_accuracy: 0.7575 - sparse_categorical_crossentropy: 0.7625 - val_loss: 0.7595 - val_sparse_categorical_accuracy: 0.7573 - val_sparse_categorical_crossentropy: 0.7595 - lr: 0.0100
# Epoch 24/200
# 90/90 [==============================] - 12s 127ms/step - loss: 0.7616 - sparse_categorical_accuracy: 0.7649 - sparse_categorical_crossentropy: 0.7616 - val_loss: 0.7605 - val_sparse_categorical_accuracy: 0.7526 - val_sparse_categorical_crossentropy: 0.7605 - lr: 0.0100
# Epoch 25/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.8778 - sparse_categorical_accuracy: 0.7193 - sparse_categorical_crossentropy: 0.8778
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 90/90 [==============================] - 12s 127ms/step - loss: 0.8777 - sparse_categorical_accuracy: 0.7193 - sparse_categorical_crossentropy: 0.8777 - val_loss: 0.7620 - val_sparse_categorical_accuracy: 0.7582 - val_sparse_categorical_crossentropy: 0.7620 - lr: 0.0100
# Epoch 26/200
# 90/90 [==============================] - 13s 134ms/step - loss: 0.7246 - sparse_categorical_accuracy: 0.7708 - sparse_categorical_crossentropy: 0.7246 - val_loss: 0.6820 - val_sparse_categorical_accuracy: 0.7789 - val_sparse_categorical_crossentropy: 0.6820 - lr: 0.0050
# Epoch 27/200
# 90/90 [==============================] - 12s 128ms/step - loss: 0.6789 - sparse_categorical_accuracy: 0.7839 - sparse_categorical_crossentropy: 0.6789 - val_loss: 0.6446 - val_sparse_categorical_accuracy: 0.7949 - val_sparse_categorical_crossentropy: 0.6446 - lr: 0.0050
# Epoch 28/200
# 90/90 [==============================] - 12s 127ms/step - loss: 0.6846 - sparse_categorical_accuracy: 0.7851 - sparse_categorical_crossentropy: 0.6846 - val_loss: 0.6621 - val_sparse_categorical_accuracy: 0.7875 - val_sparse_categorical_crossentropy: 0.6621 - lr: 0.0050
# Epoch 29/200
# 90/90 [==============================] - 13s 128ms/step - loss: 0.6526 - sparse_categorical_accuracy: 0.7944 - sparse_categorical_crossentropy: 0.6526 - val_loss: 0.6399 - val_sparse_categorical_accuracy: 0.7946 - val_sparse_categorical_crossentropy: 0.6399 - lr: 0.0050
# Epoch 30/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.6477 - sparse_categorical_accuracy: 0.7942 - sparse_categorical_crossentropy: 0.6477
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 90/90 [==============================] - 13s 129ms/step - loss: 0.6476 - sparse_categorical_accuracy: 0.7942 - sparse_categorical_crossentropy: 0.6476 - val_loss: 0.6334 - val_sparse_categorical_accuracy: 0.7887 - val_sparse_categorical_crossentropy: 0.6334 - lr: 0.0050
# Epoch 31/200
# 90/90 [==============================] - 12s 127ms/step - loss: 0.6169 - sparse_categorical_accuracy: 0.8027 - sparse_categorical_crossentropy: 0.6169 - val_loss: 0.6153 - val_sparse_categorical_accuracy: 0.7964 - val_sparse_categorical_crossentropy: 0.6153 - lr: 0.0025
# Epoch 32/200
# 90/90 [==============================] - 12s 127ms/step - loss: 0.6050 - sparse_categorical_accuracy: 0.8072 - sparse_categorical_crossentropy: 0.6050 - val_loss: 0.6051 - val_sparse_categorical_accuracy: 0.7982 - val_sparse_categorical_crossentropy: 0.6051 - lr: 0.0025
# Epoch 33/200
# 90/90 [==============================] - 12s 126ms/step - loss: 0.6041 - sparse_categorical_accuracy: 0.8052 - sparse_categorical_crossentropy: 0.6041 - val_loss: 0.6013 - val_sparse_categorical_accuracy: 0.8041 - val_sparse_categorical_crossentropy: 0.6013 - lr: 0.0025
# Epoch 34/200
# 90/90 [==============================] - 12s 128ms/step - loss: 0.6008 - sparse_categorical_accuracy: 0.8047 - sparse_categorical_crossentropy: 0.6008 - val_loss: 0.5876 - val_sparse_categorical_accuracy: 0.8076 - val_sparse_categorical_crossentropy: 0.5876 - lr: 0.0025
# Epoch 35/200
# 90/90 [==============================] - 12s 127ms/step - loss: 0.5881 - sparse_categorical_accuracy: 0.8100 - sparse_categorical_crossentropy: 0.5881 - val_loss: 0.5829 - val_sparse_categorical_accuracy: 0.8127 - val_sparse_categorical_crossentropy: 0.5829 - lr: 0.0025
# Epoch 36/200
# 90/90 [==============================] - 12s 127ms/step - loss: 0.5785 - sparse_categorical_accuracy: 0.8128 - sparse_categorical_crossentropy: 0.5785 - val_loss: 0.5750 - val_sparse_categorical_accuracy: 0.8070 - val_sparse_categorical_crossentropy: 0.5750 - lr: 0.0025
# Epoch 37/200
# 90/90 [==============================] - 13s 130ms/step - loss: 0.5761 - sparse_categorical_accuracy: 0.8138 - sparse_categorical_crossentropy: 0.5761 - val_loss: 0.5782 - val_sparse_categorical_accuracy: 0.8111 - val_sparse_categorical_crossentropy: 0.5782 - lr: 0.0025
# Epoch 38/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.5724 - sparse_categorical_accuracy: 0.8152 - sparse_categorical_crossentropy: 0.5724
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 90/90 [==============================] - 13s 129ms/step - loss: 0.5723 - sparse_categorical_accuracy: 0.8151 - sparse_categorical_crossentropy: 0.5723 - val_loss: 0.5793 - val_sparse_categorical_accuracy: 0.8078 - val_sparse_categorical_crossentropy: 0.5793 - lr: 0.0025
# Epoch 39/200
# 90/90 [==============================] - 12s 126ms/step - loss: 0.5595 - sparse_categorical_accuracy: 0.8185 - sparse_categorical_crossentropy: 0.5595 - val_loss: 0.5655 - val_sparse_categorical_accuracy: 0.8145 - val_sparse_categorical_crossentropy: 0.5655 - lr: 0.0012
# Epoch 40/200
# 90/90 [==============================] - 12s 126ms/step - loss: 0.5526 - sparse_categorical_accuracy: 0.8213 - sparse_categorical_crossentropy: 0.5526 - val_loss: 0.5656 - val_sparse_categorical_accuracy: 0.8110 - val_sparse_categorical_crossentropy: 0.5656 - lr: 0.0012
# Epoch 41/200
# 90/90 [==============================] - 12s 126ms/step - loss: 0.5522 - sparse_categorical_accuracy: 0.8212 - sparse_categorical_crossentropy: 0.5522 - val_loss: 0.5678 - val_sparse_categorical_accuracy: 0.8125 - val_sparse_categorical_crossentropy: 0.5678 - lr: 0.0012
# Epoch 42/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.5487 - sparse_categorical_accuracy: 0.8229 - sparse_categorical_crossentropy: 0.5487
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 90/90 [==============================] - 12s 127ms/step - loss: 0.5486 - sparse_categorical_accuracy: 0.8229 - sparse_categorical_crossentropy: 0.5486 - val_loss: 0.5629 - val_sparse_categorical_accuracy: 0.8133 - val_sparse_categorical_crossentropy: 0.5629 - lr: 0.0012
# Epoch 43/200
# 90/90 [==============================] - 12s 127ms/step - loss: 0.5417 - sparse_categorical_accuracy: 0.8259 - sparse_categorical_crossentropy: 0.5417 - val_loss: 0.5582 - val_sparse_categorical_accuracy: 0.8154 - val_sparse_categorical_crossentropy: 0.5582 - lr: 6.2500e-04
# Epoch 44/200
# 90/90 [==============================] - 12s 126ms/step - loss: 0.5366 - sparse_categorical_accuracy: 0.8270 - sparse_categorical_crossentropy: 0.5366 - val_loss: 0.5534 - val_sparse_categorical_accuracy: 0.8165 - val_sparse_categorical_crossentropy: 0.5534 - lr: 6.2500e-04
# Epoch 45/200
# 90/90 [==============================] - 12s 126ms/step - loss: 0.5345 - sparse_categorical_accuracy: 0.8276 - sparse_categorical_crossentropy: 0.5345 - val_loss: 0.5513 - val_sparse_categorical_accuracy: 0.8145 - val_sparse_categorical_crossentropy: 0.5513 - lr: 6.2500e-04
# Epoch 46/200
# 90/90 [==============================] - 13s 129ms/step - loss: 0.5341 - sparse_categorical_accuracy: 0.8274 - sparse_categorical_crossentropy: 0.5341 - val_loss: 0.5518 - val_sparse_categorical_accuracy: 0.8151 - val_sparse_categorical_crossentropy: 0.5518 - lr: 6.2500e-04
# Epoch 47/200
# 90/90 [==============================] - 12s 128ms/step - loss: 0.5314 - sparse_categorical_accuracy: 0.8286 - sparse_categorical_crossentropy: 0.5314 - val_loss: 0.5495 - val_sparse_categorical_accuracy: 0.8185 - val_sparse_categorical_crossentropy: 0.5495 - lr: 6.2500e-04
# Epoch 48/200
# 90/90 [==============================] - 12s 128ms/step - loss: 0.5302 - sparse_categorical_accuracy: 0.8290 - sparse_categorical_crossentropy: 0.5302 - val_loss: 0.5476 - val_sparse_categorical_accuracy: 0.8171 - val_sparse_categorical_crossentropy: 0.5476 - lr: 6.2500e-04
# Epoch 49/200
# 90/90 [==============================] - 13s 129ms/step - loss: 0.5299 - sparse_categorical_accuracy: 0.8284 - sparse_categorical_crossentropy: 0.5299 - val_loss: 0.5457 - val_sparse_categorical_accuracy: 0.8188 - val_sparse_categorical_crossentropy: 0.5457 - lr: 6.2500e-04
# Epoch 50/200
# 90/90 [==============================] - 12s 127ms/step - loss: 0.5274 - sparse_categorical_accuracy: 0.8293 - sparse_categorical_crossentropy: 0.5274 - val_loss: 0.5445 - val_sparse_categorical_accuracy: 0.8177 - val_sparse_categorical_crossentropy: 0.5445 - lr: 6.2500e-04
# Epoch 51/200
# 90/90 [==============================] - 13s 128ms/step - loss: 0.5239 - sparse_categorical_accuracy: 0.8311 - sparse_categorical_crossentropy: 0.5239 - val_loss: 0.5448 - val_sparse_categorical_accuracy: 0.8202 - val_sparse_categorical_crossentropy: 0.5448 - lr: 6.2500e-04
# Epoch 52/200
# 90/90 [==============================] - 12s 127ms/step - loss: 0.5244 - sparse_categorical_accuracy: 0.8309 - sparse_categorical_crossentropy: 0.5244 - val_loss: 0.5397 - val_sparse_categorical_accuracy: 0.8213 - val_sparse_categorical_crossentropy: 0.5397 - lr: 6.2500e-04
# Epoch 53/200
# 90/90 [==============================] - 12s 129ms/step - loss: 0.5247 - sparse_categorical_accuracy: 0.8303 - sparse_categorical_crossentropy: 0.5247 - val_loss: 0.5438 - val_sparse_categorical_accuracy: 0.8162 - val_sparse_categorical_crossentropy: 0.5438 - lr: 6.2500e-04
# Epoch 54/200
# 90/90 [==============================] - 12s 128ms/step - loss: 0.5227 - sparse_categorical_accuracy: 0.8312 - sparse_categorical_crossentropy: 0.5227 - val_loss: 0.5408 - val_sparse_categorical_accuracy: 0.8201 - val_sparse_categorical_crossentropy: 0.5408 - lr: 6.2500e-04
# Epoch 55/200
# 89/90 [============================>.] - ETA: 0s - loss: 0.5219 - sparse_categorical_accuracy: 0.8318 - sparse_categorical_crossentropy: 0.5219
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 90/90 [==============================] - 12s 128ms/step - loss: 0.5218 - sparse_categorical_accuracy: 0.8319 - sparse_categorical_crossentropy: 0.5218 - val_loss: 0.5427 - val_sparse_categorical_accuracy: 0.8208 - val_sparse_categorical_crossentropy: 0.5427 - lr: 6.2500e-04
# Epoch 56/200
# 90/90 [==============================] - 13s 128ms/step - loss: 0.5185 - sparse_categorical_accuracy: 0.8329 - sparse_categorical_crossentropy: 0.5185 - val_loss: 0.5362 - val_sparse_categorical_accuracy: 0.8204 - val_sparse_categorical_crossentropy: 0.5362 - lr: 3.1250e-04
# Epoch 57/200
# 90/90 [==============================] - 12s 128ms/step - loss: 0.5155 - sparse_categorical_accuracy: 0.8338 - sparse_categorical_crossentropy: 0.5155 - val_loss: 0.5377 - val_sparse_categorical_accuracy: 0.8208 - val_sparse_categorical_crossentropy: 0.5377 - lr: 3.1250e-04
# 26/26 [==============================] - 3s 109ms/step - loss: 0.5570 - sparse_categorical_accuracy: 0.8238 - sparse_categorical_crossentropy: 0.5570
# 26/26 [==============================] - 4s 108ms/step

# %%
results
# Out:
#    seed      loss  sparse_categorical_accuracy  \
# 0     0  0.544547                     0.828547
# 1     1  0.674495                     0.798526
# 2     2  0.479161                     0.855037
# 3     3  0.335362                     0.900108
# 4     4  0.557034                     0.823787
#
#    sparse_categorical_crossentropy
# 0                         0.544547
# 1                         0.674495
# 2                         0.479161
# 3                         0.335362
# 4                         0.557034
