# %% [markdown]
# # Loading packages

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import os
import random
import gc
import keras_cv

from os import path
from matplotlib import pyplot as plt
from tensorflow.keras import layers, losses, optimizers, metrics, callbacks, Model, Input, regularizers
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.utils import image_dataset_from_directory

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.set_logical_device_configuration(
        gpus[0],
        [tf.config.LogicalDeviceConfiguration(memory_limit=9048)]
    )

logical_gpus = tf.config.list_logical_devices('GPU')
print(len(gpus), "Physical GPU,", len(logical_gpus), "Logical GPUs")
# Out:
# 1 Physical GPU, 1 Logical GPUs

# %%
SEED = 123
N_CLASS = 10
IMG_SIZE = 224
BATCH_SIZE = 512
AUTOTUNE = tf.data.AUTOTUNE

# %%
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# # Loading datasets

# %%
train_labels_df = pd.read_csv(path.join(os.getcwd(), '..', 'train_val_test', 'train.csv')).drop(["Unnamed: 0"], axis=1)

dataset_train = image_dataset_from_directory(
    directory=path.join(os.getcwd(), '..', 'train_val_test', 'train'),
    labels=list(train_labels_df['codes']),
    label_mode='int',
    validation_split=0,
    shuffle=True,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    seed=SEED
)

dataset_train = dataset_train.map(lambda x, y: (x, tf.one_hot(y, N_CLASS)))

val_labels_df = pd.read_csv(path.join(os.getcwd(), '..', 'train_val_test', 'val.csv')).drop(["Unnamed: 0"], axis=1)
dataset_val = image_dataset_from_directory(
    directory=path.join(os.getcwd(), '..', 'train_val_test', 'val'),
    labels=list(val_labels_df['codes']),
    label_mode='int',
    validation_split=0,
    shuffle=True,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    seed=SEED
)
dataset_val = dataset_val.map(lambda x, y: (preprocess_input(x), tf.one_hot(y, N_CLASS)))

test_labels_df = pd.read_csv(path.join(os.getcwd(), '..', 'train_val_test', 'test.csv')).drop(["Unnamed: 0"], axis=1)

dataset_test = image_dataset_from_directory(
    directory=path.join(os.getcwd(), '..','train_val_test', 'test'),
    labels=list(test_labels_df['codes']),
    label_mode='int',
    validation_split=0,
    shuffle=True,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    seed=SEED
)
dataset_test = dataset_test.map(lambda x, y: (preprocess_input(x), tf.one_hot(y, N_CLASS)))
# Out:
# Found 35000 files belonging to 1 classes.
# Found 5000 files belonging to 1 classes.
# Found 10000 files belonging to 1 classes.

# %%
def get_model():
    resnet = ResNet50(input_shape=(IMG_SIZE, IMG_SIZE, 3), weights="imagenet", include_top=False)

    for i, layer in enumerate(resnet.layers):
        if not layer.name.startswith('conv5'):
            layer.trainable = False

    x = layers.GlobalAveragePooling2D()(resnet.output)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(2048, activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    output = layers.Dense(N_CLASS, activation="softmax")(x)
    model = Model(resnet.input, output)
    return model

model = get_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 2048)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 2048)         4196352     ['dropout[0][0]']
#
#  batch_normalization (BatchNorm  (None, 2048)        8192        ['dense[0][0]']
#  alization)
#
#  dropout_1 (Dropout)            (None, 2048)         0           ['batch_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 10)           20490       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 27,812,746
# Trainable params: 19,196,938
# Non-trainable params: 8,615,808
# __________________________________________________________________________________________________

# %% [markdown]
# # Cut Mix - augmentation
# Source: [link](https://keras.io/examples/vision/cutmix/) <br>
# The CutMix function takes two image and label pairs to perform the augmentation. It samples $\lambda(l)$ from the Beta distribution and returns a bounding box from get_box function. We then crop the second image (image2) and pad this image in the final padded image at the same location.

# %%
cut_mix = keras_cv.layers.preprocessing.cut_mix.CutMix(seed=SEED)

def apply_cut_mix(x, y):
    samples = {"images": x, "labels": y}
    samples = cut_mix(samples, training=True)
    return samples["images"], samples["labels"]
    
dataset_train = dataset_train.map(apply_cut_mix, num_parallel_calls=AUTOTUNE)

# %%
image_batch, label_batch = next(iter(dataset_train))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype(np.uint8))
    plt.axis("off")

# %%
dataset_train = dataset_train.map(lambda x, y: (preprocess_input(x), y))

# %% [markdown]
# # Eksperymenty

# %%
early_stopping = callbacks.EarlyStopping(
    monitor='val_categorical_accuracy',
    min_delta=0,
    patience=5,
    verbose=0,
    mode='max',
    baseline=None,
    restore_best_weights=True
)

reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_categorical_accuracy', factor=0.5, patience=5, min_lr=0.00001, verbose=1)

# %%
TRAINING_SEEDS = list(range(10))
results = []
for seed in TRAINING_SEEDS:
    random.seed(seed)
    np.random.seed(SEED)
    tf.random.set_seed(seed)

    model = get_model()

    model.compile(
        optimizer=optimizers.Adam(learning_rate=0.001),
        loss=losses.CategoricalCrossentropy(),
        metrics=[metrics.CategoricalAccuracy(), metrics.CategoricalCrossentropy()]
    )

    history = model.fit(
        dataset_train,
        epochs=200,
        batch_size=BATCH_SIZE,
        validation_data=dataset_val,
        shuffle=True,
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )
    eval_results = model.evaluate(dataset_test, batch_size=BATCH_SIZE)

    results += [{
        'seed': seed,
        'results': dict(zip(model.metrics_names, eval_results))
    }]
    gc.collect()

results = pd.DataFrame(results)
results = pd.concat([results.drop(["results"], axis=1), results["results"].apply(pd.Series)], axis=1)
results.to_csv('cutmix.csv')
# Out:
# Epoch 1/200
# 69/69 [==============================] - 64s 704ms/step - loss: 1.7268 - categorical_accuracy: 0.5450 - categorical_crossentropy: 1.7268 - val_loss: 1.5047 - val_categorical_accuracy: 0.6536 - val_categorical_crossentropy: 1.5047 - lr: 0.0010
# Epoch 2/200
# 69/69 [==============================] - 52s 687ms/step - loss: 1.3584 - categorical_accuracy: 0.6319 - categorical_crossentropy: 1.3584 - val_loss: 2.5664 - val_categorical_accuracy: 0.8258 - val_categorical_crossentropy: 2.5664 - lr: 0.0010
# Epoch 3/200
# 69/69 [==============================] - 52s 688ms/step - loss: 1.2415 - categorical_accuracy: 0.6601 - categorical_crossentropy: 1.2415 - val_loss: 3.6923 - val_categorical_accuracy: 0.8158 - val_categorical_crossentropy: 3.6923 - lr: 0.0010
# Epoch 4/200
# 69/69 [==============================] - 52s 687ms/step - loss: 1.1729 - categorical_accuracy: 0.6802 - categorical_crossentropy: 1.1729 - val_loss: 0.5059 - val_categorical_accuracy: 0.9086 - val_categorical_crossentropy: 0.5059 - lr: 0.0010
# Epoch 5/200
# 69/69 [==============================] - 52s 685ms/step - loss: 1.1327 - categorical_accuracy: 0.6935 - categorical_crossentropy: 1.1327 - val_loss: 0.3713 - val_categorical_accuracy: 0.9046 - val_categorical_crossentropy: 0.3713 - lr: 0.0010
# Epoch 6/200
# 69/69 [==============================] - 52s 686ms/step - loss: 1.0965 - categorical_accuracy: 0.7044 - categorical_crossentropy: 1.0965 - val_loss: 1.5983 - val_categorical_accuracy: 0.8798 - val_categorical_crossentropy: 1.5983 - lr: 0.0010
# Epoch 7/200
# 69/69 [==============================] - 52s 687ms/step - loss: 1.1497 - categorical_accuracy: 0.6795 - categorical_crossentropy: 1.1497 - val_loss: 0.6102 - val_categorical_accuracy: 0.8998 - val_categorical_crossentropy: 0.6102 - lr: 0.0010
# Epoch 8/200
# 69/69 [==============================] - 52s 684ms/step - loss: 1.0781 - categorical_accuracy: 0.7027 - categorical_crossentropy: 1.0781 - val_loss: 0.4211 - val_categorical_accuracy: 0.9114 - val_categorical_crossentropy: 0.4211 - lr: 0.0010
# Epoch 9/200
# 69/69 [==============================] - 52s 689ms/step - loss: 1.0434 - categorical_accuracy: 0.7186 - categorical_crossentropy: 1.0434 - val_loss: 0.3347 - val_categorical_accuracy: 0.9238 - val_categorical_crossentropy: 0.3347 - lr: 0.0010
# Epoch 10/200
# 69/69 [==============================] - 52s 686ms/step - loss: 1.0431 - categorical_accuracy: 0.7175 - categorical_crossentropy: 1.0431 - val_loss: 0.4151 - val_categorical_accuracy: 0.9156 - val_categorical_crossentropy: 0.4151 - lr: 0.0010
# Epoch 11/200
# 69/69 [==============================] - 52s 691ms/step - loss: 0.9936 - categorical_accuracy: 0.7300 - categorical_crossentropy: 0.9936 - val_loss: 0.2612 - val_categorical_accuracy: 0.9316 - val_categorical_crossentropy: 0.2612 - lr: 0.0010
# Epoch 12/200
# 69/69 [==============================] - 52s 691ms/step - loss: 0.9805 - categorical_accuracy: 0.7391 - categorical_crossentropy: 0.9805 - val_loss: 0.2752 - val_categorical_accuracy: 0.9318 - val_categorical_crossentropy: 0.2752 - lr: 0.0010
# Epoch 13/200
# 69/69 [==============================] - 51s 687ms/step - loss: 1.0103 - categorical_accuracy: 0.7330 - categorical_crossentropy: 1.0103 - val_loss: 0.2988 - val_categorical_accuracy: 0.9236 - val_categorical_crossentropy: 0.2988 - lr: 0.0010
# Epoch 14/200
# 69/69 [==============================] - 52s 689ms/step - loss: 0.9859 - categorical_accuracy: 0.7373 - categorical_crossentropy: 0.9859 - val_loss: 0.2719 - val_categorical_accuracy: 0.9270 - val_categorical_crossentropy: 0.2719 - lr: 0.0010
# Epoch 15/200
# 69/69 [==============================] - 52s 688ms/step - loss: 0.9763 - categorical_accuracy: 0.7466 - categorical_crossentropy: 0.9763 - val_loss: 0.2566 - val_categorical_accuracy: 0.9358 - val_categorical_crossentropy: 0.2566 - lr: 0.0010
# Epoch 16/200
# 69/69 [==============================] - 52s 689ms/step - loss: 0.9402 - categorical_accuracy: 0.7578 - categorical_crossentropy: 0.9402 - val_loss: 0.2516 - val_categorical_accuracy: 0.9370 - val_categorical_crossentropy: 0.2516 - lr: 0.0010
# Epoch 17/200
# 69/69 [==============================] - 52s 689ms/step - loss: 0.9233 - categorical_accuracy: 0.7629 - categorical_crossentropy: 0.9233 - val_loss: 0.2697 - val_categorical_accuracy: 0.9308 - val_categorical_crossentropy: 0.2697 - lr: 0.0010
# Epoch 18/200
# 69/69 [==============================] - 52s 693ms/step - loss: 0.9161 - categorical_accuracy: 0.7670 - categorical_crossentropy: 0.9161 - val_loss: 0.2736 - val_categorical_accuracy: 0.9302 - val_categorical_crossentropy: 0.2736 - lr: 0.0010
# Epoch 19/200
# 69/69 [==============================] - 52s 686ms/step - loss: 0.9328 - categorical_accuracy: 0.7689 - categorical_crossentropy: 0.9328 - val_loss: 0.5961 - val_categorical_accuracy: 0.8758 - val_categorical_crossentropy: 0.5961 - lr: 0.0010
# Epoch 20/200
# 69/69 [==============================] - 52s 695ms/step - loss: 0.9099 - categorical_accuracy: 0.7716 - categorical_crossentropy: 0.9099 - val_loss: 0.2855 - val_categorical_accuracy: 0.9258 - val_categorical_crossentropy: 0.2855 - lr: 0.0010
# Epoch 21/200
# 69/69 [==============================] - ETA: 0s - loss: 0.8954 - categorical_accuracy: 0.7768 - categorical_crossentropy: 0.8954
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 69/69 [==============================] - 52s 690ms/step - loss: 0.8954 - categorical_accuracy: 0.7768 - categorical_crossentropy: 0.8954 - val_loss: 0.3950 - val_categorical_accuracy: 0.9180 - val_categorical_crossentropy: 0.3950 - lr: 0.0010
# 20/20 [==============================] - 12s 433ms/step - loss: 0.2539 - categorical_accuracy: 0.9364 - categorical_crossentropy: 0.2539
# Epoch 1/200
# 69/69 [==============================] - 56s 706ms/step - loss: 1.6945 - categorical_accuracy: 0.5494 - categorical_crossentropy: 1.6945 - val_loss: 0.8960 - val_categorical_accuracy: 0.7656 - val_categorical_crossentropy: 0.8960 - lr: 0.0010
# Epoch 2/200
# 69/69 [==============================] - 52s 699ms/step - loss: 1.4097 - categorical_accuracy: 0.6227 - categorical_crossentropy: 1.4097 - val_loss: 2.5798 - val_categorical_accuracy: 0.7162 - val_categorical_crossentropy: 2.5798 - lr: 0.0010
# Epoch 3/200
# 69/69 [==============================] - 52s 688ms/step - loss: 1.2618 - categorical_accuracy: 0.6548 - categorical_crossentropy: 1.2618 - val_loss: 0.7644 - val_categorical_accuracy: 0.8946 - val_categorical_crossentropy: 0.7644 - lr: 0.0010
# Epoch 4/200
# 69/69 [==============================] - 52s 688ms/step - loss: 1.1846 - categorical_accuracy: 0.6761 - categorical_crossentropy: 1.1846 - val_loss: 0.6593 - val_categorical_accuracy: 0.8924 - val_categorical_crossentropy: 0.6593 - lr: 0.0010
# Epoch 5/200
# 69/69 [==============================] - 53s 700ms/step - loss: 1.1412 - categorical_accuracy: 0.6905 - categorical_crossentropy: 1.1412 - val_loss: 1.7306 - val_categorical_accuracy: 0.8480 - val_categorical_crossentropy: 1.7306 - lr: 0.0010
# Epoch 6/200
# 69/69 [==============================] - 52s 691ms/step - loss: 1.1374 - categorical_accuracy: 0.6912 - categorical_crossentropy: 1.1374 - val_loss: 0.4456 - val_categorical_accuracy: 0.9176 - val_categorical_crossentropy: 0.4456 - lr: 0.0010
# Epoch 7/200
# 69/69 [==============================] - 52s 690ms/step - loss: 1.0789 - categorical_accuracy: 0.7012 - categorical_crossentropy: 1.0789 - val_loss: 0.4999 - val_categorical_accuracy: 0.8934 - val_categorical_crossentropy: 0.4999 - lr: 0.0010
# Epoch 8/200
# 69/69 [==============================] - 52s 693ms/step - loss: 1.0605 - categorical_accuracy: 0.7114 - categorical_crossentropy: 1.0605 - val_loss: 0.2920 - val_categorical_accuracy: 0.9298 - val_categorical_crossentropy: 0.2920 - lr: 0.0010
# Epoch 9/200
# 69/69 [==============================] - 52s 686ms/step - loss: 1.0301 - categorical_accuracy: 0.7188 - categorical_crossentropy: 1.0301 - val_loss: 0.3396 - val_categorical_accuracy: 0.9250 - val_categorical_crossentropy: 0.3396 - lr: 0.0010
# Epoch 10/200
# 69/69 [==============================] - 52s 689ms/step - loss: 1.0164 - categorical_accuracy: 0.7290 - categorical_crossentropy: 1.0164 - val_loss: 0.4013 - val_categorical_accuracy: 0.9112 - val_categorical_crossentropy: 0.4013 - lr: 0.0010
# Epoch 11/200
# 69/69 [==============================] - 52s 692ms/step - loss: 1.0045 - categorical_accuracy: 0.7361 - categorical_crossentropy: 1.0045 - val_loss: 2.8901 - val_categorical_accuracy: 0.8142 - val_categorical_crossentropy: 2.8901 - lr: 0.0010
# Epoch 12/200
# 69/69 [==============================] - 52s 692ms/step - loss: 1.0006 - categorical_accuracy: 0.7345 - categorical_crossentropy: 1.0006 - val_loss: 0.3092 - val_categorical_accuracy: 0.9202 - val_categorical_crossentropy: 0.3092 - lr: 0.0010
# Epoch 13/200
# 69/69 [==============================] - ETA: 0s - loss: 0.9809 - categorical_accuracy: 0.7447 - categorical_crossentropy: 0.9809
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 69/69 [==============================] - 52s 689ms/step - loss: 0.9809 - categorical_accuracy: 0.7447 - categorical_crossentropy: 0.9809 - val_loss: 0.3113 - val_categorical_accuracy: 0.9156 - val_categorical_crossentropy: 0.3113 - lr: 0.0010
# 20/20 [==============================] - 12s 429ms/step - loss: 0.2970 - categorical_accuracy: 0.9309 - categorical_crossentropy: 0.2970
# Epoch 1/200
# 69/69 [==============================] - 56s 711ms/step - loss: 1.6977 - categorical_accuracy: 0.5509 - categorical_crossentropy: 1.6977 - val_loss: 1.1774 - val_categorical_accuracy: 0.6768 - val_categorical_crossentropy: 1.1774 - lr: 0.0010
# Epoch 2/200
# 69/69 [==============================] - 52s 694ms/step - loss: 1.3641 - categorical_accuracy: 0.6312 - categorical_crossentropy: 1.3641 - val_loss: 4.8510 - val_categorical_accuracy: 0.7514 - val_categorical_crossentropy: 4.8510 - lr: 0.0010
# Epoch 3/200
# 69/69 [==============================] - 52s 696ms/step - loss: 1.2416 - categorical_accuracy: 0.6615 - categorical_crossentropy: 1.2416 - val_loss: 0.8872 - val_categorical_accuracy: 0.8794 - val_categorical_crossentropy: 0.8872 - lr: 0.0010
# Epoch 4/200
# 69/69 [==============================] - 52s 691ms/step - loss: 1.1512 - categorical_accuracy: 0.6825 - categorical_crossentropy: 1.1512 - val_loss: 0.5771 - val_categorical_accuracy: 0.9146 - val_categorical_crossentropy: 0.5771 - lr: 0.0010
# Epoch 5/200
# 69/69 [==============================] - 52s 692ms/step - loss: 1.1144 - categorical_accuracy: 0.6925 - categorical_crossentropy: 1.1144 - val_loss: 0.4348 - val_categorical_accuracy: 0.9252 - val_categorical_crossentropy: 0.4348 - lr: 0.0010
# Epoch 6/200
# 69/69 [==============================] - 52s 694ms/step - loss: 1.1669 - categorical_accuracy: 0.6839 - categorical_crossentropy: 1.1669 - val_loss: 0.6048 - val_categorical_accuracy: 0.8676 - val_categorical_crossentropy: 0.6048 - lr: 0.0010
# Epoch 7/200
# 69/69 [==============================] - 52s 688ms/step - loss: 1.1147 - categorical_accuracy: 0.7021 - categorical_crossentropy: 1.1147 - val_loss: 1.4961 - val_categorical_accuracy: 0.8490 - val_categorical_crossentropy: 1.4961 - lr: 0.0010
# Epoch 8/200
# 69/69 [==============================] - 52s 693ms/step - loss: 1.0853 - categorical_accuracy: 0.7097 - categorical_crossentropy: 1.0853 - val_loss: 0.3547 - val_categorical_accuracy: 0.9122 - val_categorical_crossentropy: 0.3547 - lr: 0.0010
# Epoch 9/200
# 69/69 [==============================] - 52s 697ms/step - loss: 1.0443 - categorical_accuracy: 0.7215 - categorical_crossentropy: 1.0443 - val_loss: 0.2967 - val_categorical_accuracy: 0.9294 - val_categorical_crossentropy: 0.2967 - lr: 0.0010
# Epoch 10/200
# 69/69 [==============================] - 52s 692ms/step - loss: 1.0227 - categorical_accuracy: 0.7240 - categorical_crossentropy: 1.0227 - val_loss: 0.6257 - val_categorical_accuracy: 0.9172 - val_categorical_crossentropy: 0.6257 - lr: 0.0010
# Epoch 11/200
# 69/69 [==============================] - 52s 694ms/step - loss: 1.0102 - categorical_accuracy: 0.7353 - categorical_crossentropy: 1.0102 - val_loss: 0.3188 - val_categorical_accuracy: 0.9226 - val_categorical_crossentropy: 0.3188 - lr: 0.0010
# Epoch 12/200
# 69/69 [==============================] - 52s 690ms/step - loss: 1.0125 - categorical_accuracy: 0.7386 - categorical_crossentropy: 1.0125 - val_loss: 2.8934 - val_categorical_accuracy: 0.8656 - val_categorical_crossentropy: 2.8934 - lr: 0.0010
# Epoch 13/200
# 69/69 [==============================] - 52s 690ms/step - loss: 0.9831 - categorical_accuracy: 0.7416 - categorical_crossentropy: 0.9831 - val_loss: 0.2853 - val_categorical_accuracy: 0.9348 - val_categorical_crossentropy: 0.2853 - lr: 0.0010
# Epoch 14/200
# 69/69 [==============================] - 52s 693ms/step - loss: 0.9655 - categorical_accuracy: 0.7505 - categorical_crossentropy: 0.9655 - val_loss: 0.2830 - val_categorical_accuracy: 0.9220 - val_categorical_crossentropy: 0.2830 - lr: 0.0010
# Epoch 15/200
# 69/69 [==============================] - 52s 686ms/step - loss: 0.9518 - categorical_accuracy: 0.7584 - categorical_crossentropy: 0.9518 - val_loss: 0.4591 - val_categorical_accuracy: 0.9286 - val_categorical_crossentropy: 0.4591 - lr: 0.0010
# Epoch 16/200
# 69/69 [==============================] - 51s 685ms/step - loss: 0.9380 - categorical_accuracy: 0.7623 - categorical_crossentropy: 0.9380 - val_loss: 0.2989 - val_categorical_accuracy: 0.9224 - val_categorical_crossentropy: 0.2989 - lr: 0.0010
# Epoch 17/200
# 69/69 [==============================] - 52s 690ms/step - loss: 0.9471 - categorical_accuracy: 0.7664 - categorical_crossentropy: 0.9471 - val_loss: 0.3490 - val_categorical_accuracy: 0.9252 - val_categorical_crossentropy: 0.3490 - lr: 0.0010
# Epoch 18/200
# 69/69 [==============================] - ETA: 0s - loss: 0.9492 - categorical_accuracy: 0.7602 - categorical_crossentropy: 0.9492
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 69/69 [==============================] - 52s 690ms/step - loss: 0.9492 - categorical_accuracy: 0.7602 - categorical_crossentropy: 0.9492 - val_loss: 0.8675 - val_categorical_accuracy: 0.8838 - val_categorical_crossentropy: 0.8675 - lr: 0.0010
# 20/20 [==============================] - 12s 427ms/step - loss: 0.2896 - categorical_accuracy: 0.9319 - categorical_crossentropy: 0.2896
# Epoch 1/200
# 69/69 [==============================] - 56s 705ms/step - loss: 1.7129 - categorical_accuracy: 0.5497 - categorical_crossentropy: 1.7129 - val_loss: 0.9935 - val_categorical_accuracy: 0.7148 - val_categorical_crossentropy: 0.9935 - lr: 0.0010
# Epoch 2/200
# 69/69 [==============================] - 52s 691ms/step - loss: 1.3605 - categorical_accuracy: 0.6338 - categorical_crossentropy: 1.3605 - val_loss: 1.0891 - val_categorical_accuracy: 0.8372 - val_categorical_crossentropy: 1.0891 - lr: 0.0010
# Epoch 3/200
# 69/69 [==============================] - 52s 688ms/step - loss: 1.2378 - categorical_accuracy: 0.6592 - categorical_crossentropy: 1.2378 - val_loss: 0.6823 - val_categorical_accuracy: 0.9098 - val_categorical_crossentropy: 0.6823 - lr: 0.0010
# Epoch 4/200
# 69/69 [==============================] - 52s 689ms/step - loss: 1.1672 - categorical_accuracy: 0.6783 - categorical_crossentropy: 1.1672 - val_loss: 0.8213 - val_categorical_accuracy: 0.8812 - val_categorical_crossentropy: 0.8213 - lr: 0.0010
# Epoch 5/200
# 69/69 [==============================] - 52s 689ms/step - loss: 1.1474 - categorical_accuracy: 0.6887 - categorical_crossentropy: 1.1474 - val_loss: 5.2300 - val_categorical_accuracy: 0.8066 - val_categorical_crossentropy: 5.2300 - lr: 0.0010
# Epoch 6/200
# 69/69 [==============================] - 52s 688ms/step - loss: 1.1040 - categorical_accuracy: 0.6975 - categorical_crossentropy: 1.1040 - val_loss: 0.3893 - val_categorical_accuracy: 0.9148 - val_categorical_crossentropy: 0.3893 - lr: 0.0010
# Epoch 7/200
# 69/69 [==============================] - 52s 691ms/step - loss: 1.0672 - categorical_accuracy: 0.7138 - categorical_crossentropy: 1.0672 - val_loss: 0.3840 - val_categorical_accuracy: 0.9058 - val_categorical_crossentropy: 0.3840 - lr: 0.0010
# Epoch 8/200
# 69/69 [==============================] - 52s 690ms/step - loss: 1.0502 - categorical_accuracy: 0.7193 - categorical_crossentropy: 1.0502 - val_loss: 0.2935 - val_categorical_accuracy: 0.9230 - val_categorical_crossentropy: 0.2935 - lr: 0.0010
# Epoch 9/200
# 69/69 [==============================] - 53s 710ms/step - loss: 1.0294 - categorical_accuracy: 0.7271 - categorical_crossentropy: 1.0294 - val_loss: 0.3227 - val_categorical_accuracy: 0.9104 - val_categorical_crossentropy: 0.3227 - lr: 0.0010
# Epoch 10/200
# 69/69 [==============================] - 53s 700ms/step - loss: 1.0446 - categorical_accuracy: 0.7226 - categorical_crossentropy: 1.0446 - val_loss: 0.2776 - val_categorical_accuracy: 0.9264 - val_categorical_crossentropy: 0.2776 - lr: 0.0010
# Epoch 11/200
# 69/69 [==============================] - 52s 696ms/step - loss: 1.0195 - categorical_accuracy: 0.7298 - categorical_crossentropy: 1.0195 - val_loss: 0.5530 - val_categorical_accuracy: 0.8582 - val_categorical_crossentropy: 0.5530 - lr: 0.0010
# Epoch 12/200
# 69/69 [==============================] - 52s 702ms/step - loss: 0.9823 - categorical_accuracy: 0.7488 - categorical_crossentropy: 0.9823 - val_loss: 0.2952 - val_categorical_accuracy: 0.9272 - val_categorical_crossentropy: 0.2952 - lr: 0.0010
# Epoch 13/200
# 69/69 [==============================] - 53s 701ms/step - loss: 0.9545 - categorical_accuracy: 0.7605 - categorical_crossentropy: 0.9545 - val_loss: 0.2837 - val_categorical_accuracy: 0.9288 - val_categorical_crossentropy: 0.2837 - lr: 0.0010
# Epoch 14/200
# 69/69 [==============================] - 52s 701ms/step - loss: 0.9477 - categorical_accuracy: 0.7638 - categorical_crossentropy: 0.9477 - val_loss: 0.2864 - val_categorical_accuracy: 0.9350 - val_categorical_crossentropy: 0.2864 - lr: 0.0010
# Epoch 15/200
# 69/69 [==============================] - 53s 700ms/step - loss: 0.9965 - categorical_accuracy: 0.7440 - categorical_crossentropy: 0.9965 - val_loss: 0.3942 - val_categorical_accuracy: 0.9006 - val_categorical_crossentropy: 0.3942 - lr: 0.0010
# Epoch 16/200
# 69/69 [==============================] - 52s 696ms/step - loss: 0.9371 - categorical_accuracy: 0.7680 - categorical_crossentropy: 0.9371 - val_loss: 0.3066 - val_categorical_accuracy: 0.9186 - val_categorical_crossentropy: 0.3066 - lr: 0.0010
# Epoch 17/200
# 69/69 [==============================] - 52s 700ms/step - loss: 0.9282 - categorical_accuracy: 0.7777 - categorical_crossentropy: 0.9282 - val_loss: 0.3066 - val_categorical_accuracy: 0.9218 - val_categorical_crossentropy: 0.3066 - lr: 0.0010
# Epoch 18/200
# 69/69 [==============================] - 53s 700ms/step - loss: 0.9798 - categorical_accuracy: 0.7643 - categorical_crossentropy: 0.9798 - val_loss: 1.0091 - val_categorical_accuracy: 0.8992 - val_categorical_crossentropy: 1.0091 - lr: 0.0010
# Epoch 19/200
# 69/69 [==============================] - ETA: 0s - loss: 0.9454 - categorical_accuracy: 0.7792 - categorical_crossentropy: 0.9454
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 69/69 [==============================] - 52s 702ms/step - loss: 0.9454 - categorical_accuracy: 0.7792 - categorical_crossentropy: 0.9454 - val_loss: 0.2708 - val_categorical_accuracy: 0.9328 - val_categorical_crossentropy: 0.2708 - lr: 0.0010
# 20/20 [==============================] - 12s 434ms/step - loss: 0.2763 - categorical_accuracy: 0.9348 - categorical_crossentropy: 0.2763
# Epoch 1/200
# 69/69 [==============================] - 56s 712ms/step - loss: 1.7067 - categorical_accuracy: 0.5503 - categorical_crossentropy: 1.7067 - val_loss: 2.6843 - val_categorical_accuracy: 0.4702 - val_categorical_crossentropy: 2.6843 - lr: 0.0010
# Epoch 2/200
# 69/69 [==============================] - 52s 702ms/step - loss: 1.3630 - categorical_accuracy: 0.6319 - categorical_crossentropy: 1.3630 - val_loss: 11.1486 - val_categorical_accuracy: 0.6266 - val_categorical_crossentropy: 11.1486 - lr: 0.0010
# Epoch 3/200
# 69/69 [==============================] - 53s 711ms/step - loss: 1.2550 - categorical_accuracy: 0.6558 - categorical_crossentropy: 1.2550 - val_loss: 0.8011 - val_categorical_accuracy: 0.9034 - val_categorical_crossentropy: 0.8011 - lr: 0.0010
# Epoch 4/200
# 69/69 [==============================] - 52s 688ms/step - loss: 1.1810 - categorical_accuracy: 0.6785 - categorical_crossentropy: 1.1810 - val_loss: 0.5677 - val_categorical_accuracy: 0.9020 - val_categorical_crossentropy: 0.5677 - lr: 0.0010
# Epoch 5/200
# 69/69 [==============================] - 52s 691ms/step - loss: 1.1444 - categorical_accuracy: 0.6869 - categorical_crossentropy: 1.1444 - val_loss: 0.4121 - val_categorical_accuracy: 0.9120 - val_categorical_crossentropy: 0.4121 - lr: 0.0010
# Epoch 6/200
# 69/69 [==============================] - 52s 690ms/step - loss: 1.1121 - categorical_accuracy: 0.6944 - categorical_crossentropy: 1.1121 - val_loss: 35.4403 - val_categorical_accuracy: 0.4686 - val_categorical_crossentropy: 35.4403 - lr: 0.0010
# Epoch 7/200
# 69/69 [==============================] - 52s 688ms/step - loss: 1.0650 - categorical_accuracy: 0.7060 - categorical_crossentropy: 1.0650 - val_loss: 0.3885 - val_categorical_accuracy: 0.9062 - val_categorical_crossentropy: 0.3885 - lr: 0.0010
# Epoch 8/200
# 69/69 [==============================] - 52s 694ms/step - loss: 1.0393 - categorical_accuracy: 0.7178 - categorical_crossentropy: 1.0393 - val_loss: 0.3223 - val_categorical_accuracy: 0.9194 - val_categorical_crossentropy: 0.3223 - lr: 0.0010
# Epoch 9/200
# 69/69 [==============================] - 52s 697ms/step - loss: 1.0368 - categorical_accuracy: 0.7229 - categorical_crossentropy: 1.0368 - val_loss: 0.8128 - val_categorical_accuracy: 0.9054 - val_categorical_crossentropy: 0.8128 - lr: 0.0010
# Epoch 10/200
# 69/69 [==============================] - 52s 692ms/step - loss: 1.0279 - categorical_accuracy: 0.7231 - categorical_crossentropy: 1.0279 - val_loss: 0.3858 - val_categorical_accuracy: 0.9044 - val_categorical_crossentropy: 0.3858 - lr: 0.0010
# Epoch 11/200
# 69/69 [==============================] - 52s 692ms/step - loss: 0.9962 - categorical_accuracy: 0.7334 - categorical_crossentropy: 0.9962 - val_loss: 0.6575 - val_categorical_accuracy: 0.9166 - val_categorical_crossentropy: 0.6575 - lr: 0.0010
# Epoch 12/200
# 69/69 [==============================] - 52s 697ms/step - loss: 0.9917 - categorical_accuracy: 0.7395 - categorical_crossentropy: 0.9917 - val_loss: 0.3212 - val_categorical_accuracy: 0.9088 - val_categorical_crossentropy: 0.3212 - lr: 0.0010
# Epoch 13/200
# 69/69 [==============================] - ETA: 0s - loss: 0.9865 - categorical_accuracy: 0.7403 - categorical_crossentropy: 0.9865
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 69/69 [==============================] - 52s 694ms/step - loss: 0.9865 - categorical_accuracy: 0.7403 - categorical_crossentropy: 0.9865 - val_loss: 0.4923 - val_categorical_accuracy: 0.9162 - val_categorical_crossentropy: 0.4923 - lr: 0.0010
# 20/20 [==============================] - 12s 436ms/step - loss: 0.3198 - categorical_accuracy: 0.9209 - categorical_crossentropy: 0.3198
# Epoch 1/200
# 69/69 [==============================] - 57s 716ms/step - loss: 1.7664 - categorical_accuracy: 0.5444 - categorical_crossentropy: 1.7664 - val_loss: 1.7043 - val_categorical_accuracy: 0.7028 - val_categorical_crossentropy: 1.7043 - lr: 0.0010
# Epoch 2/200
# 69/69 [==============================] - 52s 702ms/step - loss: 1.3728 - categorical_accuracy: 0.6280 - categorical_crossentropy: 1.3728 - val_loss: 1.0738 - val_categorical_accuracy: 0.8850 - val_categorical_crossentropy: 1.0738 - lr: 0.0010
# Epoch 3/200
# 69/69 [==============================] - 52s 700ms/step - loss: 1.2469 - categorical_accuracy: 0.6603 - categorical_crossentropy: 1.2469 - val_loss: 17.4917 - val_categorical_accuracy: 0.7046 - val_categorical_crossentropy: 17.4917 - lr: 0.0010
# Epoch 4/200
# 69/69 [==============================] - 52s 698ms/step - loss: 1.1918 - categorical_accuracy: 0.6770 - categorical_crossentropy: 1.1918 - val_loss: 0.6770 - val_categorical_accuracy: 0.8790 - val_categorical_crossentropy: 0.6770 - lr: 0.0010
# Epoch 5/200
# 69/69 [==============================] - 53s 701ms/step - loss: 1.1335 - categorical_accuracy: 0.6951 - categorical_crossentropy: 1.1335 - val_loss: 1.5634 - val_categorical_accuracy: 0.8736 - val_categorical_crossentropy: 1.5634 - lr: 0.0010
# Epoch 6/200
# 69/69 [==============================] - 53s 705ms/step - loss: 1.1113 - categorical_accuracy: 0.6973 - categorical_crossentropy: 1.1113 - val_loss: 0.3957 - val_categorical_accuracy: 0.9232 - val_categorical_crossentropy: 0.3957 - lr: 0.0010
# Epoch 7/200
# 69/69 [==============================] - 52s 697ms/step - loss: 1.0837 - categorical_accuracy: 0.7083 - categorical_crossentropy: 1.0837 - val_loss: 23.1494 - val_categorical_accuracy: 0.6088 - val_categorical_crossentropy: 23.1494 - lr: 0.0010
# Epoch 8/200
# 69/69 [==============================] - 52s 691ms/step - loss: 1.0488 - categorical_accuracy: 0.7171 - categorical_crossentropy: 1.0488 - val_loss: 0.3500 - val_categorical_accuracy: 0.9180 - val_categorical_crossentropy: 0.3500 - lr: 0.0010
# Epoch 9/200
# 69/69 [==============================] - 52s 690ms/step - loss: 1.0422 - categorical_accuracy: 0.7158 - categorical_crossentropy: 1.0422 - val_loss: 0.2561 - val_categorical_accuracy: 0.9330 - val_categorical_crossentropy: 0.2561 - lr: 0.0010
# Epoch 10/200
# 69/69 [==============================] - 52s 691ms/step - loss: 1.0199 - categorical_accuracy: 0.7272 - categorical_crossentropy: 1.0199 - val_loss: 0.5892 - val_categorical_accuracy: 0.9090 - val_categorical_crossentropy: 0.5892 - lr: 0.0010
# Epoch 11/200
# 69/69 [==============================] - 52s 691ms/step - loss: 0.9938 - categorical_accuracy: 0.7339 - categorical_crossentropy: 0.9938 - val_loss: 0.3166 - val_categorical_accuracy: 0.9188 - val_categorical_crossentropy: 0.3166 - lr: 0.0010
# Epoch 12/200
# 69/69 [==============================] - 52s 693ms/step - loss: 1.0109 - categorical_accuracy: 0.7350 - categorical_crossentropy: 1.0109 - val_loss: 0.3346 - val_categorical_accuracy: 0.9246 - val_categorical_crossentropy: 0.3346 - lr: 0.0010
# Epoch 13/200
# 69/69 [==============================] - 93s 1s/step - loss: 0.9818 - categorical_accuracy: 0.7422 - categorical_crossentropy: 0.9818 - val_loss: 0.2875 - val_categorical_accuracy: 0.9358 - val_categorical_crossentropy: 0.2875 - lr: 0.0010
# Epoch 14/200
# 69/69 [==============================] - 52s 686ms/step - loss: 0.9585 - categorical_accuracy: 0.7559 - categorical_crossentropy: 0.9585 - val_loss: 0.3022 - val_categorical_accuracy: 0.9288 - val_categorical_crossentropy: 0.3022 - lr: 0.0010
# Epoch 15/200
# 69/69 [==============================] - 52s 689ms/step - loss: 0.9373 - categorical_accuracy: 0.7630 - categorical_crossentropy: 0.9373 - val_loss: 0.3031 - val_categorical_accuracy: 0.9256 - val_categorical_crossentropy: 0.3031 - lr: 0.0010
# Epoch 16/200
# 69/69 [==============================] - 52s 689ms/step - loss: 0.9356 - categorical_accuracy: 0.7661 - categorical_crossentropy: 0.9356 - val_loss: 0.5684 - val_categorical_accuracy: 0.9120 - val_categorical_crossentropy: 0.5684 - lr: 0.0010
# Epoch 17/200
# 69/69 [==============================] - 110s 2s/step - loss: 0.9447 - categorical_accuracy: 0.7697 - categorical_crossentropy: 0.9447 - val_loss: 0.2919 - val_categorical_accuracy: 0.9214 - val_categorical_crossentropy: 0.2919 - lr: 0.0010
# Epoch 18/200
# 69/69 [==============================] - ETA: 0s - loss: 0.9627 - categorical_accuracy: 0.7687 - categorical_crossentropy: 0.9627
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 69/69 [==============================] - 135s 2s/step - loss: 0.9627 - categorical_accuracy: 0.7687 - categorical_crossentropy: 0.9627 - val_loss: 2.9863 - val_categorical_accuracy: 0.8834 - val_categorical_crossentropy: 2.9863 - lr: 0.0010
# 20/20 [==============================] - 19s 713ms/step - loss: 0.2860 - categorical_accuracy: 0.9357 - categorical_crossentropy: 0.2860
# Epoch 1/200
# 69/69 [==============================] - 294s 4s/step - loss: 1.7199 - categorical_accuracy: 0.5455 - categorical_crossentropy: 1.7199 - val_loss: 1.1905 - val_categorical_accuracy: 0.6390 - val_categorical_crossentropy: 1.1905 - lr: 0.0010
# Epoch 2/200
# 69/69 [==============================] - 183s 3s/step - loss: 1.3625 - categorical_accuracy: 0.6338 - categorical_crossentropy: 1.3625 - val_loss: 144.3579 - val_categorical_accuracy: 0.2924 - val_categorical_crossentropy: 144.3578 - lr: 0.0010
# Epoch 3/200
# 69/69 [==============================] - 52s 693ms/step - loss: 1.2876 - categorical_accuracy: 0.6501 - categorical_crossentropy: 1.2876 - val_loss: 0.9042 - val_categorical_accuracy: 0.8554 - val_categorical_crossentropy: 0.9042 - lr: 0.0010
# Epoch 4/200
# 69/69 [==============================] - 52s 694ms/step - loss: 1.2066 - categorical_accuracy: 0.6706 - categorical_crossentropy: 1.2066 - val_loss: 1.2356 - val_categorical_accuracy: 0.8592 - val_categorical_crossentropy: 1.2356 - lr: 0.0010
# Epoch 5/200
# 69/69 [==============================] - 52s 689ms/step - loss: 1.1755 - categorical_accuracy: 0.6771 - categorical_crossentropy: 1.1755 - val_loss: 7.9648 - val_categorical_accuracy: 0.7606 - val_categorical_crossentropy: 7.9648 - lr: 0.0010
# Epoch 6/200
# 69/69 [==============================] - 52s 692ms/step - loss: 1.1327 - categorical_accuracy: 0.6843 - categorical_crossentropy: 1.1327 - val_loss: 0.4310 - val_categorical_accuracy: 0.9094 - val_categorical_crossentropy: 0.4310 - lr: 0.0010
# Epoch 7/200
# 69/69 [==============================] - 52s 694ms/step - loss: 1.1038 - categorical_accuracy: 0.7001 - categorical_crossentropy: 1.1038 - val_loss: 0.4593 - val_categorical_accuracy: 0.9178 - val_categorical_crossentropy: 0.4593 - lr: 0.0010
# Epoch 8/200
# 69/69 [==============================] - 52s 696ms/step - loss: 1.0610 - categorical_accuracy: 0.7113 - categorical_crossentropy: 1.0610 - val_loss: 0.3474 - val_categorical_accuracy: 0.9256 - val_categorical_crossentropy: 0.3474 - lr: 0.0010
# Epoch 9/200
# 69/69 [==============================] - 52s 697ms/step - loss: 1.0569 - categorical_accuracy: 0.7111 - categorical_crossentropy: 1.0569 - val_loss: 0.3159 - val_categorical_accuracy: 0.9182 - val_categorical_crossentropy: 0.3159 - lr: 0.0010
# Epoch 10/200
# 69/69 [==============================] - 52s 697ms/step - loss: 1.0166 - categorical_accuracy: 0.7254 - categorical_crossentropy: 1.0166 - val_loss: 0.2907 - val_categorical_accuracy: 0.9234 - val_categorical_crossentropy: 0.2907 - lr: 0.0010
# Epoch 11/200
# 69/69 [==============================] - 52s 695ms/step - loss: 1.0204 - categorical_accuracy: 0.7288 - categorical_crossentropy: 1.0204 - val_loss: 2.6628 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.6628 - lr: 0.0010
# Epoch 12/200
# 69/69 [==============================] - 53s 700ms/step - loss: 0.9939 - categorical_accuracy: 0.7361 - categorical_crossentropy: 0.9939 - val_loss: 0.2943 - val_categorical_accuracy: 0.9318 - val_categorical_crossentropy: 0.2943 - lr: 0.0010
# Epoch 13/200
# 69/69 [==============================] - 52s 694ms/step - loss: 0.9767 - categorical_accuracy: 0.7430 - categorical_crossentropy: 0.9767 - val_loss: 0.3026 - val_categorical_accuracy: 0.9136 - val_categorical_crossentropy: 0.3026 - lr: 0.0010
# Epoch 14/200
# 69/69 [==============================] - 52s 694ms/step - loss: 0.9752 - categorical_accuracy: 0.7493 - categorical_crossentropy: 0.9752 - val_loss: 0.2949 - val_categorical_accuracy: 0.9264 - val_categorical_crossentropy: 0.2949 - lr: 0.0010
# Epoch 15/200
# 69/69 [==============================] - 52s 694ms/step - loss: 0.9431 - categorical_accuracy: 0.7545 - categorical_crossentropy: 0.9431 - val_loss: 0.2514 - val_categorical_accuracy: 0.9316 - val_categorical_crossentropy: 0.2514 - lr: 0.0010
# Epoch 16/200
# 69/69 [==============================] - 52s 697ms/step - loss: 0.9608 - categorical_accuracy: 0.7495 - categorical_crossentropy: 0.9608 - val_loss: 0.3579 - val_categorical_accuracy: 0.9062 - val_categorical_crossentropy: 0.3579 - lr: 0.0010
# Epoch 17/200
# 69/69 [==============================] - ETA: 0s - loss: 0.9321 - categorical_accuracy: 0.7656 - categorical_crossentropy: 0.9321
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 69/69 [==============================] - 52s 699ms/step - loss: 0.9321 - categorical_accuracy: 0.7656 - categorical_crossentropy: 0.9321 - val_loss: 0.5129 - val_categorical_accuracy: 0.9044 - val_categorical_crossentropy: 0.5129 - lr: 0.0010
# 20/20 [==============================] - 12s 430ms/step - loss: 0.3046 - categorical_accuracy: 0.9264 - categorical_crossentropy: 0.3046
# Epoch 1/200
# 69/69 [==============================] - 58s 742ms/step - loss: 1.7457 - categorical_accuracy: 0.5396 - categorical_crossentropy: 1.7457 - val_loss: 9.7696 - val_categorical_accuracy: 0.6134 - val_categorical_crossentropy: 9.7696 - lr: 0.0010
# Epoch 2/200
# 69/69 [==============================] - 62s 836ms/step - loss: 1.3538 - categorical_accuracy: 0.6322 - categorical_crossentropy: 1.3538 - val_loss: 0.9525 - val_categorical_accuracy: 0.8636 - val_categorical_crossentropy: 0.9525 - lr: 0.0010
# Epoch 3/200
# 69/69 [==============================] - 55s 729ms/step - loss: 1.2427 - categorical_accuracy: 0.6593 - categorical_crossentropy: 1.2427 - val_loss: 0.8637 - val_categorical_accuracy: 0.8912 - val_categorical_crossentropy: 0.8637 - lr: 0.0010
# Epoch 4/200
# 69/69 [==============================] - 52s 698ms/step - loss: 1.1895 - categorical_accuracy: 0.6713 - categorical_crossentropy: 1.1895 - val_loss: 0.6625 - val_categorical_accuracy: 0.8948 - val_categorical_crossentropy: 0.6625 - lr: 0.0010
# Epoch 5/200
# 69/69 [==============================] - 52s 697ms/step - loss: 1.1377 - categorical_accuracy: 0.6884 - categorical_crossentropy: 1.1377 - val_loss: 0.4342 - val_categorical_accuracy: 0.9196 - val_categorical_crossentropy: 0.4342 - lr: 0.0010
# Epoch 6/200
# 69/69 [==============================] - 52s 695ms/step - loss: 1.0892 - categorical_accuracy: 0.7018 - categorical_crossentropy: 1.0892 - val_loss: 0.4348 - val_categorical_accuracy: 0.8952 - val_categorical_crossentropy: 0.4348 - lr: 0.0010
# Epoch 7/200
# 69/69 [==============================] - 52s 697ms/step - loss: 1.0873 - categorical_accuracy: 0.7059 - categorical_crossentropy: 1.0873 - val_loss: 0.3075 - val_categorical_accuracy: 0.9312 - val_categorical_crossentropy: 0.3075 - lr: 0.0010
# Epoch 8/200
# 69/69 [==============================] - 71s 971ms/step - loss: 1.0564 - categorical_accuracy: 0.7164 - categorical_crossentropy: 1.0564 - val_loss: 0.3063 - val_categorical_accuracy: 0.9270 - val_categorical_crossentropy: 0.3063 - lr: 0.0010
# Epoch 9/200
# 69/69 [==============================] - 60s 800ms/step - loss: 1.0256 - categorical_accuracy: 0.7230 - categorical_crossentropy: 1.0256 - val_loss: 0.3172 - val_categorical_accuracy: 0.9062 - val_categorical_crossentropy: 0.3172 - lr: 0.0010
# Epoch 10/200
# 69/69 [==============================] - 65s 879ms/step - loss: 1.0223 - categorical_accuracy: 0.7308 - categorical_crossentropy: 1.0223 - val_loss: 5.0619 - val_categorical_accuracy: 0.8468 - val_categorical_crossentropy: 5.0619 - lr: 0.0010
# Epoch 11/200
# 69/69 [==============================] - 56s 718ms/step - loss: 0.9955 - categorical_accuracy: 0.7376 - categorical_crossentropy: 0.9955 - val_loss: 0.2535 - val_categorical_accuracy: 0.9338 - val_categorical_crossentropy: 0.2535 - lr: 0.0010
# Epoch 12/200
# 69/69 [==============================] - 59s 801ms/step - loss: 0.9724 - categorical_accuracy: 0.7449 - categorical_crossentropy: 0.9724 - val_loss: 0.2578 - val_categorical_accuracy: 0.9258 - val_categorical_crossentropy: 0.2578 - lr: 0.0010
# Epoch 13/200
# 69/69 [==============================] - 53s 691ms/step - loss: 1.0492 - categorical_accuracy: 0.7235 - categorical_crossentropy: 1.0492 - val_loss: 0.3801 - val_categorical_accuracy: 0.8978 - val_categorical_crossentropy: 0.3801 - lr: 0.0010
# Epoch 14/200
# 69/69 [==============================] - 52s 695ms/step - loss: 0.9871 - categorical_accuracy: 0.7420 - categorical_crossentropy: 0.9871 - val_loss: 0.6904 - val_categorical_accuracy: 0.9094 - val_categorical_crossentropy: 0.6904 - lr: 0.0010
# Epoch 15/200
# 69/69 [==============================] - 52s 696ms/step - loss: 0.9653 - categorical_accuracy: 0.7496 - categorical_crossentropy: 0.9653 - val_loss: 0.2527 - val_categorical_accuracy: 0.9368 - val_categorical_crossentropy: 0.2527 - lr: 0.0010
# Epoch 16/200
# 69/69 [==============================] - 52s 692ms/step - loss: 0.9515 - categorical_accuracy: 0.7563 - categorical_crossentropy: 0.9515 - val_loss: 0.6177 - val_categorical_accuracy: 0.9212 - val_categorical_crossentropy: 0.6177 - lr: 0.0010
# Epoch 17/200
# 69/69 [==============================] - 52s 700ms/step - loss: 0.9721 - categorical_accuracy: 0.7536 - categorical_crossentropy: 0.9721 - val_loss: 0.3501 - val_categorical_accuracy: 0.9222 - val_categorical_crossentropy: 0.3501 - lr: 0.0010
# Epoch 18/200
# 69/69 [==============================] - 53s 714ms/step - loss: 0.9297 - categorical_accuracy: 0.7669 - categorical_crossentropy: 0.9297 - val_loss: 0.2357 - val_categorical_accuracy: 0.9392 - val_categorical_crossentropy: 0.2357 - lr: 0.0010
# Epoch 19/200
# 69/69 [==============================] - 52s 692ms/step - loss: 0.9222 - categorical_accuracy: 0.7710 - categorical_crossentropy: 0.9222 - val_loss: 0.5134 - val_categorical_accuracy: 0.9174 - val_categorical_crossentropy: 0.5134 - lr: 0.0010
# Epoch 20/200
# 69/69 [==============================] - 66s 896ms/step - loss: 0.9130 - categorical_accuracy: 0.7760 - categorical_crossentropy: 0.9130 - val_loss: 0.2450 - val_categorical_accuracy: 0.9386 - val_categorical_crossentropy: 0.2450 - lr: 0.0010
# Epoch 21/200
# 69/69 [==============================] - 63s 850ms/step - loss: 0.8873 - categorical_accuracy: 0.7809 - categorical_crossentropy: 0.8873 - val_loss: 0.2446 - val_categorical_accuracy: 0.9376 - val_categorical_crossentropy: 0.2446 - lr: 0.0010
# Epoch 22/200
# 69/69 [==============================] - 64s 853ms/step - loss: 0.8664 - categorical_accuracy: 0.7901 - categorical_crossentropy: 0.8664 - val_loss: 0.2774 - val_categorical_accuracy: 0.9286 - val_categorical_crossentropy: 0.2774 - lr: 0.0010
# Epoch 23/200
# 69/69 [==============================] - ETA: 0s - loss: 0.8875 - categorical_accuracy: 0.7876 - categorical_crossentropy: 0.8875
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 69/69 [==============================] - 53s 708ms/step - loss: 0.8875 - categorical_accuracy: 0.7876 - categorical_crossentropy: 0.8875 - val_loss: 0.2934 - val_categorical_accuracy: 0.9258 - val_categorical_crossentropy: 0.2934 - lr: 0.0010
# 20/20 [==============================] - 13s 481ms/step - loss: 0.2328 - categorical_accuracy: 0.9396 - categorical_crossentropy: 0.2328
# Epoch 1/200
# 69/69 [==============================] - 73s 956ms/step - loss: 1.7333 - categorical_accuracy: 0.5415 - categorical_crossentropy: 1.7333 - val_loss: 1.2197 - val_categorical_accuracy: 0.6138 - val_categorical_crossentropy: 1.2197 - lr: 0.0010
# Epoch 2/200
# 69/69 [==============================] - 54s 727ms/step - loss: 1.3514 - categorical_accuracy: 0.6324 - categorical_crossentropy: 1.3514 - val_loss: 19.3365 - val_categorical_accuracy: 0.6536 - val_categorical_crossentropy: 19.3365 - lr: 0.0010
# Epoch 3/200
# 69/69 [==============================] - 69s 946ms/step - loss: 1.2796 - categorical_accuracy: 0.6549 - categorical_crossentropy: 1.2796 - val_loss: 0.8874 - val_categorical_accuracy: 0.8948 - val_categorical_crossentropy: 0.8874 - lr: 0.0010
# Epoch 4/200
# 69/69 [==============================] - 70s 957ms/step - loss: 1.1771 - categorical_accuracy: 0.6771 - categorical_crossentropy: 1.1771 - val_loss: 0.5422 - val_categorical_accuracy: 0.9062 - val_categorical_crossentropy: 0.5422 - lr: 0.0010
# Epoch 5/200
# 69/69 [==============================] - 81s 1s/step - loss: 1.1346 - categorical_accuracy: 0.6909 - categorical_crossentropy: 1.1346 - val_loss: 0.4250 - val_categorical_accuracy: 0.9170 - val_categorical_crossentropy: 0.4250 - lr: 0.0010
# Epoch 6/200
# 69/69 [==============================] - 52s 699ms/step - loss: 1.0966 - categorical_accuracy: 0.7011 - categorical_crossentropy: 1.0966 - val_loss: 0.3479 - val_categorical_accuracy: 0.9102 - val_categorical_crossentropy: 0.3479 - lr: 0.0010
# Epoch 7/200
# 69/69 [==============================] - 54s 723ms/step - loss: 1.0693 - categorical_accuracy: 0.7088 - categorical_crossentropy: 1.0693 - val_loss: 0.2845 - val_categorical_accuracy: 0.9288 - val_categorical_crossentropy: 0.2845 - lr: 0.0010
# Epoch 8/200
# 69/69 [==============================] - 52s 693ms/step - loss: 1.0371 - categorical_accuracy: 0.7164 - categorical_crossentropy: 1.0371 - val_loss: 0.3150 - val_categorical_accuracy: 0.9198 - val_categorical_crossentropy: 0.3150 - lr: 0.0010
# Epoch 9/200
# 69/69 [==============================] - 52s 694ms/step - loss: 1.1295 - categorical_accuracy: 0.7017 - categorical_crossentropy: 1.1295 - val_loss: 0.6839 - val_categorical_accuracy: 0.8616 - val_categorical_crossentropy: 0.6839 - lr: 0.0010
# Epoch 10/200
# 69/69 [==============================] - 53s 714ms/step - loss: 1.0413 - categorical_accuracy: 0.7212 - categorical_crossentropy: 1.0413 - val_loss: 0.3687 - val_categorical_accuracy: 0.9066 - val_categorical_crossentropy: 0.3687 - lr: 0.0010
# Epoch 11/200
# 69/69 [==============================] - 52s 696ms/step - loss: 1.0164 - categorical_accuracy: 0.7309 - categorical_crossentropy: 1.0164 - val_loss: 0.5636 - val_categorical_accuracy: 0.8582 - val_categorical_crossentropy: 0.5636 - lr: 0.0010
# Epoch 12/200
# 69/69 [==============================] - ETA: 0s - loss: 1.0063 - categorical_accuracy: 0.7342 - categorical_crossentropy: 1.0063
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 69/69 [==============================] - 52s 701ms/step - loss: 1.0063 - categorical_accuracy: 0.7342 - categorical_crossentropy: 1.0063 - val_loss: 0.5243 - val_categorical_accuracy: 0.9078 - val_categorical_crossentropy: 0.5243 - lr: 0.0010
# 20/20 [==============================] - 12s 431ms/step - loss: 0.2872 - categorical_accuracy: 0.9232 - categorical_crossentropy: 0.2872
# Epoch 1/200
# 69/69 [==============================] - 55s 698ms/step - loss: 1.6980 - categorical_accuracy: 0.5516 - categorical_crossentropy: 1.6980 - val_loss: 14.3429 - val_categorical_accuracy: 0.5640 - val_categorical_crossentropy: 14.3429 - lr: 0.0010
# Epoch 2/200
# 69/69 [==============================] - 51s 684ms/step - loss: 1.3546 - categorical_accuracy: 0.6381 - categorical_crossentropy: 1.3546 - val_loss: 40.5119 - val_categorical_accuracy: 0.3320 - val_categorical_crossentropy: 40.5119 - lr: 0.0010
# Epoch 3/200
# 69/69 [==============================] - 53s 707ms/step - loss: 1.2867 - categorical_accuracy: 0.6529 - categorical_crossentropy: 1.2867 - val_loss: 0.7022 - val_categorical_accuracy: 0.8956 - val_categorical_crossentropy: 0.7022 - lr: 0.0010
# Epoch 4/200
# 69/69 [==============================] - 51s 686ms/step - loss: 1.1739 - categorical_accuracy: 0.6777 - categorical_crossentropy: 1.1739 - val_loss: 0.6564 - val_categorical_accuracy: 0.8716 - val_categorical_crossentropy: 0.6564 - lr: 0.0010
# Epoch 5/200
# 69/69 [==============================] - 52s 691ms/step - loss: 1.1375 - categorical_accuracy: 0.6903 - categorical_crossentropy: 1.1375 - val_loss: 0.4423 - val_categorical_accuracy: 0.9192 - val_categorical_crossentropy: 0.4423 - lr: 0.0010
# Epoch 6/200
# 69/69 [==============================] - 51s 683ms/step - loss: 1.1112 - categorical_accuracy: 0.7034 - categorical_crossentropy: 1.1112 - val_loss: 6.4757 - val_categorical_accuracy: 0.7584 - val_categorical_crossentropy: 6.4757 - lr: 0.0010
# Epoch 7/200
# 69/69 [==============================] - 51s 684ms/step - loss: 1.0663 - categorical_accuracy: 0.7092 - categorical_crossentropy: 1.0663 - val_loss: 0.3918 - val_categorical_accuracy: 0.9232 - val_categorical_crossentropy: 0.3918 - lr: 0.0010
# Epoch 8/200
# 69/69 [==============================] - 51s 684ms/step - loss: 1.0451 - categorical_accuracy: 0.7183 - categorical_crossentropy: 1.0451 - val_loss: 0.2880 - val_categorical_accuracy: 0.9282 - val_categorical_crossentropy: 0.2880 - lr: 0.0010
# Epoch 9/200
# 69/69 [==============================] - 51s 679ms/step - loss: 1.0088 - categorical_accuracy: 0.7297 - categorical_crossentropy: 1.0088 - val_loss: 4.7428 - val_categorical_accuracy: 0.7690 - val_categorical_crossentropy: 4.7428 - lr: 0.0010
# Epoch 10/200
# 69/69 [==============================] - 51s 680ms/step - loss: 1.0171 - categorical_accuracy: 0.7277 - categorical_crossentropy: 1.0171 - val_loss: 0.3630 - val_categorical_accuracy: 0.9054 - val_categorical_crossentropy: 0.3630 - lr: 0.0010
# Epoch 11/200
# 69/69 [==============================] - 51s 680ms/step - loss: 0.9956 - categorical_accuracy: 0.7389 - categorical_crossentropy: 0.9956 - val_loss: 0.3347 - val_categorical_accuracy: 0.9088 - val_categorical_crossentropy: 0.3347 - lr: 0.0010
# Epoch 12/200
# 69/69 [==============================] - 51s 679ms/step - loss: 1.0448 - categorical_accuracy: 0.7229 - categorical_crossentropy: 1.0448 - val_loss: 4.8465 - val_categorical_accuracy: 0.8290 - val_categorical_crossentropy: 4.8465 - lr: 0.0010
# Epoch 13/200
# 69/69 [==============================] - ETA: 0s - loss: 0.9897 - categorical_accuracy: 0.7374 - categorical_crossentropy: 0.9897
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 69/69 [==============================] - 52s 689ms/step - loss: 0.9897 - categorical_accuracy: 0.7374 - categorical_crossentropy: 0.9897 - val_loss: 0.3553 - val_categorical_accuracy: 0.9140 - val_categorical_crossentropy: 0.3553 - lr: 0.0010
# 20/20 [==============================] - 12s 441ms/step - loss: 0.2907 - categorical_accuracy: 0.9282 - categorical_crossentropy: 0.2907
